# %% [markdown]
# # Emotional Consistency among Political Ideologies: An Approach to Address Polarization on Youtube
#
# Group 5:
# - Chance Landis (ChancL), Hanna Lee (Lee10), Jason Sun (YongXs), Andy Wong (WongA22)

# %% [markdown]
# ## Credit Listing
# - Hanna: Democratic-leaning Channels Data Collection
# - Chance: Republican-leaning Channels Data Collection
# - Andy: Exploratory Data Analysis
# - Jason: Text Documentation
#
# ## Problem Statement
# We want to figure out whether the current political polarization is associated with the emotional values expressed by each party. Due to the current politically charged environment of our country, the semblance of sympathizing toward a value that is not related to your political party causes backlash. This fear of backlash can create a “false” polarized environment, which is an extension of the fear itself. The question that arises is whether these boundaries are reinforced by the people themselves and/or  external factors, like social media.
#
# ## Research Question
# 1. Do political parties exhibit similar emotional responses to differing ideologies?
#
# ## Data Collection
# To investigate this topic, we will analyze content from the top five YouTube channels associated with Democratic and Republican viewpoints, based on subscriber counts. The channels selected for the study are:
#
# - **Democratic-leaning Channels**: Vice, Vox, MSNBC, The Daily Show, The Young Turks
# - **Republican-leaning Channels**: Fox News, Ben Shapiro, Steven Crowder, The Daily Mail, The Daily Wire
#
# We have identified eight key ideologies for this analysis to understand if there are emotional differences in how political parties discuss these topics. For each ideology, a set of keywords has been established to facilitate data scraping:
# a
# - **ISIS**: Terrorism, Extremism, Radical
# - **Guns**: Shootings, School shooting, Firearms, Gun control, NRA, Second Amendment
# - **Immigration**: Border control, Mexico, Visa /Citizenship, Asylum, Deportation, Refugee
# - **Economy**: Budget deficit, Unemployment, Inflation, Interest rate, Federal Reserve, Market, Employment
# - **Health care**: Medicaid, Covid, Obamacare, Public health, Insurance
# - **Socio-economic**: Rich / poor, Income inequality, Poverty, Wealth distribution
# - **Abortion**: Pregnancy, Unwanted Pregnancy, Roe, Wade, Abortion, Pro-life, Rape, Incest, Life of mother, Religion
# - **Climate change**: Global Warming, Carbo, Alternative Energy, Climate, Methane, Emissions, Gas, Greenhouse

# %% [markdown]
# ### Sources of Information
# - **AllSides**: A media bias tool that provides a rating based on "multi-partisan Editorial Reviews by trained experts and Blind Bias Surveys™ in which participants rate content without knowing the source." We used this tool to determine how we should classify the most popular (based on subscriber count) YouTube channels we found. (Source: https://www.allsides.com/media-bias/media-bias-rating-methods)
# - **HypeAuitor**: A company that uses a data-driven approach to influencer marketing. In the process, they collated lists of YouTube based on category, subscriber count, and country. This allowed us to find YouTube channels that focused on news and politics with the most subscribers. (Source: https://hypeauditor.com/about/company/, https://hypeauditor.com/top-youtube-news-politics-united-states/)
# - **Pew Research Center**: A nonpartisan, nonprofit organization that conducts research on public opinion, demographic trends, and social issues. It provides data-driven insights into various aspects of social science issues, explicitly stating they do not take a stance on political issues. For our research, we relied on their studies on political ideologies and alignment with political parties as a reference. (Source: https://www.pewresearch.org/about/, https://www.pewresearch.org/politics/2016/06/22/5-views-of-parties-positions-on-issues-ideologies/)
# - **YouTube**: As a group, we've chosen to expand our collection of YouTube videos by selecting additional keywords associated with the ideology we're studying. Our focus will be on gathering comments from these videos to conduct our research.
#     - We used a combination of Andy and Hanna's code to get the comments from YouTube channels.

# %% [markdown]
# ### Top 5 Democratic YouTube Channels
# Vice, Vox, MSNBC, The Daily Show, The Young Turks

# %% [markdown]
# #### Setup

# %%
# !pip install --upgrade google-api-python-client --quiet
# !pip install nltk --quiet
# !pip install nrclex --quiet

# %%
# imports
import json
import pandas as pd

import nltk

import googleapiclient
import googleapiclient.discovery
import googleapiclient.errors
from googleapiclient.errors import HttpError

import re
import datetime
from datetime import datetime
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.tokenize import casual

from nrclex import NRCLex

# %% [markdown]
# #### Define API / Lists / Dictionaries

# %%
# API call
# vice: AIzaSyA2rNi_MI-3LQkBzzQ6Tn4EF0lgXWoilfc, AIzaSyAfHslkgOEDPAnr5_jB1b2wxZKthApBXNw, AIzaSyCxD0YFA3bAPMoK2ovmCFnKhW7yqrNshEQ
# vox: AIzaSyAoeLCEEfqmnpRHR4xRMKt1YdbeUUw75ao, AIzaSyDnBTOIfxF4o-aFiBKJNtkZJBKajBzYDlI
# msnbc: AIzaSyAbCFiuHc9untZ17tyV5A6rlpKNib4qviE
# daily show: AIzaSyD8adQZlhLNVQrQXpU5-u3s1Y-9TZs20ik
# young turk: AIzaSyB8yyrUrfQGLrlQRmF555oc1emrIDXF7yU

# Others: API_KEY = "AIzaSyCjWja_yyRROSw5tcP_KxYjasJgHLX3oKE"
# API_KEY = "AIzaSyCjWja_yyRROSw5tcP_KxYjasJgHLX3oKE"
API_KEY = "AIzaSyAfHslkgOEDPAnr5_jB1b2wxZKthApBXNw"

youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=API_KEY)

# %%
# Define channels
channels = ["Vice", "Vox", "msnbc", "thedailyshow", "TheYoungTurks"]

# %%
# Establish keyword dictionary
keyword_lists = {
    "isis": ["ISIS", "Radicalist", "Islamic State", "Jihadist", "Syria conflict", "Iraq insurgency", "Al-Qaeda", "Radical Islam", "Suicide bombings", "Mosul"],
    "guns": ["Gun", "Shooting", "School shooting", "Firearm", "Gun control", "NRA", "Second Amendment"],
    "immigration": ["Immigration", "Border control", "Mexico", "Visa", "Citizenship", "Asylum", "Deportation", "Refugee"],
    "economy": ["Economy", "Budget deficit", "Unemployment rate", "Inflation", "Interest rate", "Federal reserve", "Recession", "GDP", "Consumer Price Index", "Trade Balance", "Stock Exchange", "Central bank", "Consumer spending", "NASDAQ", "Dow Jones", "S&P", "currency exchange", "Financial crisis", "Investment strategies", "Credit rating", "Commodities", "Real estate market", "Banking sector"],
    "healthcare": ["Health care", "Medicaid", "Covid", "Obamacare", "Public health", "Insurance", "Universal healthcare", "Private healthcare", "Medicare", "Patient rights", "Vaccination", "Pandemics"], 
    "socioeco": ["Socio-economic", "Rich", "Poor", "Income inequality", "Poverty", "Wealth distribution", "Minimum Wage", "Financial Insecurity", "Welfare", "Homelessness", "Financial Literacy"],
    "abortion": ["Abortion", "Pregnancy", "Unwanted Pregnancy", "Roe", "Wade", "Pro-life", "Planned Parenthood", "Fetal rights", "Life of mother", "Reproductive", "Women's health", "Gestational", "Late-term abortion", "Post-abortion syndrome", "Safe haven laws", "Mifepristone", "Misoprostol", "Dobbs", "Pro-choice", "Anti-abortion"],
    "climate": ["Climate change", "Global Warming", "Carbon", "Alternative Energy", "Climate", "Methane", "Emissions", "Gas", "Greenhouse", "Renewable energy", "Fossil fuels", "Deforestation", "Carbon footprint"]
}

# %%
# Establish keyword dictionary
keyword_lists2 = {
    "guns": ["Gun", "Shooting", "School shooting", "Firearm", "Gun control", "NRA", "Second Amendment"],
    "immigration": ["Immigration", "Border control", "Mexico", "Visa", "Citizenship", "Asylum", "Deportation", "Refugee"],
    "healthcare": ["Health care", "Medicaid", "Covid", "Obamacare", "Public health", "Insurance", "Universal healthcare", "Private healthcare", "Medicare", "Patient rights", "Vaccination", "Pandemics"], 
    "climate": ["Climate change", "Global Warming", "Carbon", "Alternative Energy", "Climate", "Methane", "Emissions", "Gas", "Greenhouse", "Renewable energy", "Fossil fuels", "Deforestation", "Carbon footprint"]
}

# %%
# Define keywords
keyword_isis = {
    "isis": ["ISIS", "Radicalist", "Islamic State", "Jihadist", "Syria conflict", "Iraq insurgency", "Al-Qaeda", "Radical Islam", "Suicide bombings", "Mosul"]
}

# %%
keyword_guns = {
    "guns": ["Gun", "Shooting", "School shooting", "Firearm", "Gun control", "NRA", "Second Amendment"]
}

# %%
keyword_immigration = {
    "immigration": ["Immigration", "Border control", "Mexico", "Visa", "Citizenship", "Asylum", "Deportation", "Refugee"]
}

# %%
keyword_economy = {
    "economy": ["Economy", "Budget deficit", "Unemployment rate", "Inflation", "Interest rate", "Federal reserve", "Recession", "GDP", "Consumer Price Index", "Trade Balance", "Stock Exchange", "Central bank", "Consumer spending", "NASDAQ", "Dow Jones", "S&P", "currency exchange", "Financial crisis", "Investment strategies", "Credit rating", "Commodities", "Real estate market", "Banking sector"]
}

# %%
keyword_healthcare = {
    "healthcare": ["Health care", "Medicaid", "Covid", "Obamacare", "Public health", "Insurance", "Universal healthcare", "Private healthcare", "Medicare", "Patient rights", "Vaccination", "Pandemics"] 
}

# %%
keyword_socioeco = {
    "socioeco": ["Socio-economic", "Rich", "Poor", "Income inequality", "Poverty", "Wealth distribution", "Minimum Wage", "Financial Insecurity", "Welfare", "Homelessness", "Financial Literacy"],
}

# %%
keyword_abortion = {
    "abortion": ["Abortion", "Pregnancy", "Unwanted Pregnancy", "Roe", "Wade", "Pro-life", "Planned Parenthood", "Fetal rights", "Life of mother", "Reproductive", "Women's health", "Gestational", "Late-term abortion", "Post-abortion syndrome", "Safe haven laws", "Mifepristone", "Misoprostol", "Dobbs", "Pro-choice", "Anti-abortion"]
}

# %%
keyword_climate = {
    "climate": ["Climate change", "Global Warming", "Carbon", "Alternative Energy", "Climate", "Methane", "Emissions", "Gas", "Greenhouse", "Renewable energy", "Fossil fuels", "Deforestation", "Carbon footprint"]
}

# %% [markdown]
# #### Functions

# %%
# Function for getting channel id based on name
def get_channel_id(channel):  
    channel_id = youtube.search().list(
        part="snippet",
        type="channel",
        q=channel
    )

    res_channel = channel_id.execute()
    chan_id = res_channel["items"][0]["id"]["channelId"]

    return chan_id

# %%
# Function for retrieving the upload playlist id using channel id
def get_upload_id(channel):
    request = youtube.channels().list(
        part="contentDetails",
        id=channel
    )

    res = request.execute()
    uploads_playlist_id = res["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    return uploads_playlist_id

# %% [markdown]
# #### Get Channel IDs

# %%
up_id = []

for channel in channels:
    print(channel)
    chan_id = get_channel_id(channel)
    upload_id = get_upload_id(chan_id)
    up_id.append(upload_id)
# Out:
# Vice
# Vox
# msnbc
# thedailyshow
# TheYoungTurks

# %%
up_id
# Out:
# ['UUn8zNIfYAQNdrFRrr8oibKw',
#  'UULXo7UDZvByw2ixzpQCufnA',
#  'UUaXkIU1QidjPwiAYu6GcHjg',
#  'UUwWhs_6x42TyRM4Wstoq8HA',
#  'UU1yBKRuGpC1tSM73A0ZjYjQ']

# %%
# Initialize PorterStemmer
ps = PorterStemmer()

# Function to check if a video title contains any of the keywords
def contains_keyword(title, keywords):
    title_lower = title.lower()
    words = word_tokenize(title_lower)
    
    # Stem each word in the title + keyword
    stemmed_words = [ps.stem(word) for word in words]
    for keyword in keywords:
        keyword_stemmed = ps.stem(keyword.lower())
        if keyword_stemmed in stemmed_words:
            return keyword
    return None

# %%
# function to fetch videos from a playlist and get title with keywords
def keyword_videos(playlist_id, keyword_list, channel_name, limit):
    videos_info = []
    next_page_token = None

    while True:
        # Make the next API request using the nextPageToken
        request = youtube.playlistItems().list(
            part="snippet",
            playlistId=playlist_id,
            pageToken=next_page_token
        ) 
        res = request.execute()

        # Process the response and save video info
        for v in res["items"]:
            video_title = v["snippet"]["title"]
            detected_word = contains_keyword(video_title, keyword_list)
            if detected_word:
                # Separate Resource Call to retrieve video views
                views = youtube.videos().list(id=v['snippet']['resourceId']['videoId'], part="snippet,contentDetails,statistics")
                view_temp = views.execute()
                video_views = view_temp['items'][0]['statistics'].get('viewCount', 'Not Available')

                # Append video information with views to videos_info list
                videos_info.append({
                    "channel": channel_name,
                    "id": v["snippet"]["resourceId"]["videoId"],
                    "title": video_title,
                    "keyword": detected_word,
                    "published_at": v["snippet"]["publishedAt"],
                    "VideoViews": video_views
                })
        # Update the nextPageToken for the next iteration
        next_page_token = res.get('nextPageToken')

        if not next_page_token or (len(videos_info) > limit):
            break
    return videos_info

# %%
# Function for getting top 30 relevant comments for a list of videos
def get_vid_comments(vid_id, limit):
    vids_final = []

    # Iterate through each video in the video list
    try:
        # Retrieve comments for the video
        request = youtube.commentThreads().list(
            videoId=vid_id,
            part='id,snippet,replies',
            textFormat='plainText',
            order='relevance',
            maxResults=50)
        res = request.execute()

        # Iterate through each comment
        for v in res["items"]:
            # Extract comment information and add to the final list
            comment_info = {
                'VideoId': vid_id,
                'CommentId': v['id'],
                'CommentTitle': v['snippet']['topLevelComment']['snippet']['textOriginal'],
                'CommentCreationTime': v['snippet']['topLevelComment']['snippet']['publishedAt'],
                'CommentLikes': v['snippet']['topLevelComment']['snippet']['likeCount']
            }
            vids_final.append(comment_info)

            # Check if the number of saved comments exceeds the limit
            if len(vids_final) >= limit:
                return vids_final

        nextPageToken = res.get('nextPageToken')

        # Retrieve additional pages of comments if available
        while nextPageToken:
            try:
                request = youtube.commentThreads().list(
                    videoId=vid_id,
                    part='id,snippet,replies',
                    textFormat='plainText',
                    order='relevance',
                    maxResults=50,
                    pageToken=nextPageToken)
                res = request.execute()

                nextPageToken = res.get('nextPageToken')

                # Iterate through additional comments and add to the final list
                for v in res["items"]:
                    comment_info = {
                        'VideoId': vid_id,
                        'CommentId': v['id'],
                        'CommentTitle': v['snippet']['topLevelComment']['snippet']['textOriginal'],
                        'CommentCreationTime': v['snippet']['topLevelComment']['snippet']['publishedAt'],
                        'CommentLikes': v['snippet']['topLevelComment']['snippet']['likeCount']
                    }
                    vids_final.append(comment_info)

                    # Check if the number of saved comments exceeds the limit
                    if len(vids_final) >= limit:
                        return vids_final
            except KeyError:
                break

    # Error handling for videos with disabled comments
    except HttpError as e:
        if e.resp.status == 403:
            print(f"Comments are disabled for the video with videoId: {vid_id}")

        else:
            print("An HTTP error occurred:", e)

    return vids_final

# %% [markdown]
# ### Vice

# %%
# Run function to get information about relevant videos
vice_vid_info = []

for category, keywords in keyword_lists.items():
    print(f"Fetching videos for category: {category}")
    vid_info = keyword_videos("UUn8zNIfYAQNdrFRrr8oibKw", keywords, "Vice", 10)
    print(f"Found {len(vid_info)} videos for category {category}")
    vice_vid_info.append(vid_info)
# Out:
# Fetching videos for category: isis
# Found 11 videos for category isis
# Fetching videos for category: guns
# Found 11 videos for category guns
# Fetching videos for category: immigration
# Found 11 videos for category immigration
# Fetching videos for category: economy
# Found 4 videos for category economy
# Fetching videos for category: healthcare
# Found 11 videos for category healthcare
# Fetching videos for category: socioeco
# Found 11 videos for category socioeco
# Fetching videos for category: abortion
# Found 7 videos for category abortion
# Fetching videos for category: climate
# Found 12 videos for category climate

# %%
vice_vid_info
# Out:
# [[{'channel': 'Vice',
#    'id': 'SwoRx3tstxY',
#    'title': 'We Uncovered an ISIS Mass Grave | Super Users',
#    'keyword': 'ISIS',
#    'published_at': '2022-04-11T15:00:12Z',
#    'VideoViews': '349357'},
#   {'channel': 'Vice',
#    'id': 'LttCr8rudxQ',
#    'title': 'How ISIS Makes Millions From Stolen Antiques | The Business of Crime',
#    'keyword': 'ISIS',
#    'published_at': '2022-02-24T16:00:17Z',
#    'VideoViews': '404048'},
#   {'channel': 'Vice',
#    'id': 'm54L1jusS5w',
#    'title': 'Safer at War than at Home | Diary of a Combat Medic Fighting ISIS (Part 3/3)',
#    'keyword': 'ISIS',
#    'published_at': '2019-04-05T16:00:09Z',
#    'VideoViews': '330452'},
#   {'channel': 'Vice',
#    'id': '_xO5dsGEL_E',
#    'title': 'Interrogating Enemy Fighters | Diary of a Combat Medic Fighting ISIS (Part 2/3)',
#    'keyword': 'ISIS',
#    'published_at': '2019-04-04T16:00:03Z',
#    'VideoViews': '240228'},
#   {'channel': 'Vice',
#    'id': 'PdJJxwP8NaU',
#    'title': 'What to Pack for War in Syria | Diary of a Combat Medic Fighting ISIS (Part 1/3)',
#    'keyword': 'ISIS',
#    'published_at': '2019-04-03T16:30:00Z',
#    'VideoViews': '430234'},
#   {'channel': 'Vice',
#    'id': 'qoqds4LV9RI',
#    'title': 'Foreigners Fighting ISIS in Syria: The War of Others',
#    'keyword': 'ISIS',
#    'published_at': '2016-04-06T20:39:35Z',
#    'VideoViews': '3531874'},
#   {'channel': 'Vice',
#    'id': 'efSRjjzde54',
#    'title': 'Daily VICE Canada: Exclusive - Canadian Teenager Returns From Fighting ISIS',
#    'keyword': 'ISIS',
#    'published_at': '2016-03-24T16:28:18Z',
#    'VideoViews': '13012'},
#   {'channel': 'Vice',
#    'id': 'juAxCz5Vrxc',
#    'title': 'Daily VICE Canada: Our Exclusive Story On The Death of A Kurdish Commander Fighting ISIS',
#    'keyword': 'ISIS',
#    'published_at': '2016-03-01T17:28:27Z',
#    'VideoViews': '6472'},
#   {'channel': 'Vice',
#    'id': 'EaPnv82Hs3g',
#    'title': 'Daily VICE Canada: Haiti Political Chaos, Ceasing ISIS Airstrikes, Inuit Face Tattoos, Savages',
#    'keyword': 'ISIS',
#    'published_at': '2016-02-09T16:02:38Z',
#    'VideoViews': '3431'},
#   {'channel': 'Vice',
#    'id': 'Kae-nng77yE',
#    'title': 'VICE Special Report: Fighting Isis (Ben Anderson Debrief)',
#    'keyword': 'ISIS',
#    'published_at': '2016-02-01T20:40:21Z',
#    'VideoViews': '160020'},
#   {'channel': 'Vice',
#    'id': '5I2HA1MIeeo',
#    'title': 'Daily VICE Canada: Canadian ISIS Defector, Pipeline Runner, Weird Trudeau Memorabilia',
#    'keyword': 'ISIS',
#    'published_at': '2016-01-07T17:14:52Z',
#    'VideoViews': '6234'}],
#  [{'channel': 'Vice',
#    'id': 'V3KGKQd_4tk',
#    'title': 'Gun Owners & Users Debate America’s Gun Problem | VICE Debates',
#    'keyword': 'Gun',
#    'published_at': '2023-01-25T16:00:26Z',
#    'VideoViews': '887131'},
#   {'channel': 'Vice',
#    'id': '61trVLZv1-w',
#    'title': 'How to Buy Black Market Guns From Cops | The Business of Crime',
#    'keyword': 'Gun',
#    'published_at': '2023-01-09T20:00:01Z',
#    'VideoViews': '794045'},
#   {'channel': 'Vice',
#    'id': 'Jp0nqJ1yrrg',
#    'title': 'Golf, Booze & Guns: Inside Boomer Paradise | The Bubble (Full Film) | The Short List',
#    'keyword': 'Gun',
#    'published_at': '2022-10-06T16:00:18Z',
#    'VideoViews': '2175906'},
#   {'channel': 'Vice',
#    'id': 'lFIro2Dnfj8',
#    'title': 'Guns, Gambling, and Gold: Meet The Las Vegas Duke | VICE Guide to Vegas',
#    'keyword': 'Gun',
#    'published_at': '2022-07-24T14:59:56Z',
#    'VideoViews': '273113'},
#   {'channel': 'Vice',
#    'id': '4PfZlxhvdkM',
#    'title': 'The Replacement Conspiracy Inspiring Mass Shootings | Decade of Hate',
#    'keyword': 'Shooting',
#    'published_at': '2022-07-08T15:00:02Z',
#    'VideoViews': '1988490'},
#   {'channel': 'Vice',
#    'id': '-1A9v5bQDqk',
#    'title': 'Firearms Training at a One Star Gun Range | One Star Reviews',
#    'keyword': 'Gun',
#    'published_at': '2022-05-07T15:00:00Z',
#    'VideoViews': '835751'},
#   {'channel': 'Vice',
#    'id': 'Jj-3kBi49eg',
#    'title': 'With Liberty and Guns for All | Spiraling',
#    'keyword': 'Gun',
#    'published_at': '2021-11-28T16:00:13Z',
#    'VideoViews': '396938'},
#   {'channel': 'Vice',
#    'id': '388wlVWxGz0',
#    'title': 'Why Mexican Cartels Use American Guns | The War On Drugs',
#    'keyword': 'Gun',
#    'published_at': '2021-06-28T15:00:05Z',
#    'VideoViews': '783889'},
#   {'channel': 'Vice',
#    'id': 'Zh2e8nY8VJ0',
#    'title': 'The Deadliest Mass Shooting in America | Source Material',
#    'keyword': 'Shooting',
#    'published_at': '2020-12-19T16:00:08Z',
#    'VideoViews': '557533'},
#   {'channel': 'Vice',
#    'id': 'UnETVMI4tY8',
#    'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#    'keyword': 'Gun',
#    'published_at': '2020-02-09T16:00:08Z',
#    'VideoViews': '7498318'},
#   {'channel': 'Vice',
#    'id': 'gs26R56d3ww',
#    'title': 'Migrating to Shoot Up Legally: Heroin Commuters | High Society',
#    'keyword': 'Shooting',
#    'published_at': '2020-01-22T20:00:08Z',
#    'VideoViews': '1935443'}],
#  [{'channel': 'Vice',
#    'id': 'pZH9ZYFU26U',
#    'title': 'Cartel Propaganda is Fuelling Mexico’s Drug War | The War on Drugs',
#    'keyword': 'Mexico',
#    'published_at': '2023-03-06T16:00:24Z',
#    'VideoViews': '1821390'},
#   {'channel': 'Vice',
#    'id': '2RZoGOc3VCs',
#    'title': "Mexico's Most Wanted Drug Kingpin | The War on Drugs",
#    'keyword': 'Mexico',
#    'published_at': '2022-09-28T15:00:02Z',
#    'VideoViews': '2369665'},
#   {'channel': 'Vice',
#    'id': '_kqiGAswtKE',
#    'title': 'How Sinaloa Became Mexico’s Biggest Cartel | The War on Drugs',
#    'keyword': 'Mexico',
#    'published_at': '2022-09-13T15:00:21Z',
#    'VideoViews': '2181226'},
#   {'channel': 'Vice',
#    'id': 'qavbWjQpDhA',
#    'title': 'The Dangers of Medical Tourism in Mexico #shorts',
#    'keyword': 'Mexico',
#    'published_at': '2021-08-18T15:00:25Z',
#    'VideoViews': '517069'},
#   {'channel': 'Vice',
#    'id': '5cm9ELLR8ds',
#    'title': 'The Deadliest Cartel in Mexico | The War on Drugs',
#    'keyword': 'Mexico',
#    'published_at': '2021-05-31T19:00:01Z',
#    'VideoViews': '2132694'},
#   {'channel': 'Vice',
#    'id': 'hyk5YXnag9E',
#    'title': 'Increasing Tensions after Moria Refugees Camp Fires | Vice Around the World Episode 11',
#    'keyword': 'Refugee',
#    'published_at': '2020-11-07T20:00:12Z',
#    'VideoViews': '659'},
#   {'channel': 'Vice',
#    'id': '0rlaeRHgUCk',
#    'title': 'Partying at a Refugee Nightclub in Naples | World Without Planes',
#    'keyword': 'Refugee',
#    'published_at': '2020-10-14T19:00:00Z',
#    'VideoViews': '213833'},
#   {'channel': 'Vice',
#    'id': 'fD93qXcMwGA',
#    'title': 'The Struggles with Femicide, from Mexico to Jordan | Vice Around the World Episode 4',
#    'keyword': 'Mexico',
#    'published_at': '2020-09-12T19:00:03Z',
#    'VideoViews': '417677'},
#   {'channel': 'Vice',
#    'id': 'yF204b-Ngjk',
#    'title': 'Turkish Greek Tensions over Refugees | Vice Around the World Episode 2',
#    'keyword': 'Refugee',
#    'published_at': '2020-08-30T19:00:13Z',
#    'VideoViews': '355508'},
#   {'channel': 'Vice',
#    'id': 'uaDZ0bVresE',
#    'title': 'Pride, Psychedelics, and Refugee Raves in Amsterdam | World Without Planes',
#    'keyword': 'Refugee',
#    'published_at': '2020-08-19T19:00:09Z',
#    'VideoViews': '380254'},
#   {'channel': 'Vice',
#    'id': 'gXTeg5LAvN8',
#    'title': "Crisis Inside the Border's Largest Refugee Tent City",
#    'keyword': 'Refugee',
#    'published_at': '2020-05-03T15:00:31Z',
#    'VideoViews': '196895'}],
#  [{'channel': 'Vice',
#    'id': 'd9K96fZGY64',
#    'title': 'Drugs, Bribery & Violence: The Secret Prison Economy | Life Inside',
#    'keyword': 'Economy',
#    'published_at': '2024-02-02T16:00:32Z',
#    'VideoViews': '165251'},
#   {'channel': 'Vice',
#    'id': 'X3ySrcI2mEA',
#    'title': "Exposing Celebrities' Fake Sneakers and the Counterfeit Hype Economy: Yeezy Busta",
#    'keyword': 'Economy',
#    'published_at': '2019-07-30T21:00:02Z',
#    'VideoViews': '1432556'},
#   {'channel': 'Vice',
#    'id': 'QX3M8Ka9vUA',
#    'title': 'The Third Industrial Revolution: A Radical New Sharing Economy',
#    'keyword': 'Economy',
#    'published_at': '2018-02-13T16:00:04Z',
#    'VideoViews': '8110463'},
#   {'channel': 'Vice',
#    'id': 'dckjk1V-KRM',
#    'title': "China's Webcam Economy Is a Modern-Day Gold Rush",
#    'keyword': 'Economy',
#    'published_at': '2017-05-11T16:00:06Z',
#    'VideoViews': '1026866'}],
#  [{'channel': 'Vice',
#    'id': 'FDYqe5I35KA',
#    'title': 'Pretending To Die in a Canoe Accident to Claim Insurance | Fakes, Frauds & Scammers',
#    'keyword': 'Insurance',
#    'published_at': '2023-03-27T15:00:09Z',
#    'VideoViews': '405519'},
#   {'channel': 'Vice',
#    'id': '18_KBggvIZM',
#    'title': 'Immunity for the Community | Presented by VICE x Ad Council x COVID Collaborative x Latinovations',
#    'keyword': 'Covid',
#    'published_at': '2021-10-27T21:50:55Z',
#    'VideoViews': '97405'},
#   {'channel': 'Vice',
#    'id': 'vaTnP5AgQ_g',
#    'title': "'Never Going Back:' Releasing Inmates During a Pandemic",
#    'keyword': 'Pandemics',
#    'published_at': '2021-01-31T16:00:31Z',
#    'VideoViews': '370474'},
#   {'channel': 'Vice',
#    'id': '07lsXkWmpz8',
#    'title': 'Battling Addiction During a Pandemic',
#    'keyword': 'Pandemics',
#    'published_at': '2020-12-14T20:00:01Z',
#    'VideoViews': '857129'},
#   {'channel': 'Vice',
#    'id': 'ARQJlzZ2qu8',
#    'title': 'Pandemic Sparks Education Crisis | Vice Around the World Episode 8',
#    'keyword': 'Pandemics',
#    'published_at': '2020-10-24T19:00:01Z',
#    'VideoViews': '844'},
#   {'channel': 'Vice',
#    'id': 'M4BOdBJFkgA',
#    'title': 'How the Pandemic is Making Pakistan’s Tech Industry More Equitable',
#    'keyword': 'Pandemics',
#    'published_at': '2020-10-15T19:00:05Z',
#    'VideoViews': '96825'},
#   {'channel': 'Vice',
#    'id': 'cdZy4balvB8',
#    'title': '‘He Didn’t Think He Would Make It’ - Battling To Save Lives During the Pandemic',
#    'keyword': 'Pandemics',
#    'published_at': '2020-10-05T19:00:06Z',
#    'VideoViews': '89393'},
#   {'channel': 'Vice',
#    'id': 'qX_aaRepdIM',
#    'title': 'Running a Nightclub During a Pandemic',
#    'keyword': 'Pandemics',
#    'published_at': '2020-09-23T19:00:18Z',
#    'VideoViews': '137070'},
#   {'channel': 'Vice',
#    'id': '7fJpRa7o_fQ',
#    'title': 'Can Japanese Paid Companions Survive a Pandemic?',
#    'keyword': 'Pandemics',
#    'published_at': '2020-09-20T15:00:00Z',
#    'VideoViews': '286317'},
#   {'channel': 'Vice',
#    'id': 'Imj5EGZzrwg',
#    'title': 'Stranded on a Boat During a Hurricane in a Pandemic',
#    'keyword': 'Pandemics',
#    'published_at': '2020-08-27T19:00:04Z',
#    'VideoViews': '293188'},
#   {'channel': 'Vice',
#    'id': 'N9SR09eC_z0',
#    'title': 'Essential Workers Are Now Fighting Two Pandemics at Once | Essentials Episode 4',
#    'keyword': 'Pandemics',
#    'published_at': '2020-07-02T15:00:06Z',
#    'VideoViews': '363691'}],
#  [{'channel': 'Vice',
#    'id': 'xTnJgpF5LYg',
#    'title': 'Exposing Rich Saudi Playboys #vice #shorts',
#    'keyword': 'Rich',
#    'published_at': '2024-02-16T16:00:48Z',
#    'VideoViews': '55941'},
#   {'channel': 'Vice',
#    'id': 'ee5JCDzPB0I',
#    'title': 'The Visually Rich Cinema of Todd Haynes | The VICE Guide To Film',
#    'keyword': 'Rich',
#    'published_at': '2023-07-22T15:00:32Z',
#    'VideoViews': '45151'},
#   {'channel': 'Vice',
#    'id': 'nogb7DboO64',
#    'title': 'The Toxic Weed Making MS13 Rich #shorts',
#    'keyword': 'Rich',
#    'published_at': '2023-05-03T15:00:39Z',
#    'VideoViews': '65757'},
#   {'channel': 'Vice',
#    'id': 'XnpbVRg1-qc',
#    'title': 'Teenage Credit Card Scammers Stealing From the Rich | Crimewave',
#    'keyword': 'Rich',
#    'published_at': '2022-11-17T16:00:17Z',
#    'VideoViews': '1783065'},
#   {'channel': 'Vice',
#    'id': '3JFihjEWU3c',
#    'title': "From Homeless to Pro-Skater: Chad Muska | Epicly Later'd",
#    'keyword': 'Homelessness',
#    'published_at': '2022-10-15T15:00:02Z',
#    'VideoViews': '2788368'},
#   {'channel': 'Vice',
#    'id': 'KL8CIZej19o',
#    'title': 'The Dark Side of Rich Kids Volunteering Abroad | Informer',
#    'keyword': 'Rich',
#    'published_at': '2022-07-31T15:00:10Z',
#    'VideoViews': '7245571'},
#   {'channel': 'Vice',
#    'id': '_278oKkyf48',
#    'title': 'Inside the Secret Clubs of the Rich | Spiraling',
#    'keyword': 'Rich',
#    'published_at': '2022-01-02T16:00:10Z',
#    'VideoViews': '4191756'},
#   {'channel': 'Vice',
#    'id': '4qePOEBm9Aw',
#    'title': 'Addicted While Homeless | DOPESICK NATION (Episode 3)',
#    'keyword': 'Homelessness',
#    'published_at': '2021-08-07T14:59:46Z',
#    'VideoViews': '453423'},
#   {'channel': 'Vice',
#    'id': 'D669qcb7GGI',
#    'title': 'The Challenges of Being Homeless During a Pandemic',
#    'keyword': 'Homelessness',
#    'published_at': '2020-06-22T19:00:02Z',
#    'VideoViews': '475681'},
#   {'channel': 'Vice',
#    'id': 'egEbJ2gukxU',
#    'title': 'From Poverty to King of Bling | House of Dang Episode 1',
#    'keyword': 'Poverty',
#    'published_at': '2020-02-23T16:00:07Z',
#    'VideoViews': '3708451'},
#   {'channel': 'Vice',
#    'id': 'gt7HlHDmc_4',
#    'title': 'Stealing from the Rich: The Modern Day Robin Hood',
#    'keyword': 'Rich',
#    'published_at': '2019-10-25T21:00:07Z',
#    'VideoViews': '317824'}],
#  [{'channel': 'Vice',
#    'id': 'EEIvWNhuL8U',
#    'title': 'Anti & Pro Feminists Debate Abortion, Trans Rights, and #Metoo | VICE Debates',
#    'keyword': 'Abortion',
#    'published_at': '2022-12-28T16:00:11Z',
#    'VideoViews': '4040395'},
#   {'channel': 'Vice',
#    'id': 'xnS2CTmdA0A',
#    'title': 'Inside One of the Last Abortion Clinics in Alabama',
#    'keyword': 'Abortion',
#    'published_at': '2020-10-31T19:00:07Z',
#    'VideoViews': '1316074'},
#   {'channel': 'Vice',
#    'id': 'FHlI6Vjc0tI',
#    'title': 'What The Alabama Abortion Law Means for the Rest of the World | Let Lee Explain',
#    'keyword': 'Abortion',
#    'published_at': '2019-06-09T19:00:02Z',
#    'VideoViews': '118595'},
#   {'channel': 'Vice',
#    'id': '6S9oUu0R3sY',
#    'title': 'Backstreet Abortions in the Philippines: Year of Mercy',
#    'keyword': 'Abortion',
#    'published_at': '2016-03-01T10:00:01Z',
#    'VideoViews': '733971'},
#   {'channel': 'Vice',
#    'id': 'jUFOECOZ1fg',
#    'title': 'Daily VICE Canada: Planned Parenthood and Abortion Rights on The Campaign Trail in Colorado',
#    'keyword': 'Abortion',
#    'published_at': '2016-02-26T17:38:51Z',
#    'VideoViews': '3762'},
#   {'channel': 'Vice',
#    'id': 'GMdymyLNC1s',
#    'title': 'Daily VICE Canada: PEI Abortion Access, Classical Music Drugs, Kardinal Offishall',
#    'keyword': 'Abortion',
#    'published_at': '2016-01-06T15:59:29Z',
#    'VideoViews': '3825'},
#   {'channel': 'Vice',
#    'id': 'q2roLP6HIQA',
#    'title': 'Abortion Access in the Maritimes',
#    'keyword': 'Abortion',
#    'published_at': '2015-07-09T18:23:36Z',
#    'VideoViews': '275157'}],
#  [{'channel': 'Vice',
#    'id': 'Dkk1rMARYOY',
#    'title': 'Gen Z’s War on Climate Change | Vice Around the World Episode 24',
#    'keyword': 'Climate',
#    'published_at': '2021-01-02T20:00:05Z',
#    'VideoViews': '1087'},
#   {'channel': 'Vice',
#    'id': 'hxdwbZ3Oeyc',
#    'title': "A Marine's Advice on Tear Gas Attacks",
#    'keyword': 'Gas',
#    'published_at': '2020-07-25T15:00:11Z',
#    'VideoViews': '212726'},
#   {'channel': 'Vice',
#    'id': 'fU3C8o8I6GQ',
#    'title': 'Toxic Air Might be Mutating Human DNA\xa0+ 4 Other Horror Climate Stories',
#    'keyword': 'Climate',
#    'published_at': '2019-09-23T15:00:07Z',
#    'VideoViews': '360020'},
#   {'channel': 'Vice',
#    'id': 'tNwkY_V_BPI',
#    'title': 'Does Climate Change Really Mean the End of the World?  | Let Lee Explain',
#    'keyword': 'Climate',
#    'published_at': '2019-09-21T15:00:10Z',
#    'VideoViews': '183078'},
#   {'channel': 'Vice',
#    'id': 'PfbNY2G64G8',
#    'title': 'This Dude Destroys $35,000 Sneakers to Create Gas Masks',
#    'keyword': 'Gas',
#    'published_at': '2018-08-09T18:30:01Z',
#    'VideoViews': '1129027'},
#   {'channel': 'Vice',
#    'id': 'y20Tx2eCw28',
#    'title': "Assad's Syria & Cost of Climate Change (VICE on HBO: Season 5, Episode 1)",
#    'keyword': 'Climate',
#    'published_at': '2017-08-14T23:01:58Z',
#    'VideoViews': '552079'},
#   {'channel': 'Vice',
#    'id': 'gdhdAktIHtg',
#    'title': 'Inside The Laughing Gas Black Market | High Society',
#    'keyword': 'Gas',
#    'published_at': '2017-02-07T16:14:26Z',
#    'VideoViews': '6338088'},
#   {'channel': 'Vice',
#    'id': 'gXBR5ZrKdws',
#    'title': 'The Teenager Suing the US Government over Climate Change',
#    'keyword': 'Climate',
#    'published_at': '2016-04-22T15:52:18Z',
#    'VideoViews': '185676'},
#   {'channel': 'Vice',
#    'id': 'IT8XsE0If0g',
#    'title': "Daily VICE Canada: This Is Really Critical': Environmentalists Cheer U.S.-Canada Climate Deal",
#    'keyword': 'Climate',
#    'published_at': '2016-03-14T17:40:08Z',
#    'VideoViews': '5382'},
#   {'channel': 'Vice',
#    'id': '9Okkpmbdn_o',
#    'title': 'Daily VICE Canada: The Indigenous Basketball Team Taking a Stand Against a Natural Gas Pipeline',
#    'keyword': 'Gas',
#    'published_at': '2016-02-16T16:12:49Z',
#    'VideoViews': '4302'},
#   {'channel': 'Vice',
#    'id': 'RpJDwQSvXNs',
#    'title': 'Daily VICE Canada: Indigenous Climate Protesters, Quebec Grow-ops, Downtown Snowboarding',
#    'keyword': 'Climate',
#    'published_at': '2015-12-08T17:47:48Z',
#    'VideoViews': '2311'},
#   {'channel': 'Vice',
#    'id': 'TgVwCJ2J6pQ',
#    'title': 'Daily VICE Canada: Quebec Weed Industry, Skull Store, Climate Activist Arrest',
#    'keyword': 'Climate',
#    'published_at': '2015-12-07T17:31:48Z',
#    'VideoViews': '9128'}]]

# %%
# Get the video IDs of the relevant videos
vice_vid_ids = set()

# Extracting all ids
for sublist in vice_vid_info:
    for video in sublist:
        vice_vid_ids.add(video['id'])
        
len(vice_vid_ids)
# Out:
# 78

# %%
vice_vid_ids
# Out:
# {'-1A9v5bQDqk',
#  '07lsXkWmpz8',
#  '0rlaeRHgUCk',
#  '18_KBggvIZM',
#  '2RZoGOc3VCs',
#  '388wlVWxGz0',
#  '3JFihjEWU3c',
#  '4PfZlxhvdkM',
#  '4qePOEBm9Aw',
#  '5I2HA1MIeeo',
#  '5cm9ELLR8ds',
#  '61trVLZv1-w',
#  '6S9oUu0R3sY',
#  '7fJpRa7o_fQ',
#  '9Okkpmbdn_o',
#  'ARQJlzZ2qu8',
#  'D669qcb7GGI',
#  'Dkk1rMARYOY',
#  'EEIvWNhuL8U',
#  'EaPnv82Hs3g',
#  'FDYqe5I35KA',
#  'FHlI6Vjc0tI',
#  'GMdymyLNC1s',
#  'IT8XsE0If0g',
#  'Imj5EGZzrwg',
#  'Jj-3kBi49eg',
#  'Jp0nqJ1yrrg',
#  'KL8CIZej19o',
#  'Kae-nng77yE',
#  'LttCr8rudxQ',
#  'M4BOdBJFkgA',
#  'N9SR09eC_z0',
#  'PdJJxwP8NaU',
#  'PfbNY2G64G8',
#  'QX3M8Ka9vUA',
#  'RpJDwQSvXNs',
#  'SwoRx3tstxY',
#  'TgVwCJ2J6pQ',
#  'UnETVMI4tY8',
#  'V3KGKQd_4tk',
#  'X3ySrcI2mEA',
#  'XnpbVRg1-qc',
#  'Zh2e8nY8VJ0',
#  '_278oKkyf48',
#  '_kqiGAswtKE',
#  '_xO5dsGEL_E',
#  'cdZy4balvB8',
#  'd9K96fZGY64',
#  'dckjk1V-KRM',
#  'ee5JCDzPB0I',
#  'efSRjjzde54',
#  'egEbJ2gukxU',
#  'fD93qXcMwGA',
#  'fU3C8o8I6GQ',
#  'gXBR5ZrKdws',
#  'gXTeg5LAvN8',
#  'gdhdAktIHtg',
#  'gs26R56d3ww',
#  'gt7HlHDmc_4',
#  'hxdwbZ3Oeyc',
#  'hyk5YXnag9E',
#  'jUFOECOZ1fg',
#  'juAxCz5Vrxc',
#  'lFIro2Dnfj8',
#  'm54L1jusS5w',
#  'nogb7DboO64',
#  'pZH9ZYFU26U',
#  'q2roLP6HIQA',
#  'qX_aaRepdIM',
#  'qavbWjQpDhA',
#  'qoqds4LV9RI',
#  'tNwkY_V_BPI',
#  'uaDZ0bVresE',
#  'vaTnP5AgQ_g',
#  'xTnJgpF5LYg',
#  'xnS2CTmdA0A',
#  'y20Tx2eCw28',
#  'yF204b-Ngjk'}

# %%
# Get the top 30 relevant comments of each video
vice_comments = []

for ids in vice_vid_ids:
    vice_comm = get_vid_comments(ids, 30)
    vice_comments.append(vice_comm)
# Out:
# Comments are disabled for the video with videoId: EEIvWNhuL8U

# %%
vice_comments
# Out:
# [[{'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgyT8lzHq4KG18pbEAx4AaABAg',
#    'CommentTitle': 'A lot of businesses are struggling. The ones that aren’t struggling as much are banks and grocery stores.',
#    'CommentCreationTime': '2020-09-23T19:56:07Z',
#    'CommentLikes': 75},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgwWciuwhjWJtn5p2B54AaABAg',
#    'CommentTitle': 'Damn the World really sucks now.\nLooking forward to better days for everyone.',
#    'CommentCreationTime': '2020-09-23T20:42:39Z',
#    'CommentLikes': 89},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgxAbD9h5oBPSxaRgvN4AaABAg',
#    'CommentTitle': 'Sadly I think at least 50% of clubs, bars and restaurants worldwide will eventually go under. This with have a ripple effect in the supply chains and vendors who keep these businesses stocked with products as well.',
#    'CommentCreationTime': '2020-09-24T08:16:30Z',
#    'CommentLikes': 45},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'Ugx5ivt655zG1cctmVJ4AaABAg',
#    'CommentTitle': "I love Plant. It was one of the highlights to my trip to Korea. It's sad to see so many businesses suffer.",
#    'CommentCreationTime': '2020-09-27T21:20:05Z',
#    'CommentLikes': 4},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgztX1erPMN0W9t8tWZ4AaABAg',
#    'CommentTitle': '"AKA DJ Bowlcut" lmao 😂😅😅',
#    'CommentCreationTime': '2020-09-23T19:31:59Z',
#    'CommentLikes': 53},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgzNva2CkdiLdgwcf2V4AaABAg',
#    'CommentTitle': 'I was in Soputh Korea recently.  Beautiful, peaceful, amazing place.',
#    'CommentCreationTime': '2020-09-23T19:04:21Z',
#    'CommentLikes': 29},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgwRLgppH0gj3WEB7Pl4AaABAg',
#    'CommentTitle': 'I was in South Korea last year! Really enjoyed it and loved the party scene, really want to go back!',
#    'CommentCreationTime': '2020-09-24T03:26:08Z',
#    'CommentLikes': 58},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'Ugy_2Vxo48zxC8oU6q14AaABAg',
#    'CommentTitle': 'Damn that place was the spot to party people would come from all over to hit the bars and clubs',
#    'CommentCreationTime': '2020-09-23T19:15:19Z',
#    'CommentLikes': 58},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgxqXQ3YALM74Tch2gp4AaABAg',
#    'CommentTitle': "For those asking 'why only Korean nightclubs' this video originally aired on Vice Asia in August and was symbolic of the plight of a lot of nightlife places worldwide. Its a tragedy how govts are ignoring / declining to financially help an industry of such cultural importance",
#    'CommentCreationTime': '2020-09-24T03:08:28Z',
#    'CommentLikes': 43},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgyXco0zyRLf8Q7ibVN4AaABAg',
#    'CommentTitle': 'Damn. I was in Seoul last year, hope the world recovers quickly!!! 🇰🇷',
#    'CommentCreationTime': '2020-09-23T21:50:15Z',
#    'CommentLikes': 7},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'Ugyv2tlYNapJ2lkCPhZ4AaABAg',
#    'CommentTitle': 'I\'m not even vegan and now I wish I could go eat at "Plant" I hate seeing business suffer unfairly.',
#    'CommentCreationTime': '2020-09-24T20:38:55Z',
#    'CommentLikes': 11},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'Ugyv6mdcZ-H2q4V2d5p4AaABAg',
#    'CommentTitle': "Damn I always wanted to go there and explore this little area... Hopefully it's still there in a year or two smh... But honestly... From what I've always known about that area, it's not gonna be back to normal until tourist are able to go there in mass also...",
#    'CommentCreationTime': '2020-09-23T20:52:11Z',
#    'CommentLikes': 12},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'Ugw7-Ku6_gyr7EdJGUF4AaABAg',
#    'CommentTitle': 'They say you appreciate things more when you have to wait',
#    'CommentCreationTime': '2020-09-24T01:51:41Z',
#    'CommentLikes': 4},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgwPZOZPZKNrFRS9GMd4AaABAg',
#    'CommentTitle': 'Best experience I had in the army was exploring S Korea with my two friends just living life and experience live music the way it should be 🤟🏽',
#    'CommentCreationTime': '2020-09-25T06:06:20Z',
#    'CommentLikes': 3},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'Ugx9svib6uuVVU8PGGJ4AaABAg',
#    'CommentTitle': 'Great speech from all those youngsters',
#    'CommentCreationTime': '2020-09-24T14:19:06Z',
#    'CommentLikes': 1},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'Ugy4PySPlYIem6PIA7p4AaABAg',
#    'CommentTitle': "Yeah It's true that Every NightClub Businesses around the world have problems with COVID. but in korea,  things are going bit differently. It's not really the COVID but the Stigmatization towards to club culture itself makes it more difficult.",
#    'CommentCreationTime': '2020-09-24T11:02:31Z',
#    'CommentLikes': 2},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgwjWTe5N8iab6sMI1B4AaABAg',
#    'CommentTitle': "That's crazy!!! Looks like such an awesome spot! It's like there's a war on music and the nightlife going on worldwide!!",
#    'CommentCreationTime': '2020-09-23T21:04:27Z',
#    'CommentLikes': 7},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'Ugz1wOx3y5l1KBoEpKt4AaABAg',
#    'CommentTitle': 'great shots of itaewon at the beginning!',
#    'CommentCreationTime': '2020-09-23T19:29:49Z',
#    'CommentLikes': 5},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgxsN_1TZ2OuXtUPYWt4AaABAg',
#    'CommentTitle': "I've been to Itaewon Ro and it's an amazing place. South Korea is wonderful. \n\nHey Vice, how about a story on how the play on words and banning large gatherings isn't just a thing happening in the US to keep people from congregating? The pandemic guidelines are hypocratic and are ruining all societies, not just the US.",
#    'CommentCreationTime': '2020-09-29T17:49:09Z',
#    'CommentLikes': 3},
#   {'VideoId': 'qX_aaRepdIM',
#    'CommentId': 'UgxXC000p_VdHvNbwv14AaABAg',
#    'CommentTitle': 'Vice: proceeds to cluster the nightclub',
#    'CommentCreationTime': '2020-09-23T19:06:49Z',
#    'CommentLikes': 5}],
#  [{'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgxjoTVRr-NX_qmXWh94AaABAg',
#    'CommentTitle': 'Thank you for having us. Zeke we enjoyed time on the range with you and hope after all of this you will continue to train and enjoy more time on the range.',
#    'CommentCreationTime': '2021-11-29T02:20:11Z',
#    'CommentLikes': 592},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgzfR8B9fuIR3_wDwu54AaABAg',
#    'CommentTitle': '“I don’t know if I can bear the minimum responsibility required for gun ownership.” \nBoom. There it is. Firearms ownership is a perpetual exercise in personal responsibility. Every day, it’s in the back of your mind “hey, I have a gun,” and every day, you remind yourself that it is *your* charge. It isn’t for everybody, and that’s okay - what matters is that *you* know whether or not it’s something that you want.',
#    'CommentCreationTime': '2021-11-29T23:50:14Z',
#    'CommentLikes': 355},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgxjhIYbNk9myiN7wkB4AaABAg',
#    'CommentTitle': 'Hiring Zeke is the best thing VICE has ever done, if we start giving more neutral open-minded people like him a voice in media outlets we might actually slowly start coming together as a nation and I’m not over-exaggerating by saying that.',
#    'CommentCreationTime': '2021-11-28T21:30:13Z',
#    'CommentLikes': 681},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'Ugyvp96JoOFNcJqOxj14AaABAg',
#    'CommentTitle': 'I lived in NYC my whole life and guns were always frowned upon, and made me bias to seeing them as negative. When I moved to Atlanta, all my friends had legal guns. I went to the range and trained and I seen guns more as a tool than something negative. I gained respect for guns with education.',
#    'CommentCreationTime': '2021-12-01T18:07:25Z',
#    'CommentLikes': 196},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'Ugwe1vrW12p3M8sHOkJ4AaABAg',
#    'CommentTitle': 'Better than I thought it was going to be. I can tell vice at least tried to act like they were being objective.',
#    'CommentCreationTime': '2021-11-28T21:27:04Z',
#    'CommentLikes': 931},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgyTJEBCo_tLq_AQ4Wt4AaABAg',
#    'CommentTitle': 'THIS IS THE VICE we all love. Display the facts and let the reader come to their own conclusions. Throughly surprised',
#    'CommentCreationTime': '2021-11-29T02:02:03Z',
#    'CommentLikes': 243},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgwUFahkqugPzkusXPF4AaABAg',
#    'CommentTitle': 'finally, a gun episode that isnt cringe and stupid, NICE WORK',
#    'CommentCreationTime': '2021-11-28T17:26:35Z',
#    'CommentLikes': 671},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgxKfsnBJ5orjkyFjJN4AaABAg',
#    'CommentTitle': "As someone who worked at a hospital with a behavioral health unit and had to carry a fully loaded glock 17 with 2 spare mags, pepper spray, and handcuffs at all times on shift (the job requiring me to). Him saying mental health is the issues couldn't be more spot on mental health system in America is seriously broken and neglected. People especially nurses, doctors, hospital staff, and even the patients shouldnt feel the need or expect to have armed security looking after them while they save lives, help people, or receive treatment and it shouldnt be underfunded because your on section 8 or considered low income.",
#    'CommentCreationTime': '2021-11-28T21:09:50Z',
#    'CommentLikes': 184},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgyYqHx-2GJjrzRKYyt4AaABAg',
#    'CommentTitle': 'Armed Minorities Are Harder To Oppress. Self defense isn’t a crime remember that.',
#    'CommentCreationTime': '2021-11-28T18:21:31Z',
#    'CommentLikes': 58},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgzzkQQXfjWSGqZ_QOh4AaABAg',
#    'CommentTitle': 'His smile when he was dumping his mag in the mp5 was priceless.',
#    'CommentCreationTime': '2021-12-01T16:53:11Z',
#    'CommentLikes': 15},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgxiIA1PRkLBlGHaLUh4AaABAg',
#    'CommentTitle': 'You know Vice, as a gun owning, conservative guy… I give you props for not demonizing firearms or the firearms culture. Thanks for showing some of the many many safe, sane and responsible owners.',
#    'CommentCreationTime': '2021-11-28T21:15:08Z',
#    'CommentLikes': 103},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgwsWN8fPbq37CYV9fp4AaABAg',
#    'CommentTitle': 'I appreciate the take on the topic. Being a pro-gun liberal really pisses me off because people equate being liberal to hating guns. All Americans who are mentally fit should have access to firearms. That being said, mental health should be more addressed.',
#    'CommentCreationTime': '2021-11-28T17:26:19Z',
#    'CommentLikes': 294},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'Ugx9nYYM9QJvWoIh4zl4AaABAg',
#    'CommentTitle': 'My favorite part is where you brought up that 60+% of gun deaths are suicides… thank you for mentioning this as most people think guns are really the problem.',
#    'CommentCreationTime': '2021-12-08T07:48:29Z',
#    'CommentLikes': 142},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgwBitZj6M6pNYLqzF14AaABAg',
#    'CommentTitle': 'Wow…Just got done watching. A neutral gun piece on VICE. When Zeke reached out to me I was apprehensive to say the least. In fact I thought I was being punk\'d 😂 But many phone calls, texts and emails later and it became apparent Zeke was here to cover a subject, not lean it one way or another. His piece on "Doomsday Peppers" sealed the deal for me. So he and his very talented film crew flew down and we spent the entire day filming and shooting. I\'ll be putting together a video on my channel with some fun behind the scenes footage from that day.\xa0\n\nWhatever guns mean to you, good, bad, or indifferent; they are here to stay, just like our freedom of speech, freedom from unreasonable search and seizure, right to fair and speedy trial, right to due process of law, etc. The 2nd amendment protects THE PEOPLE. And I meant what I said about mental health reform. That\'s the topic we should be discussing. Don\'t let those in power (No Term Limit Career Politicians) strip your rights and power in the process by giving up our right to bear arms. It really is a simple as that. Zeke, if you see this comment, you\'re welcome back anytime. 🤙',
#    'CommentCreationTime': '2021-11-28T16:50:23Z',
#    'CommentLikes': 2145},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'Ugx0p91NzxyEkMiRrfJ4AaABAg',
#    'CommentTitle': "Black Gun Owners Association....good job representing Jacksonville and Duval.  I'm a lawyer and gun owner in Jacksonville and recognize OTS range.  You all did a great job.  A good piece overall from vice as well...surprisingly.",
#    'CommentCreationTime': '2021-12-05T06:40:24Z',
#    'CommentLikes': 74},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgxE1_GdjRRkyY-KYqx4AaABAg',
#    'CommentTitle': "Loved it! Can't lie I was totally expecting another 2A hit piece but this was a great open and honest documentary about gun culture and a call to understand the root causes of gun violence. Vice if you hire 100 more journalist that are as open and honest as him your organization would have a much better reputation.",
#    'CommentCreationTime': '2021-11-28T19:28:11Z',
#    'CommentLikes': 94},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgwMuRoDEyW3qvngw4t4AaABAg',
#    'CommentTitle': "Knowledge of firearms, practicing firearms safety and knowledge of state laws makes all the difference in the world. Vice I'm actually pleased that a knowledgeable, fun and neutral piece about firearms was produced. 💯",
#    'CommentCreationTime': '2021-11-28T17:00:43Z',
#    'CommentLikes': 208},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgxeiUc8W3f4n4nwVEF4AaABAg',
#    'CommentTitle': "I wanted to say actually thank you to Vice, Zeke and the two women that was part of this series.  You remained neutral showing all walks of life from culture to political that maintained the middle road on this topic.  I appreciate that very much.  When I first saw the title knowing Vice's history, I was very skeptical on whether this was going to be a smear fest.  Well done video and hope those that either was on the fence with firearms or completely against them have a bit of a better viewpoint on the matter.  If one person changed their mind to become a responsible gun owner, it is a win in my book.",
#    'CommentCreationTime': '2021-12-02T03:36:29Z',
#    'CommentLikes': 54},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgzfjLSH7FL9VgXTFfZ4AaABAg',
#    'CommentTitle': 'I appreciate the fair approach of this video.',
#    'CommentCreationTime': '2021-11-28T16:23:45Z',
#    'CommentLikes': 127},
#   {'VideoId': 'Jj-3kBi49eg',
#    'CommentId': 'UgzO-xNE_ryaQ4LCZ6p4AaABAg',
#    'CommentTitle': 'I remember been a huge lefty when it came to guns and laws. Then in college I got a part time job at a pawnshop. My boss heard my about my stance on guns. Rather than try to lecture me or change my mind with words, he took me to the shooting range that weekend. After my first shot, I was hooked.',
#    'CommentCreationTime': '2022-01-10T07:16:49Z',
#    'CommentLikes': 5}],
#  [{'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgzuFeIs-MRBJWmHiIJ4AaABAg',
#    'CommentTitle': "It's  like k2 or spice. Very similar to bath salts.",
#    'CommentCreationTime': '2023-06-26T02:48:45Z',
#    'CommentLikes': 20},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgydrrxPljdkmXJu0Sd4AaABAg',
#    'CommentTitle': 'Wow, that told us absolutely nothing.',
#    'CommentCreationTime': '2023-05-03T15:18:06Z',
#    'CommentLikes': 38},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgyP5RiE0g4y_Mei7tZ4AaABAg',
#    'CommentTitle': 'When you’re selling it and don’t know what’s in it yourself you should stop.',
#    'CommentCreationTime': '2023-07-23T06:31:01Z',
#    'CommentLikes': 6},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgyhTPlKBimSBTHEBnR4AaABAg',
#    'CommentTitle': 'Put the subtitles higher please!',
#    'CommentCreationTime': '2023-11-01T23:53:38Z',
#    'CommentLikes': 3},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgywWBucNNMQ8j4_g1d4AaABAg',
#    'CommentTitle': 'Liquid mdma.',
#    'CommentCreationTime': '2023-05-08T03:01:43Z',
#    'CommentLikes': 8},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgxdKIBoGavd_0QLVA54AaABAg',
#    'CommentTitle': 'It’s rat poison',
#    'CommentCreationTime': '2023-05-30T11:51:42Z',
#    'CommentLikes': 2},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgzA0caLkXksANmUaB94AaABAg',
#    'CommentTitle': 'DNG DNG DNG DNG',
#    'CommentCreationTime': '2023-05-03T21:21:52Z',
#    'CommentLikes': 6},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgxbJ2tYTeyUjLRTYpp4AaABAg',
#    'CommentTitle': 'Have a good day vice. Should’ve left Top G alone lol',
#    'CommentCreationTime': '2023-05-05T16:31:05Z',
#    'CommentLikes': 24},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgzOM4IqB-aI4g9VDzp4AaABAg',
#    'CommentTitle': 'To compare MS-13 the the Mexican drug cartels is a joke and shows where Vice is at anymore these days',
#    'CommentCreationTime': '2023-05-04T06:17:56Z',
#    'CommentLikes': 8},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'Ugx4Iix0QnXVYBkZEOt4AaABAg',
#    'CommentTitle': 'DNG',
#    'CommentCreationTime': '2023-05-05T20:11:57Z',
#    'CommentLikes': 2},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgwnLNRDV2Q7-DdDa3J4AaABAg',
#    'CommentTitle': 'maybe they are just smoking rat poison. they dont know 😂',
#    'CommentCreationTime': '2024-02-25T19:35:32Z',
#    'CommentLikes': 0},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'Ugx__YItfgm65yBZYBl4AaABAg',
#    'CommentTitle': '🔥 Amiguita..!!! Vaye buscando trabajo...Vice esta en Bancarota.',
#    'CommentCreationTime': '2023-05-09T03:55:58Z',
#    'CommentLikes': 1},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgwBvG1mpbMdEYX22Ll4AaABAg',
#    'CommentTitle': 'Top G',
#    'CommentCreationTime': '2023-05-04T12:10:14Z',
#    'CommentLikes': 7},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgwAFEb5BGOWW_XE7ph4AaABAg',
#    'CommentTitle': 'Love the videos from vice',
#    'CommentCreationTime': '2023-05-03T15:03:50Z',
#    'CommentLikes': 5},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'Ugx7jD6K61xMAmx_tzp4AaABAg',
#    'CommentTitle': "Ha ! It's over for this CIA operation. \n\n#bankruptcy",
#    'CommentCreationTime': '2023-05-03T21:50:48Z',
#    'CommentLikes': 8},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'Ugwk9FuGAoFdY6Q3dn54AaABAg',
#    'CommentTitle': "Don't think. Just do. Have a great rest of your week!",
#    'CommentCreationTime': '2023-05-03T15:22:31Z',
#    'CommentLikes': 1},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgyPi82LQv8zk1UO-vV4AaABAg',
#    'CommentTitle': 'sad',
#    'CommentCreationTime': '2023-11-01T14:59:15Z',
#    'CommentLikes': 0},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgwDbdViNv6Ukvdjgk14AaABAg',
#    'CommentTitle': '#topG',
#    'CommentCreationTime': '2023-05-04T16:35:39Z',
#    'CommentLikes': 6},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgwSAkO28KgmNmFxgQx4AaABAg',
#    'CommentTitle': 'Hello satan',
#    'CommentCreationTime': '2023-05-24T05:54:49Z',
#    'CommentLikes': 0},
#   {'VideoId': 'nogb7DboO64',
#    'CommentId': 'UgyaYIF7ngFN3jwraap4AaABAg',
#    'CommentTitle': 'Heard y’all are going bankrupt. That’s what you get for pushing all those agendas',
#    'CommentCreationTime': '2023-05-03T16:59:31Z',
#    'CommentLikes': 20}],
#  [{'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgzXTfheK3dlxhPweph4AaABAg',
#    'CommentTitle': 'This dude is brilliant you should take him in as a journalist to document the epidemic of homelessness around the world',
#    'CommentCreationTime': '2020-06-22T20:45:40Z',
#    'CommentLikes': 883},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgzNEnIQFDiOliKlOyh4AaABAg',
#    'CommentTitle': "I live in the US and work in emergency psychiatric care primarily with homeless people. It's always hard to find treatment, housing, food, work for them. But this year has been a nightmare. Even the homeless shelters are turning people away. Rehabs are closed to new patients, most places aren't hiring (especially places that employ felons), offices where you get your ID and apply for SSDI are online-only which doesn't help people who don't have a phone. This year has sucked for everyone, and a lot of people have lost their jobs and are scared of what the future will bring. But if you have a safe place to sleep every night, if you have food in your fridge, be grateful. Many people are one bad car accident away from losing their livelihood and their home. If you know where you are going to sleep tonight and if you know that you will have a meal tomorrow, you are okay. Many are not.",
#    'CommentCreationTime': '2020-07-08T04:00:17Z',
#    'CommentLikes': 175},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgzlMkGfHiJGZzSZFHd4AaABAg',
#    'CommentTitle': 'And here people whining about how they have to stay at home! And their life is ruined bcos they cannot go party and club!',
#    'CommentCreationTime': '2020-07-07T21:26:56Z',
#    'CommentLikes': 353},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgxmWHqQzT6els2yg414AaABAg',
#    'CommentTitle': "A very special old farmer saved me from homelessness...and I'll never be able to thank him as much as he deserves.  I grew up in the woods...I spent most of my time homeless in the same place...was near the river, was able to bath in it...had this little Coleman solar panel to charge my phone...my bike, tent...it wasn't all bad, at first.  But it got worse...much worse...I dropped so much weight I was at an all time low of 106 pounds.  But starting when the old farmer took me in...I've since got some medical help, and approved for disability...gained all my weight back...life is getting better, slowly but surely.  I am hoping soon I might be well enough to be able to work again.  I want to be able to give back...like all the people who helped me.",
#    'CommentCreationTime': '2020-06-22T19:12:10Z',
#    'CommentLikes': 253},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgxiWj6-Zi_RTEFSD7d4AaABAg',
#    'CommentTitle': "I've been homeless and no one can imagine the hunger and I thirst. Not to mention just wanting to brush your teeth.  Bless everyone who helps the homeless. You can't imagine their struggles",
#    'CommentCreationTime': '2020-07-04T23:35:55Z',
#    'CommentLikes': 105},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgyqxqWrRo2qwLAhWkJ4AaABAg',
#    'CommentTitle': "Bless these people man. I can't even begin to know what this is like. This is crazy eye opening.",
#    'CommentCreationTime': '2020-06-22T19:35:07Z',
#    'CommentLikes': 773},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'Ugxuwajh0RcAHwUJfBB4AaABAg',
#    'CommentTitle': 'Such an articulate, well spoken man; really makes awful thing he was put in such a situation.',
#    'CommentCreationTime': '2020-06-22T20:15:00Z',
#    'CommentLikes': 428},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgzUhjKCWlV5i5ADGrl4AaABAg',
#    'CommentTitle': 'VICE! Provide links to his film so people can buy it, please!',
#    'CommentCreationTime': '2020-06-22T19:09:46Z',
#    'CommentLikes': 660},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'Ugyj5pL1FUiLP2TFeqN4AaABAg',
#    'CommentTitle': 'God Bless his heart and Protects him and all homeless people. Let’s society help out because it can be any of us . You never know.',
#    'CommentCreationTime': '2020-06-22T21:28:03Z',
#    'CommentLikes': 481},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgzPneo5LlB87FEGxD54AaABAg',
#    'CommentTitle': 'Homelessness changes a person forever. I am grateful for my time on the street.',
#    'CommentCreationTime': '2020-06-26T07:41:59Z',
#    'CommentLikes': 30},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'Ugw8wLtZh1N_q_Qi3hp4AaABAg',
#    'CommentTitle': 'God Bless him...our homeless and elderly the most vulnerable..',
#    'CommentCreationTime': '2020-06-22T19:09:55Z',
#    'CommentLikes': 330},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgxHkTlhZrU8nqaPMiJ4AaABAg',
#    'CommentTitle': 'Just to be able to comment on this video from the comfort of home \nIs a blessing. Sometimes all take certain things for granted ✌🏿',
#    'CommentCreationTime': '2020-06-22T19:45:45Z',
#    'CommentLikes': 126},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'Ugy38NxdA3TxA9zopCF4AaABAg',
#    'CommentTitle': 'Prayers to all those effected by homelessness... That could easily be any of us',
#    'CommentCreationTime': '2020-07-12T02:32:49Z',
#    'CommentLikes': 26},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgzMRIAGhe_w1H8ew994AaABAg',
#    'CommentTitle': 'this moment i love my parents for all they gave to me.',
#    'CommentCreationTime': '2020-06-23T01:03:56Z',
#    'CommentLikes': 57},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'Ugyzxat0U4rolr8lMq54AaABAg',
#    'CommentTitle': 'I did almost 18 months being homeless in Boston MA.USA And finally got myself in a studio apartment.i have health problems so I understand what you mean about being sick on the street is bad very very bad. God bless us all we are all gods children.',
#    'CommentCreationTime': '2020-07-16T17:13:55Z',
#    'CommentLikes': 22},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgwjjUH2vmwU2lRrRSh4AaABAg',
#    'CommentTitle': 'Your honesty, and humbleness will take you places.  I hope you will find your place in society again.  We all have our struggles, some more , or less than others.  I do hope all works out well for you and all the homeless people in our world.',
#    'CommentCreationTime': '2020-06-22T19:44:39Z',
#    'CommentLikes': 33},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'Ugxc1ToHBK9HPfs6twZ4AaABAg',
#    'CommentTitle': 'Thank you so much for sharing with such clarity and honesty',
#    'CommentCreationTime': '2020-06-22T19:04:49Z',
#    'CommentLikes': 84},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgzNLjM3fJC8vOPoNap4AaABAg',
#    'CommentTitle': '*An imbalance between rich and poor is the oldest and most fatal ailment of all republics.*\nPlutarch 💔😢',
#    'CommentCreationTime': '2020-06-22T20:33:43Z',
#    'CommentLikes': 140},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgzWovkWCcuL8oy_YCx4AaABAg',
#    'CommentTitle': 'Thank you Vice and David for availing yourselves to share regarding the struggles we often take for granted. As a Malaysian, and in my early naiveness, I had the impression that the city (ex. Kuala Lumpur) would be the place where dreams were made, an environment where zero poverty and homelessness exist. Little did I know that there were countless homeless people especially in the heart of the city who will be gathering there to find shelter in the late nights when the major public has gone to sleep peacefully at home.\nI thank God for all the non profits and social entrepreneurs that are doing all they can in supporting those in need especially during seasons of social distancing. I hope all of us including myself will continue to do what we can to also help out with our talents, skills, times, etc in different shapes and forms. Stay M.A.D. (making a difference) and God Bless. all the way.',
#    'CommentCreationTime': '2020-06-24T13:45:28Z',
#    'CommentLikes': 2},
#   {'VideoId': 'D669qcb7GGI',
#    'CommentId': 'UgytLi9_CGRjUR3UyMJ4AaABAg',
#    'CommentTitle': "I am jobless but I still have a roof over my head and my heart goes out to the homeless out there. Society as a whole has definitely failed us. I will do my best to help out and donate whatever savings I have to the right people and make sure I can make a small change. God bless everyone that is suffering out there. Hang in there and don't lose hope.",
#    'CommentCreationTime': '2020-07-24T13:23:22Z',
#    'CommentLikes': 8}],
#  [{'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgyTb7DP3pQwGvj-2rl4AaABAg',
#    'CommentTitle': 'WATCH NEXT: Narco-Propaganda is Fuelling Mexico’s Drug War - https://youtu.be/pZH9ZYFU26U',
#    'CommentCreationTime': '2023-03-30T06:34:23Z',
#    'CommentLikes': 19},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgxyYXNmLta3Liv8ofV4AaABAg',
#    'CommentTitle': 'You know its gonna be interesting when you have to click confirm THREE times',
#    'CommentCreationTime': '2021-06-05T07:55:02Z',
#    'CommentLikes': 10426},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgzRhflnqd9tVA3vFNV4AaABAg',
#    'CommentTitle': 'Living in Texas our neighbors were arrested for money laundering and cartel activities.... Honestly they were the nicest  neighbors you could ask for. Total shocker when they were arrested',
#    'CommentCreationTime': '2021-06-19T08:30:12Z',
#    'CommentLikes': 4552},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgzLQwIZV0YhWdZZTEx4AaABAg',
#    'CommentTitle': 'My brother was murdered in Mexico 2 years ago by the cartel. My family doesn’t know exactly what happened, and corrupt police has stopped my us from finding out.\nJust knowing that all of this is happening in such a beautiful country hurts so much. It makes me lose a little more hope in humanity.',
#    'CommentCreationTime': '2021-06-11T05:54:12Z',
#    'CommentLikes': 1546},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgwLPWepzzIvpeAgyBF4AaABAg',
#    'CommentTitle': 'I knew this would be about Los Zetas, trained by US special forces to combat cartels, who ended up becoming their own cartel lol',
#    'CommentCreationTime': '2021-05-31T19:42:22Z',
#    'CommentLikes': 3558},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'Ugy1DLxtpKiS6u6KMdJ4AaABAg',
#    'CommentTitle': 'A family member of mine was taken from the cartels. It’s shatters me to know that this is a real problem that can affect people rlly bad . It hurts to know that he might never come back',
#    'CommentCreationTime': '2021-11-18T00:51:48Z',
#    'CommentLikes': 293},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'Ugyuqa9LdM-CvpgX50F4AaABAg',
#    'CommentTitle': "The trauma that can come from seeing headless/dismembered/tortured/hanging victims is horrific.\nA walk around the neighborhood would be awful, knowing it's only a matter of time before you see more brutality. \nI feel for all affected.",
#    'CommentCreationTime': '2021-06-06T12:15:35Z',
#    'CommentLikes': 4282},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'Ugwy9qhcEIPyl5qj8lZ4AaABAg',
#    'CommentTitle': "Imagine walking outside your house and seeing decapitated human heads on the street.... I take it for granted, but thank goodness my family and I are from and live in  a country where our main issue is trying to decide what cuisine we're having for dinner.",
#    'CommentCreationTime': '2021-06-01T00:35:18Z',
#    'CommentLikes': 2391},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgyfnERwoisXkr5zBPd4AaABAg',
#    'CommentTitle': 'Growing up in Mexico every summer I remember how we could go on bike rides at night throughout the streets. How we could have family reunions at the family ranches. How we could walk to the store down the street. I remember when my mom would tell me to stop doing that. I could never understand why and what was happening. I couldn’t go to Mexico anymore, and it broke my heart. After watching this video, it’s heartbreaking to see that this is what Mexico is. I’m terrified to go down there even though my grandparents only live one hour away from the border.',
#    'CommentCreationTime': '2021-06-05T17:00:45Z',
#    'CommentLikes': 1672},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'Ugyw7Eks72CFt6DRzrZ4AaABAg',
#    'CommentTitle': 'Prayers go out to the innocent people/families who get caught up in this violence.',
#    'CommentCreationTime': '2021-09-03T05:54:16Z',
#    'CommentLikes': 449},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgwTKRd46ojEben9dNR4AaABAg',
#    'CommentTitle': 'I always wanted to know how other Mexican people thinks about this, I work construction with some, asked a guy “if you miss Mexico?” He said “no, they’ll kill me there” his face looked sad and traumatized, to love your people, but at the same time be scared of them must be so damn tough.',
#    'CommentCreationTime': '2021-07-17T03:29:03Z',
#    'CommentLikes': 403},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgwO6F3adSylfVQWzP94AaABAg',
#    'CommentTitle': 'Two of my  cousins from Mexico were shot to death by drug  cartels. \nIn  2016. &  2017 \nRip to my cousins \nGone but not forgotten. \nViolence has played my family for years\nAlways try to live a  normal as possible\nPeace to everyone 🙏',
#    'CommentCreationTime': '2023-10-28T03:58:49Z',
#    'CommentLikes': 9},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgxIcI3vfzf-Y0q4Rt94AaABAg',
#    'CommentTitle': 'Wow was a bit hesitant to watch this till I saw something YouTube’s never done before, they warned me twice before I could hit play. So now I’m here 🤣',
#    'CommentCreationTime': '2021-05-31T19:31:51Z',
#    'CommentLikes': 2706},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'Ugy9xPsJu6VslJBt4px4AaABAg',
#    'CommentTitle': 'I remember hearing many stories growing up in MX about Zetas eating their rivalries turning them into meals, cutting them up alive, thrown into acid barrels, feeding humans to dogs, and so on.. their way of torture is beyond horrifying that we can’t even imagine',
#    'CommentCreationTime': '2021-05-31T21:50:15Z',
#    'CommentLikes': 800},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgwfEan2MMR75l_pY6l4AaABAg',
#    'CommentTitle': "I lived in Monterrey, Mexico for 10 years.\nAlmost being heavily trafficked thru the Zetas.\n\nIt's not a joke. Please be safe. Keep your head up and watch your back",
#    'CommentCreationTime': '2021-05-31T19:18:56Z',
#    'CommentLikes': 957},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgxU2Zv5R1BPur3u9h14AaABAg',
#    'CommentTitle': 'I’m half Mexican and remember how we would go to Mexico in early 2000’s we could drive the whole 17 hours calmly and would stop to eat. We would stay late until 11pm at night, would chill outside the house, but ever since the cartels took over I haven’t been in Mexico ever since. I really hope the Mexican government take this serious and put an end to cartels.',
#    'CommentCreationTime': '2022-09-19T07:50:53Z',
#    'CommentLikes': 28},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'Ugxu9g7ZvU722RzFcy94AaABAg',
#    'CommentTitle': '"We\'d like to congratulate drugs for winning the war on drugs." Touché.',
#    'CommentCreationTime': '2021-06-27T05:02:51Z',
#    'CommentLikes': 353},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgxfBPQm0vm4XkAkLl94AaABAg',
#    'CommentTitle': 'As someone from Belize its really sad to see all the problems facing our northern neighbor i pray for all the innocent people of Mexico.',
#    'CommentCreationTime': '2021-09-26T08:18:34Z',
#    'CommentLikes': 114},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgzgUvyW0qFTmJJkhTx4AaABAg',
#    'CommentTitle': "Everytime you do coke or any other drug trafficked by Mexicans remember what is going on in Mexico and it's people. People in first world countries also need to do more aware of what is happening. Not saying it's entirely their fault but I think everyone should be more aware",
#    'CommentCreationTime': '2021-06-21T13:01:11Z',
#    'CommentLikes': 1419},
#   {'VideoId': '5cm9ELLR8ds',
#    'CommentId': 'UgzN4a6aFcQfiMntbiF4AaABAg',
#    'CommentTitle': 'This is why my family doesn’t want to go back to even visit. I live in the US and was born here, so I feel kind of detached from my roots. Not going back and visiting my roots makes me feel empty sometimes, like something is missing. But I understand why my mom doesn’t want us to go.',
#    'CommentCreationTime': '2021-05-31T22:13:13Z',
#    'CommentLikes': 668}],
#  [{'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgzcYEJ8MWYOzpvuyL94AaABAg',
#    'CommentTitle': "Hey, Vice. I'm just curious, what is your standard for turning off comments on some videos but leaving them on for others?",
#    'CommentCreationTime': '2023-01-10T02:53:27Z',
#    'CommentLikes': 1259},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgwOfQSrlpbAuJwiE1h4AaABAg',
#    'CommentTitle': "Good to see the comments haven't let Vice off the hook for shutting down their comments either. Because they shouldn't be. It means you're wrong and or lying when you have to literally silence discussion. Which you also did ironically for the last feminist discussion....How hilarious is that? Let's talk about wahmens. But ONLY these specific 3 women (2 trans), and NO ONE ELSE IS ALLOWED TO TALK PERIOD!!!",
#    'CommentCreationTime': '2023-01-10T14:08:02Z',
#    'CommentLikes': 487},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgwLZTsamgHS-cdwbJ14AaABAg',
#    'CommentTitle': "I'm truly doubting vice and believing there is an agenda to EVERYTHING they make a video about.",
#    'CommentCreationTime': '2023-01-11T19:49:45Z',
#    'CommentLikes': 226},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgzISD8xxj4ztPg8K3N4AaABAg',
#    'CommentTitle': 'Vice turned off the comments on the Tate Brothers documentary yet they leave comments open about crimes in South Africa. Vice is a joke shame!',
#    'CommentCreationTime': '2023-01-10T08:59:45Z',
#    'CommentLikes': 559},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'Ugx0NMfKrmsL6b5vgYh4AaABAg',
#    'CommentTitle': 'You took a gigantic L with Andrew Tate. Dont think people will forget.',
#    'CommentCreationTime': '2023-01-10T10:46:26Z',
#    'CommentLikes': 424},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgzvNupGB3vkm1qMO3d4AaABAg',
#    'CommentTitle': 'When you turn comments off it shows an admission of guilt and that you don’t want to face the backlash for your actions. Vile is what vice is.',
#    'CommentCreationTime': '2023-01-11T15:03:47Z',
#    'CommentLikes': 171},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgzoiyXCr4uIFNf7eKB4AaABAg',
#    'CommentTitle': 'These days, Everyone is corrupt. Including VICE themselves, uploading content, then taking it down and being silent and scared when asked about it smh😂',
#    'CommentCreationTime': '2023-01-09T22:29:47Z',
#    'CommentLikes': 81},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgzioRawskZSDk6772l4AaABAg',
#    'CommentTitle': 'We demand an explanation on how you did the Tate brothers dirty',
#    'CommentCreationTime': '2023-01-11T01:15:41Z',
#    'CommentLikes': 291},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgwYTBapudxyemKYckd4AaABAg',
#    'CommentTitle': "This is why when you come to SA the first thing you notice are the walls. Every house in every neighborhood has 2 meter walls with layers of spikes + electric fencing + armed contracted private security. It's so bad that there are 100,000 police for 60 million people. We've had to outsource community protection to private security. There are over 1 million private security in SA.",
#    'CommentCreationTime': '2023-01-09T20:22:01Z',
#    'CommentLikes': 199},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'Ugx6b69JXZh4gQbXF294AaABAg',
#    'CommentTitle': 'For those whose wondering they have nearly 60k dislikes on the Tate video',
#    'CommentCreationTime': '2023-01-09T22:59:28Z',
#    'CommentLikes': 142},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgzRcltiarAnQ-yXy9l4AaABAg',
#    'CommentTitle': '"Police are generally consider to be the most corrupt public institute in just about in any country." He is right.',
#    'CommentCreationTime': '2023-05-10T01:05:01Z',
#    'CommentLikes': 11},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'Ugw6-RweKeuta9KeLgt4AaABAg',
#    'CommentTitle': 'I find it fascinating that the comments are turned on with this video. But your last video you disabled the comments. Its almost as if you guys are here to shape a narrative and not promote a discussion.',
#    'CommentCreationTime': '2023-01-10T05:56:29Z',
#    'CommentLikes': 27},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'Ugxke48XUM_DkcxYTL14AaABAg',
#    'CommentTitle': 'No ones guilty until proven guilty. I like how comments are turned off on the Tate videos bc they know no one believes a thing they say since they’re fr wrong about him y’all will see when he’s released that dude acting like Tates brother to do a vice interview was all for nothing, it’s gonna do the opposite of benefit y’all when he beats the “case”. All this about Tate when there’s still no evidence out yet',
#    'CommentCreationTime': '2023-01-09T21:01:22Z',
#    'CommentLikes': 187},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'Ugyz0t4th0gwj5WYsy54AaABAg',
#    'CommentTitle': "Why can I comment on this and not the Tate video? It seems wrong for such a huge media channel to share allegations like that when it COULD be complete rubbish. (Granted, it might not) But It's not Vice's job to decide who deserves to have their life ruined or not. At least have the decency or guts to let people comment. It looks like a clear attempt to silence someone for having opinions that go directly against this progressive narrative.",
#    'CommentCreationTime': '2023-01-09T22:19:34Z',
#    'CommentLikes': 270},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgwhNUZTX1VIe3ke35d4AaABAg',
#    'CommentTitle': 'Here in Brazil we see this happening a lot due the corruption and a lack of efficient laws to punish crimes. Basically, with a good lawyer, anyone can get off of any charges, and the worst, still misdoing in the process. Such a shame.',
#    'CommentCreationTime': '2023-01-17T02:52:02Z',
#    'CommentLikes': 13},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'Ugyygzq--KP6Q1q67KN4AaABAg',
#    'CommentTitle': 'Man how was Vice such a great channel when it came out and then became a propaganda machine for a freaking decade',
#    'CommentCreationTime': '2023-01-10T19:36:48Z',
#    'CommentLikes': 282},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgwkU_L4t-pYVjoQU5d4AaABAg',
#    'CommentTitle': "It's funny how Vice think that they can get away with turning off comments and expect people not to comment on the next one. Turning off comments just shows how insecure they were with their previous video.",
#    'CommentCreationTime': '2023-01-13T19:04:57Z',
#    'CommentLikes': 72},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgwdWa4w9N8GLSbIg9R4AaABAg',
#    'CommentTitle': 'Vice is pathetic.  TOP G!!!!',
#    'CommentCreationTime': '2023-01-10T02:19:44Z',
#    'CommentLikes': 121},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgzIW28nT-mGtXf5JlJ4AaABAg',
#    'CommentTitle': 'Turn on the comment section on the Andrew Tate video...VICE will go down for this!!!😖😖',
#    'CommentCreationTime': '2023-01-09T21:28:36Z',
#    'CommentLikes': 64},
#   {'VideoId': '61trVLZv1-w',
#    'CommentId': 'UgxZILYJg7mMQvZOD3N4AaABAg',
#    'CommentTitle': 'I visited SA right before the pandemic started, it’s seriously one of the most beautiful countries I’ve ever been to. The safety risk is real, there is security everywhere and the divide between the haves and have nots is ever present.',
#    'CommentCreationTime': '2023-01-10T00:15:30Z',
#    'CommentLikes': 77}],
#  [{'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'Ugw9WDM_k-NHJ4WgVmR4AaABAg',
#    'CommentTitle': 'Five stories of human stupidity messing up our planet. \n\nFind each segment at the below time codes: \n00:36 - Swimming in Shit [BARCELONA, SPAIN]\n03:15 - MDMA Killing Trees [BRABANT, NETHERLANDS]\n06:31 - Human DNA Changing Due to Air Pollution [KRAKOW, POLAND]\n09:05 - Wall of Shit Wet Wipes [LONDON, UK]\n11:19 - Forests on Fire [MACAO, PORTUGAL]\n\nWatch more VICE docs on climate change and environmental impact: https://www.youtube.com/watch?v=oCVQdr9QFwY&list=PLDbSvEZka6GEIy8PES4UWtX7JwuYHKdJZ',
#    'CommentCreationTime': '2019-09-23T15:05:38Z',
#    'CommentLikes': 150},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'Ugz-VjFBEXCcyu5WnBJ4AaABAg',
#    'CommentTitle': 'This is very sad. Everyday I clean my beach ( my beach is the beach near my house) every single day I fill three 100-liter plastic waste bags and see how little difference I make.',
#    'CommentCreationTime': '2019-09-28T05:48:38Z',
#    'CommentLikes': 241},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgzUaDT4N9K4mQ9KZD54AaABAg',
#    'CommentTitle': 'Great journalism. And I love that each reporter could speak the native tongue of each country. Keep it up Vice!',
#    'CommentCreationTime': '2019-09-23T15:32:32Z',
#    'CommentLikes': 71},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgwJj5HAdFxVrRojeDB4AaABAg',
#    'CommentTitle': 'If MDMA was produced legally, there would be regulations on how to dispose the waste... just sayin...',
#    'CommentCreationTime': '2019-09-23T16:46:01Z',
#    'CommentLikes': 805},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgwojsYUYGCIuAUbsWR4AaABAg',
#    'CommentTitle': 'the Krakow kindergarten lady seems like the nicest person ever <3',
#    'CommentCreationTime': '2019-10-04T19:21:11Z',
#    'CommentLikes': 6},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgyEALLJgSOl8slNQVt4AaABAg',
#    'CommentTitle': 'Mother nature is going to have the last laugh....',
#    'CommentCreationTime': '2019-09-23T15:06:37Z',
#    'CommentLikes': 354},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgwMLP_Pv-bv8nwjdzl4AaABAg',
#    'CommentTitle': 'Another reason to decriminalise, legalise and regulate drug production and sale.',
#    'CommentCreationTime': '2019-09-23T15:09:13Z',
#    'CommentLikes': 619},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgwZKSCMpo342gF_w9p4AaABAg',
#    'CommentTitle': 'Humans are a trip. We consider ourselves so smart yet we’re the only animal dumb enough to actively kill the planet, still we’re smart enough to reverse this and keep not only us but life itself alive.',
#    'CommentCreationTime': '2019-09-23T15:13:04Z',
#    'CommentLikes': 186},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgyZUebx4sYEGJe1zeh4AaABAg',
#    'CommentTitle': 'Thank you Vice for bringing attention and coverage to these issues !!!!',
#    'CommentCreationTime': '2019-09-23T16:05:11Z',
#    'CommentLikes': 0},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'Ugy1GFs_RgaEPacsgaJ4AaABAg',
#    'CommentTitle': 'vice: drugs are fun and good. Also vice: dont do drugs it ruins the environment',
#    'CommentCreationTime': '2019-09-26T11:32:22Z',
#    'CommentLikes': 174},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgxNTGUY3_XpkU9Rz_t4AaABAg',
#    'CommentTitle': 'thank you so much Vice for this great video! you guys deserve an award',
#    'CommentCreationTime': '2019-09-30T21:26:32Z',
#    'CommentLikes': 0},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgyH_dKdM77fnlwgV8Z4AaABAg',
#    'CommentTitle': '"Welcome to extinction update" \n\nim dead',
#    'CommentCreationTime': '2019-09-23T22:17:55Z',
#    'CommentLikes': 60},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'Ugwsf-a_C7V7yb2qpsh4AaABAg',
#    'CommentTitle': '“Stop throwing condoms in the toilet” how about stop running the sewers to the ocean.',
#    'CommentCreationTime': '2019-09-30T05:19:31Z',
#    'CommentLikes': 461},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgyEww8IKxKdUp3wiBl4AaABAg',
#    'CommentTitle': "I love the Vice channel. They don't mince words and they tell it like it is. This video is a real eye opener.",
#    'CommentCreationTime': '2019-09-23T19:26:00Z',
#    'CommentLikes': 0},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgzN-4mAMZCiamwb5rl4AaABAg',
#    'CommentTitle': 'Awesome format ! :DDD keep it up please',
#    'CommentCreationTime': '2019-09-23T15:21:41Z',
#    'CommentLikes': 0},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgyjKhYyNFPV4WDRAcB4AaABAg',
#    'CommentTitle': 'Should say: the prohibition of drugs is killing trees...',
#    'CommentCreationTime': '2019-09-23T15:43:51Z',
#    'CommentLikes': 424},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'Ugy0tR6zt_77HfDfgER4AaABAg',
#    'CommentTitle': 'Please do more "Extinction Update" episodes! 👏 👏 👏 👏 👏',
#    'CommentCreationTime': '2019-10-07T16:46:49Z',
#    'CommentLikes': 0},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgxPKzmTL9_p3dhCiwh4AaABAg',
#    'CommentTitle': '"If this Condom was disposed of properly it would of been incinerated " and went from being trash in the ocean to air pollution.....PLEBS.',
#    'CommentCreationTime': '2019-09-24T10:09:52Z',
#    'CommentLikes': 22},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'UgygJ3g8aHR3Coozes14AaABAg',
#    'CommentTitle': '*"It\'s like a wild west of wet wipes"*',
#    'CommentCreationTime': '2019-09-25T22:44:17Z',
#    'CommentLikes': 18},
#   {'VideoId': 'fU3C8o8I6GQ',
#    'CommentId': 'Ugx67yG7m0RseIz5PPB4AaABAg',
#    'CommentTitle': 'This needs to be viral quick.',
#    'CommentCreationTime': '2019-10-05T12:55:25Z',
#    'CommentLikes': 0}],
#  [{'VideoId': 'V3KGKQd_4tk',
#    'CommentId': 'UgwVa75-c4A3jpVCedl4AaABAg',
# ...
#    'CommentId': 'Ugjy_PTvtVSdC3gCoAEC',
#    'CommentTitle': "under the bucket seems hype, can't wait to see what comes of it",
#    'CommentCreationTime': '2016-02-16T19:33:39Z',
#    'CommentLikes': 1},
#   {'VideoId': '9Okkpmbdn_o',
#    'CommentId': 'Ughx6P5iMHGOBHgCoAEC',
#    'CommentTitle': 'This guy is hilarious lol',
#    'CommentCreationTime': '2016-02-17T00:02:58Z',
#    'CommentLikes': 0},
#   {'VideoId': '9Okkpmbdn_o',
#    'CommentId': 'UggPSnGMQnKpJngCoAEC',
#    'CommentTitle': "Fuck yeah. Go, go Lax Kw'alaams.",
#    'CommentCreationTime': '2016-02-16T20:38:46Z',
#    'CommentLikes': 0},
#   {'VideoId': '9Okkpmbdn_o',
#    'CommentId': 'Uggn9_NoLDVGkHgCoAEC',
#    'CommentTitle': 'Come on and slam!',
#    'CommentCreationTime': '2016-02-16T17:25:00Z',
#    'CommentLikes': 0},
#   {'VideoId': '9Okkpmbdn_o',
#    'CommentId': 'Ughco3f93eRpcXgCoAEC',
#    'CommentTitle': "When is bc not controversial really they have so much controversy their controversy has controversy if i were a businessman i would get the hell out of bc doesn't matter what you do oil,tech,housing,drugs just get out before it's too late",
#    'CommentCreationTime': '2016-02-18T00:02:41Z',
#    'CommentLikes': 0},
#   {'VideoId': '9Okkpmbdn_o',
#    'CommentId': 'UgiW5KkrJE_7nngCoAEC',
#    'CommentTitle': "Wait is this also the basketball team that didn't allow that black kid to play which team did it then?",
#    'CommentCreationTime': '2016-02-18T00:06:31Z',
#    'CommentLikes': 0},
#   {'VideoId': '9Okkpmbdn_o',
#    'CommentId': 'Ugh3twTjBb54ZHgCoAEC',
#    'CommentTitle': 'Hey is for horses......these "reporters" are awful.',
#    'CommentCreationTime': '2016-02-16T22:26:20Z',
#    'CommentLikes': 1},
#   {'VideoId': '9Okkpmbdn_o',
#    'CommentId': 'Ughj5WwSmgyYmXgCoAEC',
#    'CommentTitle': 'If they get enough money then any pipeline can go through. I bet they like having heated homes with gas lines.',
#    'CommentCreationTime': '2016-02-17T02:20:47Z',
#    'CommentLikes': 0},
#   {'VideoId': '9Okkpmbdn_o',
#    'CommentId': 'UgieUqk_QOrFkngCoAEC',
#    'CommentTitle': 'BC',
#    'CommentCreationTime': '2016-02-16T17:16:21Z',
#    'CommentLikes': 0}],
#  [{'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgzRFe-kSMP8WYVsshB4AaABAg',
#    'CommentTitle': "Earth isnt in danger, we are. Earth would just heal itself after we're gone.",
#    'CommentCreationTime': '2019-10-02T10:05:46Z',
#    'CommentLikes': 322},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgzqBuiuI4eCXhtp05Z4AaABAg',
#    'CommentTitle': "It's not about giving up, it's now about figuring out how to survive.",
#    'CommentCreationTime': '2019-09-21T15:07:43Z',
#    'CommentLikes': 47},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgxfwwIcumzydoknFKJ4AaABAg',
#    'CommentTitle': 'Love the video, especially the title. :)\n\nThe question I always ask myself is this; When did we accept adults making choices that were clearly irresponsible? \n\nGrowing up it was bombarded into my head to be responsible. Take responsibility for your actions and respect ones action in how they effect other people. But yet somehow it seems there has been a radical shift in holding those responsible for making these poor choices accountable.\n\nI am speaking from my perspective in the US, and let me say I am truly sorry for how piss poor many of our leaders are. I shoulder a great responsibility for their lack of empathy and conduct. I know it is not my fault, but it is more my fault than any other human due to the fact that on paper we use a "democracy" but that does not take away from the pain in knowing the truth.\n\nKeep up the good work, I do feel the best course of action is to educate everyone until we can all agree. If not maybe we need to flat out hog tie some representatives and pull them into a public space and set some examples for what we expect them to do. I do not advocate violence, but something needs to be done.',
#    'CommentCreationTime': '2019-09-21T20:49:19Z',
#    'CommentLikes': 14},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'Ugw3D0ahWVoeMcavEyd4AaABAg',
#    'CommentTitle': 'The end of the world? Did you mean the end of humanity?',
#    'CommentCreationTime': '2019-09-21T15:44:56Z',
#    'CommentLikes': 539},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgzOzLzEBoC2HAqhfjV4AaABAg',
#    'CommentTitle': 'Even if the climate wouldn\'t cause a collapse, the depletion of the oil reserves would destroy civilisation since literally everything runs on oil. Alternative energy could provide the bare minimum but it would eb goodbye to 90% of all cars etc. Such a huge change won\'t happen in the next 50 years so it\'s lights out no matter what.\n\n\nWe live at "peak civilisation" and i am happy to live now and not in the mad-max like future.',
#    'CommentCreationTime': '2019-09-21T15:32:53Z',
#    'CommentLikes': 14},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgzJITD3KR2-YVCNCXN4AaABAg',
#    'CommentTitle': 'Shoutout to my homies in Malaysia, Singapore and Indonesia choking on smog right now, this is it lads..',
#    'CommentCreationTime': '2019-09-21T15:36:11Z',
#    'CommentLikes': 194},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgzMM_R2vNqf3Rqp3z94AaABAg',
#    'CommentTitle': "this world is just ran by money and that's the only focus people have",
#    'CommentCreationTime': '2019-09-21T22:00:24Z',
#    'CommentLikes': 88},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgyjzwOP5WxXZJ9v6MZ4AaABAg',
#    'CommentTitle': "How can I just subscribe to your videos instead of the entire vice network. Love them, but have to spend time searching for everything you do. It's so good.",
#    'CommentCreationTime': '2019-09-28T06:52:20Z',
#    'CommentLikes': 8},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgzaXrVXuivIBA8UT-F4AaABAg',
#    'CommentTitle': 'I’m not gonna give up, I guess my life has a purpose. Save the Earth!',
#    'CommentCreationTime': '2019-09-21T16:11:18Z',
#    'CommentLikes': 24},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgyxFWvf0SCxxwGoIUd4AaABAg',
#    'CommentTitle': 'We will one day be fossils for the next species. Hope I die in a cool position.',
#    'CommentCreationTime': '2019-09-21T18:36:19Z',
#    'CommentLikes': 230},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'Ugxzc7bZC-r4v5jbNm94AaABAg',
#    'CommentTitle': 'On the gravestone of the human race\n\n"It was faster than expected"',
#    'CommentCreationTime': '2019-09-22T14:05:11Z',
#    'CommentLikes': 63},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'Ugwk9SCF-5PTXrBTgrh4AaABAg',
#    'CommentTitle': 'This didn’t cure my Sunday anxiety',
#    'CommentCreationTime': '2019-10-06T11:33:58Z',
#    'CommentLikes': 22},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgxmaSKyomXgwWngiS94AaABAg',
#    'CommentTitle': 'Well, I hope the pooclypse is kind to me. I did recycle some cans once.',
#    'CommentCreationTime': '2019-09-21T17:45:21Z',
#    'CommentLikes': 48},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgzVlFLXHLlMeqFtqRN4AaABAg',
#    'CommentTitle': 'it’s all up to the vsco girls to save our planet 🌱🐢🥤',
#    'CommentCreationTime': '2019-09-21T16:10:22Z',
#    'CommentLikes': 239},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgzlY4FFviQtok95OR54AaABAg',
#    'CommentTitle': 'What if we live in a city/state that is locally doing 10x more, environmentally, than most cities/states?  Regardless of our continued conservationism, everyone else (and all the companies, internationally) keep erasing all the good progress we are making.  Its frustrating.',
#    'CommentCreationTime': '2019-09-22T21:36:16Z',
#    'CommentLikes': 4},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgzKsRTXu5h-1Mdxoax4AaABAg',
#    'CommentTitle': 'Remember that Fallout 3 song " I DON\'T want to set the World on fire" ?',
#    'CommentCreationTime': '2019-09-21T15:31:40Z',
#    'CommentLikes': 73},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'Ugx18aG92Y6uDNjByQV4AaABAg',
#    'CommentTitle': '“The common enemy of humanity is man.\nIn searching for a new enemy to unite us,\xa0we came up\nwith the idea that pollution, the threat of global warming,\nwater shortages, famine and the like would fit the bill. All these\ndangers are caused by human intervention, and it is only through\nchanged attitudes and\xa0behaviour\xa0that they can be overcome.\nThe real enemy then, is humanity itself.“\n–\xa0Club of Rome,\npremier environmental think-tank,\nconsultants to the United Nations\n\n“Isn’t the only hope for the planet that the\nindustrialized civilizations collapse?\nIsn’t it our responsiblity to bring that about?”\n–',
#    'CommentCreationTime': '2019-09-21T15:30:33Z',
#    'CommentLikes': 3},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'Ugw2CguG_ofjmUX4OrV4AaABAg',
#    'CommentTitle': "It was never a question of 'if', it has been a question of 'when' since the 70's",
#    'CommentCreationTime': '2019-09-23T10:38:39Z',
#    'CommentLikes': 22},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgzpGZz2DQtEzzqTSuZ4AaABAg',
#    'CommentTitle': 'I think about starting a business and sometimes i think, what if the world just ends.',
#    'CommentCreationTime': '2019-09-27T06:31:34Z',
#    'CommentLikes': 21},
#   {'VideoId': 'tNwkY_V_BPI',
#    'CommentId': 'UgyIlXrQfmWZ9Ol-Ifd4AaABAg',
#    'CommentTitle': 'Well great to know that I won’t live past 50 thanks vice',
#    'CommentCreationTime': '2019-09-21T15:50:41Z',
#    'CommentLikes': 25}],
#  [{'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'Ugg7Z2F-hSbJJXgCoAEC',
#    'CommentTitle': "Don't care what the comments in the comment section say, his hair is fucking GLORIOUS!",
#    'CommentCreationTime': '2016-04-23T01:14:44Z',
#    'CommentLikes': 246},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'Ugi8dDbPjsJWT3gCoAEC',
#    'CommentTitle': "Confidence comes from doing the right thing.  Thats why he has it and you don't.",
#    'CommentCreationTime': '2016-04-22T17:11:43Z',
#    'CommentLikes': 194},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'UgzT9-JN6uNQu6abKgV4AaABAg',
#    'CommentTitle': 'Seeing the younger generation come together taking action gives so much hope for all of your future lives. There needs to be more ppl of all ages made aware of this. So proud of you all, God bless*',
#    'CommentCreationTime': '2019-09-26T02:24:56Z',
#    'CommentLikes': 11},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'Ugj3O9iYTl8LfngCoAEC',
#    'CommentTitle': "I think it's sad to see people talk about someone they don't know in a negative way just because he's an eloquent speaker & isn't part of the phone zombie generation. Seeing this gives me hope for the future & knowing that there are kids out there who are not just educated but dedicated to doing something about an issue that has been around for decades.",
#    'CommentCreationTime': '2016-05-10T08:14:53Z',
#    'CommentLikes': 17},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'UggQ6ZAsCRbwg3gCoAEC',
#    'CommentTitle': "that's fucking awesome man,  I'm 15, and I think the government and big industry need to get kicked in the ass for what they do to the planet we live on, and it blows my mind that it's being done by a 15 year old, super inspiring man, keep it up",
#    'CommentCreationTime': '2016-04-27T06:24:27Z',
#    'CommentLikes': 133},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'UgjkvgiLJ3k3YngCoAEC',
#    'CommentTitle': "Props to this guy for standing up and actually TAKING ACTION on something he believes in. For a few years after 2010 I was literally paralyzed with fear about global warming/climate change and the idea that I am only one person. I would make a bunch of FB posts and Tumblr posts telling people ways to reduce carbon footprint and stuff but mostly nobody cared. When I accepted the fact that my own death is inevitable it diminished the anxiety about entropic heat death. This kid has a confidence and natural leadership that I definitely admire. I always think its a great idea to be an activist but very rarely have I actually done anything. He is speaking up for the people who feel they don't have a voice but the more people talking about these issues the better.",
#    'CommentCreationTime': '2016-04-24T18:20:21Z',
#    'CommentLikes': 3},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'UgiGCM0J8NfXpngCoAEC',
#    'CommentTitle': 'The hate this dude receives is unreal...',
#    'CommentCreationTime': '2016-04-22T16:27:19Z',
#    'CommentLikes': 36},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'Uggh6zib-51phXgCoAEC',
#    'CommentTitle': 'This child is hope for humanity.',
#    'CommentCreationTime': '2016-09-04T03:54:59Z',
#    'CommentLikes': 48},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'Ugijh8w_O8TFaHgCoAEC',
#    'CommentTitle': 'This is genuinely inspiring, massive thanks to vice for covering this 👍👏',
#    'CommentCreationTime': '2016-04-22T19:49:51Z',
#    'CommentLikes': 6},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'UgiqvEaFdWtrKXgCoAEC',
#    'CommentTitle': "How come you didn't delve into the specific demands presented to the court... not a single one...",
#    'CommentCreationTime': '2016-04-22T16:56:04Z',
#    'CommentLikes': 21},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'UgzKDqcCqGzO6yXx4X14AaABAg',
#    'CommentTitle': "truly heartened! Simply true words spoken out! Facts that are facts - he does not put the attention on himself - in contrary to law makers - it's about our resources and about our respect we should pay for this planet. If we fail - we get the bill and it's not to pay in USD, EUR or GBP it's not a currency - its to be paid in lives. My entire and full respect for Xiuhtezcatl Tonatiuh! You give me inspiration and passion for contribution and for fighting towards the establishment!",
#    'CommentCreationTime': '2018-08-06T20:54:36Z',
#    'CommentLikes': 1},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'UghpWhNmX5jcSngCoAEC',
#    'CommentTitle': 'Leonardo DiCaprio also helped bring a movie called "Cowspiracy" to the masses. Its a must see, for any environmentalist.',
#    'CommentCreationTime': '2016-04-22T19:57:54Z',
#    'CommentLikes': 12},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'UghssNTs6Yj7BXgCoAEC',
#    'CommentTitle': 'fucking Aztec Warrior suing the U.S. government.',
#    'CommentCreationTime': '2016-04-22T15:55:56Z',
#    'CommentLikes': 21},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'Ugg2Bm40b7pRm3gCoAEC',
#    'CommentTitle': "Damn, dude. It's awesome to see that he's so loud and passionate about climate change.",
#    'CommentCreationTime': '2016-04-24T20:23:12Z',
#    'CommentLikes': 40},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'UgiSMvHLUPNm-ngCoAEC',
#    'CommentTitle': 'I love how most of the comments so far have been about his physical appearance rather that how strong and empowering this kid is for pushing for a better environment. But you know, people dont care.',
#    'CommentCreationTime': '2016-04-22T16:02:11Z',
#    'CommentLikes': 7},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'Ugj6iOnvD9w5CngCoAEC',
#    'CommentTitle': 'I dont get why so many dislikes. People dont want to save the planet? WTF?',
#    'CommentCreationTime': '2016-04-22T16:12:40Z',
#    'CommentLikes': 39},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'Ugh_3wxj3Nz133gCoAEC',
#    'CommentTitle': "I'm happy that people from my generation are being able to get their voice heard, this is truly inspiring !!!",
#    'CommentCreationTime': '2017-07-09T20:26:54Z',
#    'CommentLikes': 4},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'Uggn5-aY8Ql-FXgCoAEC',
#    'CommentTitle': "I don't understand how people can give a video like this a thumbs down. We need to start caring and loving the people and the earth more",
#    'CommentCreationTime': '2016-04-28T16:32:09Z',
#    'CommentLikes': 1},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'Ugh73scvVr9Wb3gCoAEC',
#    'CommentTitle': "I can't hate on this kid. He's doing what he feels is the right thing to do with the cards he has.",
#    'CommentCreationTime': '2016-04-22T16:11:01Z',
#    'CommentLikes': 52},
#   {'VideoId': 'gXBR5ZrKdws',
#    'CommentId': 'UgibOCQK7b9kengCoAEC',
#    'CommentTitle': 'haters gotta hate. he is a great person and a hero in my opinion. he is 12 years younger than me, but a real rolemodel!',
#    'CommentCreationTime': '2016-04-30T21:27:45Z',
#    'CommentLikes': 6}]]

# %%
# Count comments per videoId to ensure there is enough comments

from collections import defaultdict

comment_count = defaultdict(int)

for video_comments in vice_comments:
    for comment in video_comments:
        video_id = comment['VideoId']
        comment_count[video_id] += 1

print("Number of comments per videoId:")
for video_id, count in comment_count.items():
    print(f"Video ID: {video_id}, Number of Comments: {count}")
# Out:
# Number of comments per videoId:
# Video ID: qX_aaRepdIM, Number of Comments: 30
# Video ID: Jj-3kBi49eg, Number of Comments: 30
# Video ID: nogb7DboO64, Number of Comments: 23
# Video ID: D669qcb7GGI, Number of Comments: 30
# Video ID: 5cm9ELLR8ds, Number of Comments: 30
# Video ID: 61trVLZv1-w, Number of Comments: 30
# Video ID: fU3C8o8I6GQ, Number of Comments: 30
# Video ID: V3KGKQd_4tk, Number of Comments: 30
# Video ID: _kqiGAswtKE, Number of Comments: 30
# Video ID: LttCr8rudxQ, Number of Comments: 30
# Video ID: xTnJgpF5LYg, Number of Comments: 20
# Video ID: Imj5EGZzrwg, Number of Comments: 30
# Video ID: lFIro2Dnfj8, Number of Comments: 30
# Video ID: QX3M8Ka9vUA, Number of Comments: 30
# Video ID: jUFOECOZ1fg, Number of Comments: 2
# Video ID: 5I2HA1MIeeo, Number of Comments: 6
# Video ID: KL8CIZej19o, Number of Comments: 30
# Video ID: hxdwbZ3Oeyc, Number of Comments: 30
# Video ID: FDYqe5I35KA, Number of Comments: 30
# Video ID: 07lsXkWmpz8, Number of Comments: 30
# Video ID: dckjk1V-KRM, Number of Comments: 30
# Video ID: Zh2e8nY8VJ0, Number of Comments: 30
# Video ID: 4PfZlxhvdkM, Number of Comments: 30
# Video ID: gdhdAktIHtg, Number of Comments: 30
# Video ID: xnS2CTmdA0A, Number of Comments: 30
# Video ID: Kae-nng77yE, Number of Comments: 30
# Video ID: ARQJlzZ2qu8, Number of Comments: 2
# Video ID: _xO5dsGEL_E, Number of Comments: 30
# Video ID: 18_KBggvIZM, Number of Comments: 30
# Video ID: M4BOdBJFkgA, Number of Comments: 30
# Video ID: y20Tx2eCw28, Number of Comments: 30
# Video ID: q2roLP6HIQA, Number of Comments: 30
# Video ID: RpJDwQSvXNs, Number of Comments: 8
# Video ID: uaDZ0bVresE, Number of Comments: 30
# Video ID: 6S9oUu0R3sY, Number of Comments: 30
# Video ID: ee5JCDzPB0I, Number of Comments: 30
# Video ID: gs26R56d3ww, Number of Comments: 30
# Video ID: cdZy4balvB8, Number of Comments: 30
# Video ID: qavbWjQpDhA, Number of Comments: 30
# Video ID: 2RZoGOc3VCs, Number of Comments: 30
# Video ID: efSRjjzde54, Number of Comments: 22
# Video ID: pZH9ZYFU26U, Number of Comments: 30
# Video ID: fD93qXcMwGA, Number of Comments: 5
# Video ID: 0rlaeRHgUCk, Number of Comments: 30
# Video ID: IT8XsE0If0g, Number of Comments: 5
# Video ID: FHlI6Vjc0tI, Number of Comments: 30
# Video ID: SwoRx3tstxY, Number of Comments: 30
# Video ID: 3JFihjEWU3c, Number of Comments: 30
# Video ID: PdJJxwP8NaU, Number of Comments: 30
# Video ID: X3ySrcI2mEA, Number of Comments: 30
# Video ID: _278oKkyf48, Number of Comments: 30
# Video ID: m54L1jusS5w, Number of Comments: 30
# Video ID: EaPnv82Hs3g, Number of Comments: 5
# Video ID: vaTnP5AgQ_g, Number of Comments: 30
# Video ID: TgVwCJ2J6pQ, Number of Comments: 3
# Video ID: UnETVMI4tY8, Number of Comments: 30
# Video ID: 4qePOEBm9Aw, Number of Comments: 30
# Video ID: gXTeg5LAvN8, Number of Comments: 30
# Video ID: GMdymyLNC1s, Number of Comments: 8
# Video ID: egEbJ2gukxU, Number of Comments: 30
# Video ID: PfbNY2G64G8, Number of Comments: 30
# Video ID: Dkk1rMARYOY, Number of Comments: 6
# Video ID: d9K96fZGY64, Number of Comments: 30
# Video ID: XnpbVRg1-qc, Number of Comments: 30
# Video ID: -1A9v5bQDqk, Number of Comments: 30
# Video ID: 7fJpRa7o_fQ, Number of Comments: 30
# Video ID: hyk5YXnag9E, Number of Comments: 6
# Video ID: yF204b-Ngjk, Number of Comments: 4
# Video ID: Jp0nqJ1yrrg, Number of Comments: 30
# Video ID: qoqds4LV9RI, Number of Comments: 30
# Video ID: 388wlVWxGz0, Number of Comments: 30
# Video ID: N9SR09eC_z0, Number of Comments: 30
# Video ID: gt7HlHDmc_4, Number of Comments: 30
# Video ID: 9Okkpmbdn_o, Number of Comments: 13
# Video ID: tNwkY_V_BPI, Number of Comments: 30
# Video ID: gXBR5ZrKdws, Number of Comments: 30

# %%
# Create a dict to map video ids to their corresponding details
vid_details = {vid['id']: vid for sublist in vice_vid_info for vid in sublist}

# Comebine vid detail with comments
vice_result = []

for sublist in vice_comments:
    for item in sublist:
        vid_id = item['VideoId']
        if vid_id in vid_details:
            details = vid_details[vid_id].copy()
            details.update(item)
            vice_result.append(details)

# %%
len(vice_result)
# Out:
# 1938

# %%
vice_result
# Out:
# [{'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgyT8lzHq4KG18pbEAx4AaABAg',
#   'CommentTitle': 'A lot of businesses are struggling. The ones that aren’t struggling as much are banks and grocery stores.',
#   'CommentCreationTime': '2020-09-23T19:56:07Z',
#   'CommentLikes': 75},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgwWciuwhjWJtn5p2B54AaABAg',
#   'CommentTitle': 'Damn the World really sucks now.\nLooking forward to better days for everyone.',
#   'CommentCreationTime': '2020-09-23T20:42:39Z',
#   'CommentLikes': 89},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgxAbD9h5oBPSxaRgvN4AaABAg',
#   'CommentTitle': 'Sadly I think at least 50% of clubs, bars and restaurants worldwide will eventually go under. This with have a ripple effect in the supply chains and vendors who keep these businesses stocked with products as well.',
#   'CommentCreationTime': '2020-09-24T08:16:30Z',
#   'CommentLikes': 45},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'Ugx5ivt655zG1cctmVJ4AaABAg',
#   'CommentTitle': "I love Plant. It was one of the highlights to my trip to Korea. It's sad to see so many businesses suffer.",
#   'CommentCreationTime': '2020-09-27T21:20:05Z',
#   'CommentLikes': 4},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgztX1erPMN0W9t8tWZ4AaABAg',
#   'CommentTitle': '"AKA DJ Bowlcut" lmao 😂😅😅',
#   'CommentCreationTime': '2020-09-23T19:31:59Z',
#   'CommentLikes': 53},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgzNva2CkdiLdgwcf2V4AaABAg',
#   'CommentTitle': 'I was in Soputh Korea recently.  Beautiful, peaceful, amazing place.',
#   'CommentCreationTime': '2020-09-23T19:04:21Z',
#   'CommentLikes': 29},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgwRLgppH0gj3WEB7Pl4AaABAg',
#   'CommentTitle': 'I was in South Korea last year! Really enjoyed it and loved the party scene, really want to go back!',
#   'CommentCreationTime': '2020-09-24T03:26:08Z',
#   'CommentLikes': 58},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'Ugy_2Vxo48zxC8oU6q14AaABAg',
#   'CommentTitle': 'Damn that place was the spot to party people would come from all over to hit the bars and clubs',
#   'CommentCreationTime': '2020-09-23T19:15:19Z',
#   'CommentLikes': 58},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgxqXQ3YALM74Tch2gp4AaABAg',
#   'CommentTitle': "For those asking 'why only Korean nightclubs' this video originally aired on Vice Asia in August and was symbolic of the plight of a lot of nightlife places worldwide. Its a tragedy how govts are ignoring / declining to financially help an industry of such cultural importance",
#   'CommentCreationTime': '2020-09-24T03:08:28Z',
#   'CommentLikes': 43},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgyXco0zyRLf8Q7ibVN4AaABAg',
#   'CommentTitle': 'Damn. I was in Seoul last year, hope the world recovers quickly!!! 🇰🇷',
#   'CommentCreationTime': '2020-09-23T21:50:15Z',
#   'CommentLikes': 7},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'Ugyv2tlYNapJ2lkCPhZ4AaABAg',
#   'CommentTitle': 'I\'m not even vegan and now I wish I could go eat at "Plant" I hate seeing business suffer unfairly.',
#   'CommentCreationTime': '2020-09-24T20:38:55Z',
#   'CommentLikes': 11},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'Ugyv6mdcZ-H2q4V2d5p4AaABAg',
#   'CommentTitle': "Damn I always wanted to go there and explore this little area... Hopefully it's still there in a year or two smh... But honestly... From what I've always known about that area, it's not gonna be back to normal until tourist are able to go there in mass also...",
#   'CommentCreationTime': '2020-09-23T20:52:11Z',
#   'CommentLikes': 12},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'Ugw7-Ku6_gyr7EdJGUF4AaABAg',
#   'CommentTitle': 'They say you appreciate things more when you have to wait',
#   'CommentCreationTime': '2020-09-24T01:51:41Z',
#   'CommentLikes': 4},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgwPZOZPZKNrFRS9GMd4AaABAg',
#   'CommentTitle': 'Best experience I had in the army was exploring S Korea with my two friends just living life and experience live music the way it should be 🤟🏽',
#   'CommentCreationTime': '2020-09-25T06:06:20Z',
#   'CommentLikes': 3},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'Ugx9svib6uuVVU8PGGJ4AaABAg',
#   'CommentTitle': 'Great speech from all those youngsters',
#   'CommentCreationTime': '2020-09-24T14:19:06Z',
#   'CommentLikes': 1},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'Ugy4PySPlYIem6PIA7p4AaABAg',
#   'CommentTitle': "Yeah It's true that Every NightClub Businesses around the world have problems with COVID. but in korea,  things are going bit differently. It's not really the COVID but the Stigmatization towards to club culture itself makes it more difficult.",
#   'CommentCreationTime': '2020-09-24T11:02:31Z',
#   'CommentLikes': 2},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgwjWTe5N8iab6sMI1B4AaABAg',
#   'CommentTitle': "That's crazy!!! Looks like such an awesome spot! It's like there's a war on music and the nightlife going on worldwide!!",
#   'CommentCreationTime': '2020-09-23T21:04:27Z',
#   'CommentLikes': 7},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'Ugz1wOx3y5l1KBoEpKt4AaABAg',
#   'CommentTitle': 'great shots of itaewon at the beginning!',
#   'CommentCreationTime': '2020-09-23T19:29:49Z',
#   'CommentLikes': 5},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgxsN_1TZ2OuXtUPYWt4AaABAg',
#   'CommentTitle': "I've been to Itaewon Ro and it's an amazing place. South Korea is wonderful. \n\nHey Vice, how about a story on how the play on words and banning large gatherings isn't just a thing happening in the US to keep people from congregating? The pandemic guidelines are hypocratic and are ruining all societies, not just the US.",
#   'CommentCreationTime': '2020-09-29T17:49:09Z',
#   'CommentLikes': 3},
#  {'channel': 'Vice',
#   'id': 'qX_aaRepdIM',
#   'title': 'Running a Nightclub During a Pandemic',
#   'keyword': 'Pandemics',
#   'published_at': '2020-09-23T19:00:18Z',
#   'VideoViews': '137070',
#   'VideoId': 'qX_aaRepdIM',
#   'CommentId': 'UgxXC000p_VdHvNbwv14AaABAg',
#   'CommentTitle': 'Vice: proceeds to cluster the nightclub',
#   'CommentCreationTime': '2020-09-23T19:06:49Z',
#   'CommentLikes': 5},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgxjoTVRr-NX_qmXWh94AaABAg',
#   'CommentTitle': 'Thank you for having us. Zeke we enjoyed time on the range with you and hope after all of this you will continue to train and enjoy more time on the range.',
#   'CommentCreationTime': '2021-11-29T02:20:11Z',
#   'CommentLikes': 592},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgzfR8B9fuIR3_wDwu54AaABAg',
#   'CommentTitle': '“I don’t know if I can bear the minimum responsibility required for gun ownership.” \nBoom. There it is. Firearms ownership is a perpetual exercise in personal responsibility. Every day, it’s in the back of your mind “hey, I have a gun,” and every day, you remind yourself that it is *your* charge. It isn’t for everybody, and that’s okay - what matters is that *you* know whether or not it’s something that you want.',
#   'CommentCreationTime': '2021-11-29T23:50:14Z',
#   'CommentLikes': 355},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgxjhIYbNk9myiN7wkB4AaABAg',
#   'CommentTitle': 'Hiring Zeke is the best thing VICE has ever done, if we start giving more neutral open-minded people like him a voice in media outlets we might actually slowly start coming together as a nation and I’m not over-exaggerating by saying that.',
#   'CommentCreationTime': '2021-11-28T21:30:13Z',
#   'CommentLikes': 681},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'Ugyvp96JoOFNcJqOxj14AaABAg',
#   'CommentTitle': 'I lived in NYC my whole life and guns were always frowned upon, and made me bias to seeing them as negative. When I moved to Atlanta, all my friends had legal guns. I went to the range and trained and I seen guns more as a tool than something negative. I gained respect for guns with education.',
#   'CommentCreationTime': '2021-12-01T18:07:25Z',
#   'CommentLikes': 196},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'Ugwe1vrW12p3M8sHOkJ4AaABAg',
#   'CommentTitle': 'Better than I thought it was going to be. I can tell vice at least tried to act like they were being objective.',
#   'CommentCreationTime': '2021-11-28T21:27:04Z',
#   'CommentLikes': 931},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgyTJEBCo_tLq_AQ4Wt4AaABAg',
#   'CommentTitle': 'THIS IS THE VICE we all love. Display the facts and let the reader come to their own conclusions. Throughly surprised',
#   'CommentCreationTime': '2021-11-29T02:02:03Z',
#   'CommentLikes': 243},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgwUFahkqugPzkusXPF4AaABAg',
#   'CommentTitle': 'finally, a gun episode that isnt cringe and stupid, NICE WORK',
#   'CommentCreationTime': '2021-11-28T17:26:35Z',
#   'CommentLikes': 671},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgxKfsnBJ5orjkyFjJN4AaABAg',
#   'CommentTitle': "As someone who worked at a hospital with a behavioral health unit and had to carry a fully loaded glock 17 with 2 spare mags, pepper spray, and handcuffs at all times on shift (the job requiring me to). Him saying mental health is the issues couldn't be more spot on mental health system in America is seriously broken and neglected. People especially nurses, doctors, hospital staff, and even the patients shouldnt feel the need or expect to have armed security looking after them while they save lives, help people, or receive treatment and it shouldnt be underfunded because your on section 8 or considered low income.",
#   'CommentCreationTime': '2021-11-28T21:09:50Z',
#   'CommentLikes': 184},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgyYqHx-2GJjrzRKYyt4AaABAg',
#   'CommentTitle': 'Armed Minorities Are Harder To Oppress. Self defense isn’t a crime remember that.',
#   'CommentCreationTime': '2021-11-28T18:21:31Z',
#   'CommentLikes': 58},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgzzkQQXfjWSGqZ_QOh4AaABAg',
#   'CommentTitle': 'His smile when he was dumping his mag in the mp5 was priceless.',
#   'CommentCreationTime': '2021-12-01T16:53:11Z',
#   'CommentLikes': 15},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgxiIA1PRkLBlGHaLUh4AaABAg',
#   'CommentTitle': 'You know Vice, as a gun owning, conservative guy… I give you props for not demonizing firearms or the firearms culture. Thanks for showing some of the many many safe, sane and responsible owners.',
#   'CommentCreationTime': '2021-11-28T21:15:08Z',
#   'CommentLikes': 103},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgwsWN8fPbq37CYV9fp4AaABAg',
#   'CommentTitle': 'I appreciate the take on the topic. Being a pro-gun liberal really pisses me off because people equate being liberal to hating guns. All Americans who are mentally fit should have access to firearms. That being said, mental health should be more addressed.',
#   'CommentCreationTime': '2021-11-28T17:26:19Z',
#   'CommentLikes': 294},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'Ugx9nYYM9QJvWoIh4zl4AaABAg',
#   'CommentTitle': 'My favorite part is where you brought up that 60+% of gun deaths are suicides… thank you for mentioning this as most people think guns are really the problem.',
#   'CommentCreationTime': '2021-12-08T07:48:29Z',
#   'CommentLikes': 142},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgwBitZj6M6pNYLqzF14AaABAg',
#   'CommentTitle': 'Wow…Just got done watching. A neutral gun piece on VICE. When Zeke reached out to me I was apprehensive to say the least. In fact I thought I was being punk\'d 😂 But many phone calls, texts and emails later and it became apparent Zeke was here to cover a subject, not lean it one way or another. His piece on "Doomsday Peppers" sealed the deal for me. So he and his very talented film crew flew down and we spent the entire day filming and shooting. I\'ll be putting together a video on my channel with some fun behind the scenes footage from that day.\xa0\n\nWhatever guns mean to you, good, bad, or indifferent; they are here to stay, just like our freedom of speech, freedom from unreasonable search and seizure, right to fair and speedy trial, right to due process of law, etc. The 2nd amendment protects THE PEOPLE. And I meant what I said about mental health reform. That\'s the topic we should be discussing. Don\'t let those in power (No Term Limit Career Politicians) strip your rights and power in the process by giving up our right to bear arms. It really is a simple as that. Zeke, if you see this comment, you\'re welcome back anytime. 🤙',
#   'CommentCreationTime': '2021-11-28T16:50:23Z',
#   'CommentLikes': 2145},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'Ugx0p91NzxyEkMiRrfJ4AaABAg',
#   'CommentTitle': "Black Gun Owners Association....good job representing Jacksonville and Duval.  I'm a lawyer and gun owner in Jacksonville and recognize OTS range.  You all did a great job.  A good piece overall from vice as well...surprisingly.",
#   'CommentCreationTime': '2021-12-05T06:40:24Z',
#   'CommentLikes': 74},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgxE1_GdjRRkyY-KYqx4AaABAg',
#   'CommentTitle': "Loved it! Can't lie I was totally expecting another 2A hit piece but this was a great open and honest documentary about gun culture and a call to understand the root causes of gun violence. Vice if you hire 100 more journalist that are as open and honest as him your organization would have a much better reputation.",
#   'CommentCreationTime': '2021-11-28T19:28:11Z',
#   'CommentLikes': 94},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgwMuRoDEyW3qvngw4t4AaABAg',
#   'CommentTitle': "Knowledge of firearms, practicing firearms safety and knowledge of state laws makes all the difference in the world. Vice I'm actually pleased that a knowledgeable, fun and neutral piece about firearms was produced. 💯",
#   'CommentCreationTime': '2021-11-28T17:00:43Z',
#   'CommentLikes': 208},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgxeiUc8W3f4n4nwVEF4AaABAg',
#   'CommentTitle': "I wanted to say actually thank you to Vice, Zeke and the two women that was part of this series.  You remained neutral showing all walks of life from culture to political that maintained the middle road on this topic.  I appreciate that very much.  When I first saw the title knowing Vice's history, I was very skeptical on whether this was going to be a smear fest.  Well done video and hope those that either was on the fence with firearms or completely against them have a bit of a better viewpoint on the matter.  If one person changed their mind to become a responsible gun owner, it is a win in my book.",
#   'CommentCreationTime': '2021-12-02T03:36:29Z',
#   'CommentLikes': 54},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgzfjLSH7FL9VgXTFfZ4AaABAg',
#   'CommentTitle': 'I appreciate the fair approach of this video.',
#   'CommentCreationTime': '2021-11-28T16:23:45Z',
#   'CommentLikes': 127},
#  {'channel': 'Vice',
#   'id': 'Jj-3kBi49eg',
#   'title': 'With Liberty and Guns for All | Spiraling',
#   'keyword': 'Gun',
#   'published_at': '2021-11-28T16:00:13Z',
#   'VideoViews': '396938',
#   'VideoId': 'Jj-3kBi49eg',
#   'CommentId': 'UgzO-xNE_ryaQ4LCZ6p4AaABAg',
#   'CommentTitle': 'I remember been a huge lefty when it came to guns and laws. Then in college I got a part time job at a pawnshop. My boss heard my about my stance on guns. Rather than try to lecture me or change my mind with words, he took me to the shooting range that weekend. After my first shot, I was hooked.',
#   'CommentCreationTime': '2022-01-10T07:16:49Z',
#   'CommentLikes': 5},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgzuFeIs-MRBJWmHiIJ4AaABAg',
#   'CommentTitle': "It's  like k2 or spice. Very similar to bath salts.",
#   'CommentCreationTime': '2023-06-26T02:48:45Z',
#   'CommentLikes': 20},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgydrrxPljdkmXJu0Sd4AaABAg',
#   'CommentTitle': 'Wow, that told us absolutely nothing.',
#   'CommentCreationTime': '2023-05-03T15:18:06Z',
#   'CommentLikes': 38},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgyP5RiE0g4y_Mei7tZ4AaABAg',
#   'CommentTitle': 'When you’re selling it and don’t know what’s in it yourself you should stop.',
#   'CommentCreationTime': '2023-07-23T06:31:01Z',
#   'CommentLikes': 6},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgyhTPlKBimSBTHEBnR4AaABAg',
#   'CommentTitle': 'Put the subtitles higher please!',
#   'CommentCreationTime': '2023-11-01T23:53:38Z',
#   'CommentLikes': 3},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgywWBucNNMQ8j4_g1d4AaABAg',
#   'CommentTitle': 'Liquid mdma.',
#   'CommentCreationTime': '2023-05-08T03:01:43Z',
#   'CommentLikes': 8},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgxdKIBoGavd_0QLVA54AaABAg',
#   'CommentTitle': 'It’s rat poison',
#   'CommentCreationTime': '2023-05-30T11:51:42Z',
#   'CommentLikes': 2},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgzA0caLkXksANmUaB94AaABAg',
#   'CommentTitle': 'DNG DNG DNG DNG',
#   'CommentCreationTime': '2023-05-03T21:21:52Z',
#   'CommentLikes': 6},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgxbJ2tYTeyUjLRTYpp4AaABAg',
#   'CommentTitle': 'Have a good day vice. Should’ve left Top G alone lol',
#   'CommentCreationTime': '2023-05-05T16:31:05Z',
#   'CommentLikes': 24},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgzOM4IqB-aI4g9VDzp4AaABAg',
#   'CommentTitle': 'To compare MS-13 the the Mexican drug cartels is a joke and shows where Vice is at anymore these days',
#   'CommentCreationTime': '2023-05-04T06:17:56Z',
#   'CommentLikes': 8},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'Ugx4Iix0QnXVYBkZEOt4AaABAg',
#   'CommentTitle': 'DNG',
#   'CommentCreationTime': '2023-05-05T20:11:57Z',
#   'CommentLikes': 2},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgwnLNRDV2Q7-DdDa3J4AaABAg',
#   'CommentTitle': 'maybe they are just smoking rat poison. they dont know 😂',
#   'CommentCreationTime': '2024-02-25T19:35:32Z',
#   'CommentLikes': 0},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'Ugx__YItfgm65yBZYBl4AaABAg',
#   'CommentTitle': '🔥 Amiguita..!!! Vaye buscando trabajo...Vice esta en Bancarota.',
#   'CommentCreationTime': '2023-05-09T03:55:58Z',
#   'CommentLikes': 1},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgwBvG1mpbMdEYX22Ll4AaABAg',
#   'CommentTitle': 'Top G',
#   'CommentCreationTime': '2023-05-04T12:10:14Z',
#   'CommentLikes': 7},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgwAFEb5BGOWW_XE7ph4AaABAg',
#   'CommentTitle': 'Love the videos from vice',
#   'CommentCreationTime': '2023-05-03T15:03:50Z',
#   'CommentLikes': 5},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'Ugx7jD6K61xMAmx_tzp4AaABAg',
#   'CommentTitle': "Ha ! It's over for this CIA operation. \n\n#bankruptcy",
#   'CommentCreationTime': '2023-05-03T21:50:48Z',
#   'CommentLikes': 8},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'Ugwk9FuGAoFdY6Q3dn54AaABAg',
#   'CommentTitle': "Don't think. Just do. Have a great rest of your week!",
#   'CommentCreationTime': '2023-05-03T15:22:31Z',
#   'CommentLikes': 1},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgyPi82LQv8zk1UO-vV4AaABAg',
#   'CommentTitle': 'sad',
#   'CommentCreationTime': '2023-11-01T14:59:15Z',
#   'CommentLikes': 0},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgwDbdViNv6Ukvdjgk14AaABAg',
#   'CommentTitle': '#topG',
#   'CommentCreationTime': '2023-05-04T16:35:39Z',
#   'CommentLikes': 6},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgwSAkO28KgmNmFxgQx4AaABAg',
#   'CommentTitle': 'Hello satan',
#   'CommentCreationTime': '2023-05-24T05:54:49Z',
#   'CommentLikes': 0},
#  {'channel': 'Vice',
#   'id': 'nogb7DboO64',
#   'title': 'The Toxic Weed Making MS13 Rich #shorts',
#   'keyword': 'Rich',
#   'published_at': '2023-05-03T15:00:39Z',
#   'VideoViews': '65757',
#   'VideoId': 'nogb7DboO64',
#   'CommentId': 'UgyaYIF7ngFN3jwraap4AaABAg',
#   'CommentTitle': 'Heard y’all are going bankrupt. That’s what you get for pushing all those agendas',
#   'CommentCreationTime': '2023-05-03T16:59:31Z',
#   'CommentLikes': 20},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgzXTfheK3dlxhPweph4AaABAg',
#   'CommentTitle': 'This dude is brilliant you should take him in as a journalist to document the epidemic of homelessness around the world',
#   'CommentCreationTime': '2020-06-22T20:45:40Z',
#   'CommentLikes': 883},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgzNEnIQFDiOliKlOyh4AaABAg',
#   'CommentTitle': "I live in the US and work in emergency psychiatric care primarily with homeless people. It's always hard to find treatment, housing, food, work for them. But this year has been a nightmare. Even the homeless shelters are turning people away. Rehabs are closed to new patients, most places aren't hiring (especially places that employ felons), offices where you get your ID and apply for SSDI are online-only which doesn't help people who don't have a phone. This year has sucked for everyone, and a lot of people have lost their jobs and are scared of what the future will bring. But if you have a safe place to sleep every night, if you have food in your fridge, be grateful. Many people are one bad car accident away from losing their livelihood and their home. If you know where you are going to sleep tonight and if you know that you will have a meal tomorrow, you are okay. Many are not.",
#   'CommentCreationTime': '2020-07-08T04:00:17Z',
#   'CommentLikes': 175},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgzlMkGfHiJGZzSZFHd4AaABAg',
#   'CommentTitle': 'And here people whining about how they have to stay at home! And their life is ruined bcos they cannot go party and club!',
#   'CommentCreationTime': '2020-07-07T21:26:56Z',
#   'CommentLikes': 353},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgxmWHqQzT6els2yg414AaABAg',
#   'CommentTitle': "A very special old farmer saved me from homelessness...and I'll never be able to thank him as much as he deserves.  I grew up in the woods...I spent most of my time homeless in the same place...was near the river, was able to bath in it...had this little Coleman solar panel to charge my phone...my bike, tent...it wasn't all bad, at first.  But it got worse...much worse...I dropped so much weight I was at an all time low of 106 pounds.  But starting when the old farmer took me in...I've since got some medical help, and approved for disability...gained all my weight back...life is getting better, slowly but surely.  I am hoping soon I might be well enough to be able to work again.  I want to be able to give back...like all the people who helped me.",
#   'CommentCreationTime': '2020-06-22T19:12:10Z',
#   'CommentLikes': 253},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgxiWj6-Zi_RTEFSD7d4AaABAg',
#   'CommentTitle': "I've been homeless and no one can imagine the hunger and I thirst. Not to mention just wanting to brush your teeth.  Bless everyone who helps the homeless. You can't imagine their struggles",
#   'CommentCreationTime': '2020-07-04T23:35:55Z',
#   'CommentLikes': 105},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgyqxqWrRo2qwLAhWkJ4AaABAg',
#   'CommentTitle': "Bless these people man. I can't even begin to know what this is like. This is crazy eye opening.",
#   'CommentCreationTime': '2020-06-22T19:35:07Z',
#   'CommentLikes': 773},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'Ugxuwajh0RcAHwUJfBB4AaABAg',
#   'CommentTitle': 'Such an articulate, well spoken man; really makes awful thing he was put in such a situation.',
#   'CommentCreationTime': '2020-06-22T20:15:00Z',
#   'CommentLikes': 428},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgzUhjKCWlV5i5ADGrl4AaABAg',
#   'CommentTitle': 'VICE! Provide links to his film so people can buy it, please!',
#   'CommentCreationTime': '2020-06-22T19:09:46Z',
#   'CommentLikes': 660},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'Ugyj5pL1FUiLP2TFeqN4AaABAg',
#   'CommentTitle': 'God Bless his heart and Protects him and all homeless people. Let’s society help out because it can be any of us . You never know.',
#   'CommentCreationTime': '2020-06-22T21:28:03Z',
#   'CommentLikes': 481},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgzPneo5LlB87FEGxD54AaABAg',
#   'CommentTitle': 'Homelessness changes a person forever. I am grateful for my time on the street.',
#   'CommentCreationTime': '2020-06-26T07:41:59Z',
#   'CommentLikes': 30},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'Ugw8wLtZh1N_q_Qi3hp4AaABAg',
#   'CommentTitle': 'God Bless him...our homeless and elderly the most vulnerable..',
#   'CommentCreationTime': '2020-06-22T19:09:55Z',
#   'CommentLikes': 330},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgxHkTlhZrU8nqaPMiJ4AaABAg',
#   'CommentTitle': 'Just to be able to comment on this video from the comfort of home \nIs a blessing. Sometimes all take certain things for granted ✌🏿',
#   'CommentCreationTime': '2020-06-22T19:45:45Z',
#   'CommentLikes': 126},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'Ugy38NxdA3TxA9zopCF4AaABAg',
#   'CommentTitle': 'Prayers to all those effected by homelessness... That could easily be any of us',
#   'CommentCreationTime': '2020-07-12T02:32:49Z',
#   'CommentLikes': 26},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgzMRIAGhe_w1H8ew994AaABAg',
#   'CommentTitle': 'this moment i love my parents for all they gave to me.',
#   'CommentCreationTime': '2020-06-23T01:03:56Z',
#   'CommentLikes': 57},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'Ugyzxat0U4rolr8lMq54AaABAg',
#   'CommentTitle': 'I did almost 18 months being homeless in Boston MA.USA And finally got myself in a studio apartment.i have health problems so I understand what you mean about being sick on the street is bad very very bad. God bless us all we are all gods children.',
#   'CommentCreationTime': '2020-07-16T17:13:55Z',
#   'CommentLikes': 22},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgwjjUH2vmwU2lRrRSh4AaABAg',
#   'CommentTitle': 'Your honesty, and humbleness will take you places.  I hope you will find your place in society again.  We all have our struggles, some more , or less than others.  I do hope all works out well for you and all the homeless people in our world.',
#   'CommentCreationTime': '2020-06-22T19:44:39Z',
#   'CommentLikes': 33},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'Ugxc1ToHBK9HPfs6twZ4AaABAg',
#   'CommentTitle': 'Thank you so much for sharing with such clarity and honesty',
#   'CommentCreationTime': '2020-06-22T19:04:49Z',
#   'CommentLikes': 84},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgzNLjM3fJC8vOPoNap4AaABAg',
#   'CommentTitle': '*An imbalance between rich and poor is the oldest and most fatal ailment of all republics.*\nPlutarch 💔😢',
#   'CommentCreationTime': '2020-06-22T20:33:43Z',
#   'CommentLikes': 140},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgzWovkWCcuL8oy_YCx4AaABAg',
#   'CommentTitle': 'Thank you Vice and David for availing yourselves to share regarding the struggles we often take for granted. As a Malaysian, and in my early naiveness, I had the impression that the city (ex. Kuala Lumpur) would be the place where dreams were made, an environment where zero poverty and homelessness exist. Little did I know that there were countless homeless people especially in the heart of the city who will be gathering there to find shelter in the late nights when the major public has gone to sleep peacefully at home.\nI thank God for all the non profits and social entrepreneurs that are doing all they can in supporting those in need especially during seasons of social distancing. I hope all of us including myself will continue to do what we can to also help out with our talents, skills, times, etc in different shapes and forms. Stay M.A.D. (making a difference) and God Bless. all the way.',
#   'CommentCreationTime': '2020-06-24T13:45:28Z',
#   'CommentLikes': 2},
#  {'channel': 'Vice',
#   'id': 'D669qcb7GGI',
#   'title': 'The Challenges of Being Homeless During a Pandemic',
#   'keyword': 'Homelessness',
#   'published_at': '2020-06-22T19:00:02Z',
#   'VideoViews': '475681',
#   'VideoId': 'D669qcb7GGI',
#   'CommentId': 'UgytLi9_CGRjUR3UyMJ4AaABAg',
#   'CommentTitle': "I am jobless but I still have a roof over my head and my heart goes out to the homeless out there. Society as a whole has definitely failed us. I will do my best to help out and donate whatever savings I have to the right people and make sure I can make a small change. God bless everyone that is suffering out there. Hang in there and don't lose hope.",
#   'CommentCreationTime': '2020-07-24T13:23:22Z',
#   'CommentLikes': 8},
#  {'channel': 'Vice',
#   'id': '5cm9ELLR8ds',
#   'title': 'The Deadliest Cartel in Mexico | The War on Drugs',
#   'keyword': 'Mexico',
#   'published_at': '2021-05-31T19:00:01Z',
#   'VideoViews': '2132694',
#   'VideoId': '5cm9ELLR8ds',
#   'CommentId': 'UgyTb7DP3pQwGvj-2rl4AaABAg',
#   'CommentTitle': 'WATCH NEXT: Narco-Propaganda is Fuelling Mexico’s Drug War - https://youtu.be/pZH9ZYFU26U',
#   'CommentCreationTime': '2023-03-30T06:34:23Z',
#   'CommentLikes': 19},
#  {'channel': 'Vice',
#   'id': '5cm9ELLR8ds',
#   'title': 'The Deadliest Cartel in Mexico | The War on Drugs',
#   'keyword': 'Mexico',
#   'published_at': '2021-05-31T19:00:01Z',
#   'VideoViews': '2132694',
#   'VideoId': '5cm9ELLR8ds',
#   'CommentId': 'UgxyYXNmLta3Liv8ofV4AaABAg',
#   'CommentTitle': 'You know its gonna be interesting when you have to click confirm THREE times',
#   'CommentCreationTime': '2021-06-05T07:55:02Z',
#   'CommentLikes': 10426},
#  {'channel': 'Vice',
#   'id': '5cm9ELLR8ds',
#   'title': 'The Deadliest Cartel in Mexico | The War on Drugs',
#   'keyword': 'Mexico',
#   'published_at': '2021-05-31T19:00:01Z',
#   'VideoViews': '2132694',
#   'VideoId': '5cm9ELLR8ds',
#   'CommentId': 'UgzRhflnqd9tVA3vFNV4AaABAg',
#   'CommentTitle': 'Living in Texas our neighbors were arrested for money laundering and cartel activities.... Honestly they were the nicest  neighbors you could ask for. Total shocker when they were arrested',
#   'CommentCreationTime': '2021-06-19T08:30:12Z',
#   'CommentLikes': 4552},
#  {'channel': 'Vice',
#   'id': '5cm9ELLR8ds',
#   'title': 'The Deadliest Cartel in Mexico | The War on Drugs',
#   'keyword': 'Mexico',
#   'published_at': '2021-05-31T19:00:01Z',
#   'VideoViews': '2132694',
#   'VideoId': '5cm9ELLR8ds',
#   'CommentId': 'UgzLQwIZV0YhWdZZTEx4AaABAg',
#   'CommentTitle': 'My brother was murdered in Mexico 2 years ago by the cartel. My family doesn’t know exactly what happened, and corrupt police has stopped my us from finding out.\nJust knowing that all of this is happening in such a beautiful country hurts so much. It makes me lose a little more hope in humanity.',
#   'CommentCreationTime': '2021-06-11T05:54:12Z',
#   'CommentLikes': 1546},
#  {'channel': 'Vice',
#   'id': '5cm9ELLR8ds',
#   'title': 'The Deadliest Cartel in Mexico | The War on Drugs',
#   'keyword': 'Mexico',
#   'published_at': '2021-05-31T19:00:01Z',
#   'VideoViews': '2132694',
#   'VideoId': '5cm9ELLR8ds',
#   'CommentId': 'UgwLPWepzzIvpeAgyBF4AaABAg',
#   'CommentTitle': 'I knew this would be about Los Zetas, trained by US special forces to combat cartels, who ended up becoming their own cartel lol',
#   'CommentCreationTime': '2021-05-31T19:42:22Z',
#   'CommentLikes': 3558},
#  {'channel': 'Vice',
#   'id': '5cm9ELLR8ds',
#   'title': 'The Deadliest Cartel in Mexico | The War on Drugs',
#   'keyword': 'Mexico',
#   'published_at': '2021-05-31T19:00:01Z',
#   'VideoViews': '2132694',
#   'VideoId': '5cm9ELLR8ds',
#   'CommentId': 'Ugy1DLxtpKiS6u6KMdJ4AaABAg',
#   'CommentTitle': 'A family member of mine was taken from the cartels. It’s shatters me to know that this is a real problem that can affect people rlly bad . It hurts to know that he might never come back',
#   'CommentCreationTime': '2021-11-18T00:51:48Z',
#   'CommentLikes': 293},
#  {'channel': 'Vice',
#   'id': '5cm9ELLR8ds',
#   'title': 'The Deadliest Cartel in Mexico | The War on Drugs',
#   'keyword': 'Mexico',
#   'published_at': '2021-05-31T19:00:01Z',
#   'VideoViews': '2132694',
#   'VideoId': '5cm9ELLR8ds',
#   'CommentId': 'Ugyuqa9LdM-CvpgX50F4AaABAg',
#   'CommentTitle': "The trauma that can come from seeing headless/dismembered/tortured/hanging victims is horrific.\nA walk around the neighborhood would be awful, knowing it's only a matter of time before you see more brutality. \nI feel for all affected.",
#   'CommentCreationTime': '2021-06-06T12:15:35Z',
#   'CommentLikes': 4282},
#  {'channel': 'Vice',
#   'id': '5cm9ELLR8ds',
#   'title': 'The Deadliest Cartel in Mexico | The War on Drugs',
#   'keyword': 'Mexico',
#   'published_at': '2021-05-31T19:00:01Z',
#   'VideoViews': '2132694',
#   'VideoId': '5cm9ELLR8ds',
#   'CommentId': 'Ugwy9qhcEIPyl5qj8lZ4AaABAg',
#   'CommentTitle': "Imagine walking outside your house and seeing decapitated human heads on the street.... I take it for granted, but thank goodness my family and I are from and live in  a country where our main issue is trying to decide what cuisine we're having for dinner.",
#   'CommentCreationTime': '2021-06-01T00:35:18Z',
#   'CommentLikes': 2391},
#  {'channel': 'Vice',
#   'id': '5cm9ELLR8ds',
#   'title': 'The Deadliest Cartel in Mexico | The War on Drugs',
#   'keyword': 'Mexico',
#   'published_at': '2021-05-31T19:00:01Z',
#   'VideoViews': '2132694',
#   'VideoId': '5cm9ELLR8ds',
#   'CommentId': 'UgyfnERwoisXkr5zBPd4AaABAg',
#   'CommentTitle': 'Growing up in Mexico every summer I remember how we could go on bike rides at night throughout the streets. How we could have family reunions at the family ranches. How we could walk to the store down the street. I remember when my mom would tell me to stop doing that. I could never understand why and what was happening. I couldn’t go to Mexico anymore, and it broke my heart. After watching this video, it’s heartbreaking to see that this is what Mexico is. I’m terrified to go down there even though my grandparents only live one hour away from the border.',
#   'CommentCreationTime': '2021-06-05T17:00:45Z',
#   'CommentLikes': 1672},
#  {'channel': 'Vice',
#   'id': '5cm9ELLR8ds',
#   'title': 'The Deadliest Cartel in Mexico | The War on Drugs',
#   'keyword': 'Mexico',
#   'published_at': '2021-05-31T19:00:01Z',
#   'VideoViews': '2132694',
#   'VideoId': '5cm9ELLR8ds',
# ...
#   'CommentId': 'UgwOBnXg7UfRp39SrVN4AaABAg',
#   'CommentTitle': 'Imagine publishing a sob story about a convicted rapist.\nThat is not very cash money of you Vice.',
#   'CommentCreationTime': '2021-01-31T17:01:24Z',
#   'CommentLikes': 145},
#  {'channel': 'Vice',
#   'id': 'vaTnP5AgQ_g',
#   'title': "'Never Going Back:' Releasing Inmates During a Pandemic",
#   'keyword': 'Pandemics',
#   'published_at': '2021-01-31T16:00:31Z',
#   'VideoViews': '370474',
#   'VideoId': 'vaTnP5AgQ_g',
#   'CommentId': 'Ugy_z48s9sE0KZ4-4tV4AaABAg',
#   'CommentTitle': '"Don\'t setup an unrealistic expectation that people that come into your life are going to love you genuinely"',
#   'CommentCreationTime': '2021-02-01T18:04:05Z',
#   'CommentLikes': 10},
#  {'channel': 'Vice',
#   'id': 'vaTnP5AgQ_g',
#   'title': "'Never Going Back:' Releasing Inmates During a Pandemic",
#   'keyword': 'Pandemics',
#   'published_at': '2021-01-31T16:00:31Z',
#   'VideoViews': '370474',
#   'VideoId': 'vaTnP5AgQ_g',
#   'CommentId': 'UgxACXUecGspCTjjcRl4AaABAg',
#   'CommentTitle': 'Finally something that isn’t blocked in my country',
#   'CommentCreationTime': '2021-01-31T16:08:30Z',
#   'CommentLikes': 180},
#  {'channel': 'Vice',
#   'id': 'vaTnP5AgQ_g',
#   'title': "'Never Going Back:' Releasing Inmates During a Pandemic",
#   'keyword': 'Pandemics',
#   'published_at': '2021-01-31T16:00:31Z',
#   'VideoViews': '370474',
#   'VideoId': 'vaTnP5AgQ_g',
#   'CommentId': 'Ugww_piMUdwdfxOVvjB4AaABAg',
#   'CommentTitle': 'His friends name is Cedar... and he works for his dads tree business. That made me laugh, sorry.',
#   'CommentCreationTime': '2021-01-31T21:41:25Z',
#   'CommentLikes': 141},
#  {'channel': 'Vice',
#   'id': 'vaTnP5AgQ_g',
#   'title': "'Never Going Back:' Releasing Inmates During a Pandemic",
#   'keyword': 'Pandemics',
#   'published_at': '2021-01-31T16:00:31Z',
#   'VideoViews': '370474',
#   'VideoId': 'vaTnP5AgQ_g',
#   'CommentId': 'UgxBB-AB3j21y6UKyyt4AaABAg',
#   'CommentTitle': 'All I have is 2 words to change to future youth incarnation: Education, Parenting.',
#   'CommentCreationTime': '2021-01-31T18:42:46Z',
#   'CommentLikes': 70},
#  {'channel': 'Vice',
#   'id': 'TgVwCJ2J6pQ',
#   'title': 'Daily VICE Canada: Quebec Weed Industry, Skull Store, Climate Activist Arrest',
#   'keyword': 'Climate',
#   'published_at': '2015-12-07T17:31:48Z',
#   'VideoViews': '9128',
#   'VideoId': 'TgVwCJ2J6pQ',
#   'CommentId': 'Ugg9cq_7jo7eBHgCoAEC',
#   'CommentTitle': "Great contents , informative, to the point and fast paced. I get bored fast. I'll try another 2 vlogs before I sub..I'll see then. I hope its the same.",
#   'CommentCreationTime': '2016-07-10T05:42:19Z',
#   'CommentLikes': 0},
#  {'channel': 'Vice',
#   'id': 'TgVwCJ2J6pQ',
#   'title': 'Daily VICE Canada: Quebec Weed Industry, Skull Store, Climate Activist Arrest',
#   'keyword': 'Climate',
#   'published_at': '2015-12-07T17:31:48Z',
#   'VideoViews': '9128',
#   'VideoId': 'TgVwCJ2J6pQ',
#   'CommentId': 'UggfL7L-bcADW3gCoAEC',
#   'CommentTitle': 'Anybody hear the owner of facebook is donating 60 billion',
#   'CommentCreationTime': '2015-12-07T17:50:19Z',
#   'CommentLikes': 0},
#  {'channel': 'Vice',
#   'id': 'TgVwCJ2J6pQ',
#   'title': 'Daily VICE Canada: Quebec Weed Industry, Skull Store, Climate Activist Arrest',
#   'keyword': 'Climate',
#   'published_at': '2015-12-07T17:31:48Z',
#   'VideoViews': '9128',
#   'VideoId': 'TgVwCJ2J6pQ',
#   'CommentId': 'UghWKFJLIvM4DngCoAEC',
#   'CommentTitle': '15 $ what is in that weed ? Crack ?',
#   'CommentCreationTime': '2015-12-07T17:56:39Z',
#   'CommentLikes': 1},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgwhgpMeh3xqak0zmt14AaABAg',
#   'CommentTitle': "If a dude is making $60k designing and making firearms, he's a gunsmith, not a dishwasher.",
#   'CommentCreationTime': '2020-04-19T19:43:48Z',
#   'CommentLikes': 5074},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'Ugzea-TOVpltJ3le0Jd4AaABAg',
#   'CommentTitle': "I don't know why, but it's really calming to see an old person who have perfected their craft talk about it. I really admire it.",
#   'CommentCreationTime': '2021-03-13T16:46:24Z',
#   'CommentLikes': 634},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgxIsB-6AvufMO_FKdd4AaABAg',
#   'CommentTitle': 'Not a gunsmith, or a dishwasher...This man is an artist. What a blessing it is to have people still around that metalwork the traditional way.',
#   'CommentCreationTime': '2021-01-15T21:19:52Z',
#   'CommentLikes': 518},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgzM2OzatIX3OO6brFZ4AaABAg',
#   'CommentTitle': 'Naked Snake: “The engravings give you no tactical advantage whatsoever.”\n\nArturo: “Y me lo tomé personalmente.”',
#   'CommentCreationTime': '2021-09-05T21:33:32Z',
#   'CommentLikes': 372},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgxoMwFKtdvvh4_0PG54AaABAg',
#   'CommentTitle': 'This man is not a dishwasher, he is an engraving artist that just happens to help out the family business.',
#   'CommentCreationTime': '2021-05-27T20:14:05Z',
#   'CommentLikes': 92},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'Ugx1ucDsvdiRwpTZtoR4AaABAg',
#   'CommentTitle': "Man...it's a crying shame that there literally master artisans all around us we just don't know. I really hope that someone out there continues this man's teachings. His work is truly mind blowing",
#   'CommentCreationTime': '2022-04-02T01:37:06Z',
#   'CommentLikes': 191},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'Ugw2MwXSwjhKhs3J3jZ4AaABAg',
#   'CommentTitle': 'He said "My occupation is to craft with metal" AND "in my *SPARE TIME* I help my son with his business" and Vice titled this video \'This dishwasher charges 60k for custom guns\'. I can\'t believe you Vice.',
#   'CommentCreationTime': '2020-05-24T06:45:41Z',
#   'CommentLikes': 2319},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgzMCbVj2OGdnEu_4Hh4AaABAg',
#   'CommentTitle': 'It’s unfortunate that none of his children wanted to continue his work, I’d be honored to have a parent with those type of skills and not only continue his legacy but do my best to perfect it',
#   'CommentCreationTime': '2020-11-14T00:15:05Z',
#   'CommentLikes': 1348},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgwUi_XWiUgVAHZ4Kv94AaABAg',
#   'CommentTitle': 'I wish I could learn from this man. Simple, Humble and a master in what he does.',
#   'CommentCreationTime': '2020-12-04T00:15:59Z',
#   'CommentLikes': 86},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgyVN0Iw0mQz_sQNjD54AaABAg',
#   'CommentTitle': 'I used to work for this place, my very first job. It was an honor to work for them and I learned a lot about how to be myself from them. Very happy for what they’ve been able to accomplish from a tiny business in Fort Worth to a huge staple in Dallas.',
#   'CommentCreationTime': '2022-01-08T05:07:37Z',
#   'CommentLikes': 101},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'Ugy47RPikoeP912E3j14AaABAg',
#   'CommentTitle': 'Me and my dad were dishwashers too. this video touched my heart. Blessings from around the world💯',
#   'CommentCreationTime': '2020-11-28T01:30:53Z',
#   'CommentLikes': 47},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgwrUyq7snyvGoBIpUh4AaABAg',
#   'CommentTitle': 'My god, \nIm from DFW. born here. Been here my whole life, and Ive never heard of this man. What an absolute OG. So sad that nobody is going to carry on this beautiful, wonderful and priceless artform. We truely are regressing as a society and species.',
#   'CommentCreationTime': '2022-05-21T04:45:13Z',
#   'CommentLikes': 17},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgxgnRRALhXSpESPPDt4AaABAg',
#   'CommentTitle': 'It’s disrespectful to call him a dishwasher he’s an engraver that’s helps his sons restaurant',
#   'CommentCreationTime': '2020-06-01T04:14:27Z',
#   'CommentLikes': 7707},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgzjCRU8mRWW6eGzC9V4AaABAg',
#   'CommentTitle': "The love that this craftsman has for his work and his family is very admirable. With hard-earned money, he was able to fulfill his wife's dream of having a Restaurant, and on top of that, he respects his son's decision of running the Family Restaurant. Very respectable!",
#   'CommentCreationTime': '2021-09-11T05:40:51Z',
#   'CommentLikes': 24},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgwnSScsi-h-VuNh30l4AaABAg',
#   'CommentTitle': 'This man is incredible he has such patience to carefully engrave a pattern after hours and hours',
#   'CommentCreationTime': '2020-12-07T22:42:17Z',
#   'CommentLikes': 21},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgwQBVIWGYKihBZ4w6p4AaABAg',
#   'CommentTitle': 'Found a typo in the title, should be: "custom gun artist enjoys washing dishes".',
#   'CommentCreationTime': '2021-05-26T21:47:26Z',
#   'CommentLikes': 23},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgyNORzRMt9iNLQQ2jJ4AaABAg',
#   'CommentTitle': 'this guy is 100% good vibes. I hope the world smiles on him in return!',
#   'CommentCreationTime': '2022-05-24T10:57:07Z',
#   'CommentLikes': 3},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgyAzpr1cjMy0DaaO-V4AaABAg',
#   'CommentTitle': 'What a chad of a man. Unmatched artistry. I hope he’s still doing these engravings today.',
#   'CommentCreationTime': '2022-03-30T04:27:14Z',
#   'CommentLikes': 5},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgxmxKb-hgqtombfTp94AaABAg',
#   'CommentTitle': 'A gunsmith who washes dishes on his down time. Not the other way around',
#   'CommentCreationTime': '2020-02-09T19:08:42Z',
#   'CommentLikes': 12231},
#  {'channel': 'Vice',
#   'id': 'UnETVMI4tY8',
#   'title': 'This Dishwasher Charges $60K to Design Custom Guns',
#   'keyword': 'Gun',
#   'published_at': '2020-02-09T16:00:08Z',
#   'VideoViews': '7498318',
#   'VideoId': 'UnETVMI4tY8',
#   'CommentId': 'UgxhIYoLMd-p4ivkxvJ4AaABAg',
#   'CommentTitle': "What I would give just to sit and watch this man work on a weapon. \nHe has a gift for what he loves to do.... yes he is a true artist,  but yet humble enough to help out at his son's Restaurant.  Even if it's to wash dishes.  Noticed how he takes great pride as he washes the plate. My Dad once told me as I was grown up and started working. He said Son take Pride in what ever you do in life , even if it's flipping burgers.  I became a Histology technician I assisted with autopsies for 13 1/2 yrs. I took Great Pride and Respect when I  handled each case. Cause that was someone's loved one....",
#   'CommentCreationTime': '2020-12-30T20:48:09Z',
#   'CommentLikes': 15},
#  {'channel': 'Vice',
#   'id': '4qePOEBm9Aw',
#   'title': 'Addicted While Homeless | DOPESICK NATION (Episode 3)',
#   'keyword': 'Homelessness',
#   'published_at': '2021-08-07T14:59:46Z',
#   'VideoViews': '453423',
#   'VideoId': '4qePOEBm9Aw',
#   'CommentId': 'UgwLUiURv7z8gABhumh4AaABAg',
#   'CommentTitle': 'When she said, “fentanyl kills people but it doesn’t kill me”, that’s the exact mentality my friend had, “I’m invincible” she would say. She passed away at 16, would have been 22 today. No one is safe.',
#   'CommentCreationTime': '2021-08-13T23:49:22Z',
#   'CommentLikes': 897},
#  {'channel': 'Vice',
#   'id': '4qePOEBm9Aw',
#   'title': 'Addicted While Homeless | DOPESICK NATION (Episode 3)',
#   'keyword': 'Homelessness',
#   'published_at': '2021-08-07T14:59:46Z',
#   'VideoViews': '453423',
#   'VideoId': '4qePOEBm9Aw',
#   'CommentId': 'UgzM-ict_R1Waqz4dD14AaABAg',
#   'CommentTitle': 'Trying to get an addict help is draining asf. Hats off to the ones that do it everyday.',
#   'CommentCreationTime': '2021-08-12T14:01:41Z',
#   'CommentLikes': 444},
#  {'channel': 'Vice',
#   'id': '4qePOEBm9Aw',
#   'title': 'Addicted While Homeless | DOPESICK NATION (Episode 3)',
#   'keyword': 'Homelessness',
#   'published_at': '2021-08-07T14:59:46Z',
#   'VideoViews': '453423',
#   'VideoId': '4qePOEBm9Aw',
#   'CommentId': 'UgzVJYqWFkskcxqAME94AaABAg',
#   'CommentTitle': 'Almost 80 days sober today, fent is a hell of a drug',
#   'CommentCreationTime': '2021-08-08T02:22:20Z',
#   'CommentLikes': 783},
#  {'channel': 'Vice',
#   'id': '4qePOEBm9Aw',
#   'title': 'Addicted While Homeless | DOPESICK NATION (Episode 3)',
#   'keyword': 'Homelessness',
#   'published_at': '2021-08-07T14:59:46Z',
#   'VideoViews': '453423',
#   'VideoId': '4qePOEBm9Aw',
#   'CommentId': 'UgyuR8ZaN6HmgXQxu7V4AaABAg',
#   'CommentTitle': "The way allie smiles when she sees frank is everything. That's a friendship we all need, ESPECIALLY in recovery.",
#   'CommentCreationTime': '2021-09-27T14:26:05Z',
#   'CommentLikes': 127},
#  ...]

# %%
vice_comments_df = pd.DataFrame(vice_result)

vice_comments_df.head()
vice_comments_df.shape
# Out:
# (1938, 11)

# %% [markdown]
# ### Vox

# %%
vox_vid_info = []

for category, keywords in keyword_lists.items():
    print(f"Fetching videos for category: {category}")
    vid_info = keyword_videos("UULXo7UDZvByw2ixzpQCufnA", keywords, "Vox", 10)
    print(f"Found {len(vid_info)} videos for category {category}")
    vox_vid_info.append(vid_info)
# Out:
# Fetching videos for category: isis
# Found 9 videos for category isis
# Fetching videos for category: guns
# Found 11 videos for category guns
# Fetching videos for category: immigration
# Found 11 videos for category immigration
# Fetching videos for category: economy
# Found 4 videos for category economy
# Fetching videos for category: healthcare
# Found 11 videos for category healthcare
# Fetching videos for category: socioeco
# Found 9 videos for category socioeco
# Fetching videos for category: abortion
# Found 10 videos for category abortion
# Fetching videos for category: climate
# Found 11 videos for category climate

# %%
vox_vid_info[3]
# Out:
# [{'channel': 'Vox',
#   'id': '9kaSKoBb7ew',
#   'title': 'High female employment rates in Europe mean more babies #shorts',
#   'keyword': 'Employment',
#   'published_at': '2023-08-02T16:31:01Z',
#   'VideoViews': '243267'},
#  {'channel': 'Vox',
#   'id': 'ualUPur6iks',
#   'title': "Why it's so hard to get unemployment benefits",
#   'keyword': 'Unemployed',
#   'published_at': '2020-06-10T12:00:33Z',
#   'VideoViews': '550201'},
#  {'channel': 'Vox',
#   'id': 'P81i66_tLlU',
#   'title': 'How marketers target your nose',
#   'keyword': 'Market',
#   'published_at': '2018-09-26T12:00:03Z',
#   'VideoViews': '493366'},
#  {'channel': 'Vox',
#   'id': 'GWH5vyi3lTk',
#   'title': 'How the economy shapes our love lives',
#   'keyword': 'Economy',
#   'published_at': '2018-02-22T13:00:01Z',
#   'VideoViews': '836379'},
#  {'channel': 'Vox',
#   'id': 'Cjzvvgmg1NU',
#   'title': 'Why the market for skin whitening is growing',
#   'keyword': 'Market',
#   'published_at': '2018-01-04T13:00:02Z',
#   'VideoViews': '1709622'},
#  {'channel': 'Vox',
#   'id': 'RBKhpV6MYto',
#   'title': 'Obama on American politics and economy: the extended Vox conversation',
#   'keyword': 'Economy',
#   'published_at': '2015-02-09T11:24:04Z',
#   'VideoViews': '263747'}]

# %%
vox_vid_ids = set()

# Extracting all ids
for sublist in vox_vid_info:
    for video in sublist:
        vox_vid_ids.add(video['id'])
        
len(vox_vid_ids)
# Out:
# 74

# %%
vox_comments = []

for ids in vox_vid_ids:
    vox_comm = get_vid_comments(ids, 30)
    vox_comments.append(vox_comm)

# %%
vox_comment_count = defaultdict(int)

for video_comments in vox_comments:
    for comment in video_comments:
        video_id = comment['VideoId']
        vox_comment_count[video_id] += 1

for video_id, count in vox_comment_count.items():
    print(f"Video ID: {video_id}, Number of Comments: {count}")
# Out:
# Video ID: 4Ltr7x8nO2M, Number of Comments: 30
# Video ID: _e0VofLJTIk, Number of Comments: 30
# Video ID: ssSIUVPjDns, Number of Comments: 30
# Video ID: Z9gQLELtbhg, Number of Comments: 30
# Video ID: HJ034SvB16E, Number of Comments: 30
# Video ID: tC0IMn8lsdc, Number of Comments: 30
# Video ID: yeaQUhAOdtk, Number of Comments: 30
# Video ID: LJjo1kJW6To, Number of Comments: 30
# Video ID: qcJeOphUtek, Number of Comments: 30
# Video ID: Al0rBxHuVk4, Number of Comments: 30
# Video ID: nUnJQWO4YJY, Number of Comments: 30
# Video ID: BB3qNWRaxGE, Number of Comments: 30
# Video ID: qdjArlHB8k8, Number of Comments: 30
# Video ID: H7tUEWNL7lg, Number of Comments: 30
# Video ID: sv0dQfRRrEQ, Number of Comments: 30
# Video ID: yzDjjUAt3zc, Number of Comments: 30
# Video ID: 3bIvqS7gnQo, Number of Comments: 30
# Video ID: pTwPHuE_HrU, Number of Comments: 30
# Video ID: -S_f-huz-EU, Number of Comments: 30
# Video ID: t6V9i8fFADI, Number of Comments: 30
# Video ID: iKHl__BEsD0, Number of Comments: 30
# Video ID: k1vE_LVBx4s, Number of Comments: 30
# Video ID: 0NIZZNo4YMY, Number of Comments: 30
# Video ID: FBwFJeleth0, Number of Comments: 30
# Video ID: VIY0FF3TE_E, Number of Comments: 30
# Video ID: _0TCrGtTEQM, Number of Comments: 30
# Video ID: xiiHjrewXNI, Number of Comments: 30
# Video ID: LRP2Vw9ix-s, Number of Comments: 30
# Video ID: ylLTMYt24lA, Number of Comments: 30
# Video ID: F6NKbQzo4aE, Number of Comments: 30
# Video ID: mvA9gs5gxNY, Number of Comments: 30
# Video ID: r2fxJI_cP58, Number of Comments: 30
# Video ID: RWSaceaSpRI, Number of Comments: 30
# Video ID: 6yiQAmgI5s4, Number of Comments: 30
# Video ID: Bzuk13Ftxgo, Number of Comments: 30
# Video ID: SCl6s68_sGY, Number of Comments: 30
# Video ID: 2ty2J0s2W0c, Number of Comments: 30
# Video ID: riWh6Ljgu_M, Number of Comments: 30
# Video ID: hwuujiHvduc, Number of Comments: 30
# Video ID: EyAdby3hMRM, Number of Comments: 30
# Video ID: 1O_YHxd_HWQ, Number of Comments: 30
# Video ID: ol6xKUkYyhM, Number of Comments: 30
# Video ID: iMiQeS1XywA, Number of Comments: 30
# Video ID: qp5CEcIyk94, Number of Comments: 30
# Video ID: 1xbt0ACMbiA, Number of Comments: 30
# Video ID: oRUjKZOhV6E, Number of Comments: 30
# Video ID: utUOJ64X7u0, Number of Comments: 30
# Video ID: mBoAMsif9Gk, Number of Comments: 30
# Video ID: 18lf1kpBgRk, Number of Comments: 30
# Video ID: K3odScka55A, Number of Comments: 30
# Video ID: 6SPzfGFOJ84, Number of Comments: 30
# Video ID: K5E8eeyAQLM, Number of Comments: 30
# Video ID: FoTE-6wWxXs, Number of Comments: 30
# Video ID: Zj8HyeixuqM, Number of Comments: 23
# Video ID: Ry5jTjBhZpA, Number of Comments: 30
# Video ID: hIxiXHEBrYQ, Number of Comments: 30
# Video ID: FHQqKWxF1Tg, Number of Comments: 30
# Video ID: qwqm8T_IFzk, Number of Comments: 30
# Video ID: GWH5vyi3lTk, Number of Comments: 30
# Video ID: 2OVMYUFWoaU, Number of Comments: 30
# Video ID: pzmO6RWy1v8, Number of Comments: 30
# Video ID: RCLQREWIwyA, Number of Comments: 30
# Video ID: cWHuWxeH9gU, Number of Comments: 30
# Video ID: RBKhpV6MYto, Number of Comments: 30
# Video ID: ENw2y0ek1Jg, Number of Comments: 30
# Video ID: UI4g_amOTSg, Number of Comments: 30
# Video ID: tvM067ITfe4, Number of Comments: 30
# Video ID: 3lrJYTsKdUM, Number of Comments: 30
# Video ID: tfZYfYbONmI, Number of Comments: 30
# Video ID: c5ZtB8nLRdU, Number of Comments: 30
# Video ID: 80OFcp02_r0, Number of Comments: 14
# Video ID: J1wJuXjrxDU, Number of Comments: 13
# Video ID: MbDIYj7IIQo, Number of Comments: 30
# Video ID: qXdjt8ZBQbE, Number of Comments: 30

# %%
# Create a dict to map video ids to their corresponding details
vox_vid_details = {vid['id']: vid for sublist in vox_vid_info for vid in sublist}

# Comebine vid detail with comments
vox_result = []

for sublist in vox_comments:
    for item in sublist:
        vid_id = item['VideoId']
        if vid_id in vox_vid_details:
            details = vox_vid_details[vid_id].copy()
            details.update(item)
            vox_result.append(details)

# %%
len(vox_result)
# Out:
# 2180

# %%
vox_comments_df = pd.DataFrame(vox_result)

vox_comments_df.head()
vox_comments_df.shape
# Out:
# (2180, 11)

# %% [markdown]
# ### MSNBC

# %%
msnbc_vid_info = []

# %%
for category, keywords in keyword_lists2.items():
    print(f"Fetching videos for category: {category}")
    vid_info = keyword_videos("UUaXkIU1QidjPwiAYu6GcHjg", keywords, "MSNBC", 10)
    print(f"Found {len(vid_info)} videos for category {category}")
    msnbc_vid_info.append(vid_info)
# Out:
# Fetching videos for category: guns
# Found 11 videos for category guns
# Fetching videos for category: immigration
# Found 11 videos for category immigration
# Fetching videos for category: healthcare
# Found 11 videos for category healthcare
# Fetching videos for category: climate
# Found 11 videos for category climate

# %%
for category, keywords in keyword_isis.items():
    print(f"Fetching videos for category: {category}")
    vid_info = keyword_videos("UUaXkIU1QidjPwiAYu6GcHjg", keywords, "MSNBC", 24)
    print(f"Found {len(vid_info)} videos for category {category}")
    msnbc_vid_info.append(vid_info)
# Out:
# Fetching videos for category: isis
# Found 6 videos for category isis

# %%
for category, keywords in keyword_economy.items():
    print(f"Fetching videos for category: {category}")
    vid_info = keyword_videos("UUaXkIU1QidjPwiAYu6GcHjg", keywords, "MSNBC", 26)
    print(f"Found {len(vid_info)} videos for category {category}")
    msnbc_vid_info.append(vid_info)
# Out:
# Fetching videos for category: economy
# Found 27 videos for category economy

# %%
for category, keywords in keyword_socioeco.items():
    print(f"Fetching videos for category: {category}")
    vid_info = keyword_videos("UUaXkIU1QidjPwiAYu6GcHjg", keywords, "MSNBC", 13)
    print(f"Found {len(vid_info)} videos for category {category}")
    msnbc_vid_info.append(vid_info)
# Out:
# Fetching videos for category: socioeco
# Found 14 videos for category socioeco

# %%
for category, keywords in keyword_abortion.items():
    print(f"Fetching videos for category: {category}")
    vid_info = keyword_videos("UUaXkIU1QidjPwiAYu6GcHjg", keywords, "MSNBC", 16)
    print(f"Found {len(vid_info)} videos for category {category}")
    msnbc_vid_info.append(vid_info)
# Out:
# Fetching videos for category: climate
# Found 17 videos for category climate

# %%
msnbc_vid_ids = set()

# Extracting all ids
for sublist in msnbc_vid_info:
    for video in sublist:
        msnbc_vid_ids.add(video['id'])
        
len(msnbc_vid_ids)
# Out:
# 96

# %%
msnbc_comments = []

for ids in msnbc_vid_ids:
    msnbc_comm = get_vid_comments(ids, 30)
    msnbc_comments.append(msnbc_comm)

# %%
msnbc_comment_count = defaultdict(int)

for video_comments in msnbc_comments:
    for comment in video_comments:
        video_id = comment['VideoId']
        msnbc_comment_count[video_id] += 1

print("Number of comments per videoId:")

for video_id, count in msnbc_comment_count.items():
    print(f"Video ID: {video_id}, Number of Comments: {count}")
# Out:
# Number of comments per videoId:
# Video ID: SVxPp2POkCY, Number of Comments: 30
# Video ID: L3ogH6j7CaI, Number of Comments: 30
# Video ID: 1ltzfeFeiP4, Number of Comments: 30
# Video ID: mUutMIoBuco, Number of Comments: 30
# Video ID: FPK35AVH8BQ, Number of Comments: 30
# Video ID: jesO90gunFs, Number of Comments: 30
# Video ID: yTFGRCL_ZTc, Number of Comments: 30
# Video ID: colxgYIy4mo, Number of Comments: 30
# Video ID: BEanahjUQhI, Number of Comments: 30
# Video ID: lgRP_w4CgBw, Number of Comments: 30
# Video ID: SU9avQSjJrM, Number of Comments: 30
# Video ID: 3qiJp65MDBI, Number of Comments: 30
# Video ID: LZRgMwS7B8o, Number of Comments: 30
# Video ID: DnpgzhZRwPE, Number of Comments: 30
# Video ID: 2TeUrMjuEa0, Number of Comments: 30
# Video ID: hpIhbJTW42M, Number of Comments: 30
# Video ID: ehyFN4JCOTY, Number of Comments: 30
# Video ID: RZUBLTph5uw, Number of Comments: 30
# Video ID: HqMl3HfR8nk, Number of Comments: 30
# Video ID: u0wKRykb5HY, Number of Comments: 30
# Video ID: YBdZ3QtLrHI, Number of Comments: 30
# Video ID: AK7qfKuM9Bw, Number of Comments: 30
# Video ID: QooenWhi1eU, Number of Comments: 30
# Video ID: AjDuf7gx4Fw, Number of Comments: 30
# Video ID: mUOg_uS1U9E, Number of Comments: 30
# Video ID: SxfMlsygxcI, Number of Comments: 30
# Video ID: De1TSLJecSc, Number of Comments: 30
# Video ID: DRyCwJPDfXg, Number of Comments: 30
# Video ID: ih551IZjfLo, Number of Comments: 30
# Video ID: 3fF8MfxFgQg, Number of Comments: 7
# Video ID: Y_V7b6P6hDk, Number of Comments: 30
# Video ID: TdluMvfUM4M, Number of Comments: 30
# Video ID: XYz8QsZeXz4, Number of Comments: 30
# Video ID: MgKBusMm5xM, Number of Comments: 30
# Video ID: S-uhgpXAATY, Number of Comments: 30
# Video ID: JpaU7z0dBWQ, Number of Comments: 30
# Video ID: fhpVTUt_0Mc, Number of Comments: 30
# Video ID: ROqIhnZzQgY, Number of Comments: 30
# Video ID: M8ArLCxek5k, Number of Comments: 30
# Video ID: t4qcNiuxFfs, Number of Comments: 30
# Video ID: wc6csjcb5mk, Number of Comments: 30
# Video ID: AFP3kPU1Ly0, Number of Comments: 20
# Video ID: it8tZK5CSyo, Number of Comments: 30
# Video ID: NyByaL9Bnhs, Number of Comments: 30
# Video ID: ELGrIBrs7KM, Number of Comments: 30
# Video ID: 5UwR1DzpXjM, Number of Comments: 30
# Video ID: 3OaWVIw0j9w, Number of Comments: 30
# Video ID: _dD-P0JzLZA, Number of Comments: 30
# Video ID: 7Q0Y0xeOS4k, Number of Comments: 30
# Video ID: 9iFseaHfyMc, Number of Comments: 30
# Video ID: 3qD_PZRiCDs, Number of Comments: 30
# Video ID: 8MwYGX-HGBs, Number of Comments: 30
# Video ID: VmEvUTl6UL4, Number of Comments: 30
# Video ID: thGEUaYunXs, Number of Comments: 30
# Video ID: hJvaTbWnHiU, Number of Comments: 30
# Video ID: TypI8XY50Ho, Number of Comments: 30
# Video ID: jdX6qpeRybc, Number of Comments: 30
# Video ID: lEdpuwA7fDM, Number of Comments: 30
# Video ID: I_nH_eBwsAI, Number of Comments: 30
# Video ID: nEuVk9Rojyw, Number of Comments: 30
# Video ID: 87aK2jwZtsU, Number of Comments: 30
# Video ID: FV7KLybtNhU, Number of Comments: 30
# Video ID: QRdwjOKUmCU, Number of Comments: 30
# Video ID: qxbm-5zayK8, Number of Comments: 30
# Video ID: gR2exXk02pg, Number of Comments: 30
# Video ID: PLnq_WWP3zw, Number of Comments: 30
# Video ID: MgcymCOriGs, Number of Comments: 30
# Video ID: 28kZLsnFgDM, Number of Comments: 30
# Video ID: BS7iJlx1j14, Number of Comments: 30
# Video ID: i6EDH_OLoK0, Number of Comments: 30
# Video ID: 0XOYFb1nDMY, Number of Comments: 30
# Video ID: fsrpFu9imko, Number of Comments: 30
# Video ID: Y6QKKOtyi4s, Number of Comments: 30
# Video ID: BZ_f66aoZ0I, Number of Comments: 30
# Video ID: xE7bk8xrxUA, Number of Comments: 30
# Video ID: rHxE5dCcZc4, Number of Comments: 30
# Video ID: V_SW8248GoE, Number of Comments: 28
# Video ID: xlS1Jkucs6I, Number of Comments: 30
# Video ID: cWM8V9q9XSk, Number of Comments: 30
# Video ID: W5kJA_Pc_jQ, Number of Comments: 30
# Video ID: 2QAwbcmZL14, Number of Comments: 30
# Video ID: nC4ztHc515E, Number of Comments: 24
# Video ID: _-RKAvNziy4, Number of Comments: 30
# Video ID: 8mwVtmsVgRQ, Number of Comments: 30
# Video ID: zo5toA_U6FQ, Number of Comments: 30
# Video ID: 7Q290G7FaoQ, Number of Comments: 30
# Video ID: sYht9MF2QLU, Number of Comments: 30
# Video ID: Y8Pbtbai9dM, Number of Comments: 30
# Video ID: E292SryC4nk, Number of Comments: 30
# Video ID: Ks3825r31GU, Number of Comments: 30
# Video ID: 26J0FZQJHaY, Number of Comments: 30
# Video ID: GVeA6MfJ_Ls, Number of Comments: 30
# Video ID: cy5IxnikE5A, Number of Comments: 30
# Video ID: NW94cqI9-Yg, Number of Comments: 30
# Video ID: DlAMjRWJEDo, Number of Comments: 30
# Video ID: TSVHNytB6aM, Number of Comments: 30

# %%
# Create a dict to map video ids to their corresponding details
msnbc_vid_details = {vid['id']: vid for sublist in msnbc_vid_info for vid in sublist}

# Comebine vid detail with comments
msnbc_result = []

for sublist in msnbc_comments:
    for item in sublist:
        vid_id = item['VideoId']
        if vid_id in msnbc_vid_details:
            details = msnbc_vid_details[vid_id].copy()
            details.update(item)
            msnbc_result.append(details)

# %%
len(msnbc_result)
# Out:
# 2839

# %%
msnbc_comments_df = pd.DataFrame(msnbc_result)

msnbc_comments_df.head()
msnbc_comments_df.shape
# Out:
# (2839, 11)

# %% [markdown]
# ### The Daily Show

# %%
daily_vid_info = []

for category, keywords in keyword_lists.items():
    print(f"Fetching videos for category: {category}")
    vid_info = keyword_videos("UUwWhs_6x42TyRM4Wstoq8HA", keywords, "Daily Show", 10)
    print(f"Found {len(vid_info)} videos for category {category}")
    daily_vid_info.append(vid_info)
# Out:
# Fetching videos for category: isis
# Found 6 videos for category isis
# Fetching videos for category: guns
# Found 11 videos for category guns
# Fetching videos for category: immigration
# Found 11 videos for category immigration
# Fetching videos for category: economy
# Found 10 videos for category economy
# Fetching videos for category: healthcare
# Found 11 videos for category healthcare
# Fetching videos for category: socioeco
# Found 11 videos for category socioeco
# Fetching videos for category: abortion
# Found 11 videos for category abortion
# Fetching videos for category: climate
# Found 11 videos for category climate

# %%
daily_vid_ids = set()

# Extracting all ids
for sublist in daily_vid_info:
    for video in sublist:
        daily_vid_ids.add(video['id'])
        
len(daily_vid_ids)
# Out:
# 79

# %%
daily_comments = []

for ids in daily_vid_ids:
    daily_comm = get_vid_comments(ids, 30)
    daily_comments.append(daily_comm)

# %%
daily_comment_count = defaultdict(int)

for video_comments in daily_comments:
    for comment in video_comments:
        video_id = comment['VideoId']
        daily_comment_count[video_id] += 1

print("Number of comments per videoId:")

for video_id, count in daily_comment_count.items():
    print(f"Video ID: {video_id}, Number of Comments: {count}")
# Out:
# Number of comments per videoId:
# Video ID: 8uZhdZlY6qY, Number of Comments: 30
# Video ID: TtziF8sgZ0I, Number of Comments: 30
# Video ID: cV0vH_IIQo4, Number of Comments: 30
# Video ID: 2Qv0I76zZcE, Number of Comments: 30
# Video ID: 6J55FgWN85o, Number of Comments: 30
# Video ID: rVQUxB7M0nA, Number of Comments: 30
# Video ID: UlQC7SfwlwA, Number of Comments: 28
# Video ID: 0e1hpD7ForE, Number of Comments: 30
# Video ID: coL1uedveZE, Number of Comments: 30
# Video ID: 4YMPEK1pwtQ, Number of Comments: 30
# Video ID: 9QZy8dV7q1s, Number of Comments: 30
# Video ID: 3JUk5QXpW4Y, Number of Comments: 30
# Video ID: B5t12TDa618, Number of Comments: 30
# Video ID: nnPuCJqRn4U, Number of Comments: 30
# Video ID: v2bIyik6JUI, Number of Comments: 30
# Video ID: hqgFwO2D0NU, Number of Comments: 30
# Video ID: ndl97Kt9ERQ, Number of Comments: 30
# Video ID: UZw5EbpZOoY, Number of Comments: 30
# Video ID: sPtvQupLUyU, Number of Comments: 30
# Video ID: hESoqv2AwWA, Number of Comments: 30
# Video ID: F_O1_SXIdlA, Number of Comments: 30
# Video ID: jUcE3h2A_Cw, Number of Comments: 30
# Video ID: aOVKzKahIOg, Number of Comments: 30
# Video ID: r5WDqwHi6UQ, Number of Comments: 30
# Video ID: eBhmqoRj_t4, Number of Comments: 30
# Video ID: hgsBViUWwsI, Number of Comments: 30
# Video ID: -sTZrgkQx4E, Number of Comments: 30
# Video ID: 83DX5XDwz40, Number of Comments: 30
# Video ID: dOtRNgpFRn8, Number of Comments: 30
# Video ID: DZIHXZKqDeQ, Number of Comments: 30
# Video ID: U3fPfQ8MZFQ, Number of Comments: 30
# Video ID: bLgofqqWi9Y, Number of Comments: 30
# Video ID: F0kBaf-iKUs, Number of Comments: 30
# Video ID: F-89ergi_Rs, Number of Comments: 30
# Video ID: HUhe-4Tqek8, Number of Comments: 30
# Video ID: 2Py-MLiX_0g, Number of Comments: 30
# Video ID: 5FdnVetOKkw, Number of Comments: 30
# Video ID: JdWWWD29vlk, Number of Comments: 30
# Video ID: L9s5a1JNz2M, Number of Comments: 30
# Video ID: yp5HylZ05kM, Number of Comments: 30
# Video ID: sgHQknJnuRk, Number of Comments: 30
# Video ID: HA0iiXZtozE, Number of Comments: 30
# Video ID: K6sy3l68WUA, Number of Comments: 30
# Video ID: ICtioqgEmFI, Number of Comments: 30
# Video ID: 0oL6K8kg7IU, Number of Comments: 30
# Video ID: 3vrAjkOfnfA, Number of Comments: 30
# Video ID: 4IIwK-ZMScA, Number of Comments: 30
# Video ID: LCpH8O9MhlI, Number of Comments: 30
# Video ID: rx3ZpyjcVs4, Number of Comments: 30
# Video ID: 7Cl0O9nrlho, Number of Comments: 30
# Video ID: 9T80GK-koec, Number of Comments: 29
# Video ID: FNkDPqRAZqY, Number of Comments: 30
# Video ID: SCLSOjHOX3U, Number of Comments: 27
# Video ID: 7582OORlvxU, Number of Comments: 30
# Video ID: vbCSiHc-szY, Number of Comments: 30
# Video ID: eMSHNS0OOA8, Number of Comments: 30
# Video ID: TN5-1QX8XZI, Number of Comments: 30
# Video ID: kT7SlqL474Q, Number of Comments: 30
# Video ID: oOndvtJ5LKM, Number of Comments: 30
# Video ID: bLsRnx5wAds, Number of Comments: 30
# Video ID: XwxIqBCrvyk, Number of Comments: 30
# Video ID: 7l_Vos7TUZI, Number of Comments: 30
# Video ID: JTXGlrty-S0, Number of Comments: 30
# Video ID: _J2G9a09ato, Number of Comments: 30
# Video ID: 2LJ8nBgEA2Q, Number of Comments: 30
# Video ID: HPAd81AzqXg, Number of Comments: 30
# Video ID: 5byqAsAqWsk, Number of Comments: 30
# Video ID: lZeybIsnav4, Number of Comments: 30
# Video ID: bOAnCTvq55Y, Number of Comments: 30
# Video ID: N8zF9tAzu74, Number of Comments: 30
# Video ID: VfhV-ppYORU, Number of Comments: 30
# Video ID: QbTWxFwuQtM, Number of Comments: 30
# Video ID: ZPYkWsa77Rk, Number of Comments: 30
# Video ID: z8RFDOWdsrA, Number of Comments: 30
# Video ID: fBTmZHcjDgQ, Number of Comments: 30
# Video ID: Ocx4ogv1tDI, Number of Comments: 30
# Video ID: 8iSscWiA87Q, Number of Comments: 30
# Video ID: DrN9NCzeU-0, Number of Comments: 30
# Video ID: F6oHayc5pjo, Number of Comments: 30

# %%
# Create a dict to map video ids to their corresponding details
daily_vid_details = {vid['id']: vid for sublist in daily_vid_info for vid in sublist}

# Comebine vid detail with comments
daily_result = []

for sublist in daily_comments:
    for item in sublist:
        vid_id = item['VideoId']
        if vid_id in daily_vid_details:
            details = daily_vid_details[vid_id].copy()
            details.update(item)
            daily_result.append(details)

# %%
len(daily_result)
# Out:
# 2364

# %%
daily_comments_df = pd.DataFrame(daily_result)

daily_comments_df.head()
daily_comments_df.shape
# Out:
# (2364, 11)

# %% [markdown]
# ### The Young Turks

# %%
yturk_vid_info = []

for category, keywords in keyword_lists.items():
    print(f"Fetching videos for category: {category}")
    vid_info = keyword_videos("UU1yBKRuGpC1tSM73A0ZjYjQ", keywords, "Young Turks", 10)
    print(f"Found {len(vid_info)} videos for category {category}")
    yturk_vid_info.append(vid_info)
# Out:
# Fetching videos for category: isis
# Found 5 videos for category isis
# Fetching videos for category: guns
# Found 11 videos for category guns
# Fetching videos for category: immigration
# Found 11 videos for category immigration
# Fetching videos for category: economy
# Found 11 videos for category economy
# Fetching videos for category: healthcare
# Found 11 videos for category healthcare
# Fetching videos for category: socioeco
# Found 11 videos for category socioeco
# Fetching videos for category: abortion
# Found 11 videos for category abortion
# Fetching videos for category: climate
# Found 11 videos for category climate

# %%
yturk_vid_ids = set()

# Extracting all ids
for sublist in yturk_vid_info:
    for video in sublist:
        yturk_vid_ids.add(video['id'])
        
len(yturk_vid_ids)
# Out:
# 81

# %%
yturk_comments = []

for ids in yturk_vid_ids:
    yturk_comm = get_vid_comments(ids, 30)
    yturk_comments.append(yturk_comm)

# %%
yturk_comment_count = defaultdict(int)

for video_comments in yturk_comments:
    for comment in video_comments:
        video_id = comment['VideoId']
        yturk_comment_count[video_id] += 1

print("Number of comments per videoId:")

for video_id, count in yturk_comment_count.items():
    print(f"Video ID: {video_id}, Number of Comments: {count}")
# Out:
# Number of comments per videoId:
# Video ID: MEc2gfWcQEc, Number of Comments: 30
# Video ID: ymF88jc2oPo, Number of Comments: 30
# Video ID: _7nnyMHUUys, Number of Comments: 30
# Video ID: H_gbq0pdYp0, Number of Comments: 30
# Video ID: 4vw4sCou7wU, Number of Comments: 30
# Video ID: fjBtngQR4WY, Number of Comments: 30
# Video ID: ZRGEDoixz_8, Number of Comments: 30
# Video ID: q4bBZEEL71s, Number of Comments: 30
# Video ID: 1RWcMnxUZVc, Number of Comments: 30
# Video ID: tZu91Y_l8dc, Number of Comments: 30
# Video ID: SkFJTsEsMVY, Number of Comments: 30
# Video ID: 2Eb2kPjP60c, Number of Comments: 1
# Video ID: JiPtY6stLB4, Number of Comments: 30
# Video ID: yWMmnfjTT8s, Number of Comments: 30
# Video ID: Q8lGHAPfSis, Number of Comments: 30
# Video ID: _dMtdutY2f4, Number of Comments: 30
# Video ID: I5YvqhWYSuM, Number of Comments: 30
# Video ID: vfSZ5krN2Hc, Number of Comments: 30
# Video ID: szPhH-7TOvY, Number of Comments: 30
# Video ID: 5SlR-UHguKY, Number of Comments: 30
# Video ID: tTJMvR-NcO8, Number of Comments: 30
# Video ID: V33C3pqZLkA, Number of Comments: 30
# Video ID: 1J_qMKusKm0, Number of Comments: 30
# Video ID: Mx-UAw6hxok, Number of Comments: 30
# Video ID: NEbvhGPbZy0, Number of Comments: 30
# Video ID: 7KHdyycmmwI, Number of Comments: 30
# Video ID: yvfBnOLe4U8, Number of Comments: 30
# Video ID: VPVuEqjoN-o, Number of Comments: 30
# Video ID: aJzXrnTIJ7M, Number of Comments: 30
# Video ID: ffyycT9y09U, Number of Comments: 30
# Video ID: 9p7-IdpcjVg, Number of Comments: 30
# Video ID: OSE1rptD1yM, Number of Comments: 30
# Video ID: chTEF4JFWls, Number of Comments: 30
# Video ID: Nn2mgrLP8Ac, Number of Comments: 30
# Video ID: i_4t16NNITI, Number of Comments: 30
# Video ID: fR46YIa11Zg, Number of Comments: 30
# Video ID: HovsvsaCwts, Number of Comments: 30
# Video ID: aOjNXlg9bNg, Number of Comments: 30
# Video ID: xRq0SCJCAPs, Number of Comments: 30
# Video ID: QYkKHoCsi8I, Number of Comments: 30
# Video ID: wiL9Gx0ZwZ8, Number of Comments: 30
# Video ID: jaP0E8qyzSc, Number of Comments: 30
# Video ID: 6l5hDmCHAKU, Number of Comments: 30
# Video ID: UkUve3O6zO8, Number of Comments: 30
# Video ID: 85-QTg1gWVU, Number of Comments: 30
# Video ID: UHhCKM7ZVoE, Number of Comments: 30
# Video ID: 32WrXoGqA-o, Number of Comments: 30
# Video ID: 5WbS9ekzx90, Number of Comments: 30
# Video ID: vpq4A85hi74, Number of Comments: 30
# Video ID: a2p8qc7KPPk, Number of Comments: 30
# Video ID: xtizGqyqP4o, Number of Comments: 30
# Video ID: IbzzED4SSV4, Number of Comments: 30
# Video ID: KFclnQ6fLtM, Number of Comments: 30
# Video ID: EOj5JsjOlL0, Number of Comments: 30
# Video ID: xxeFUBWzNhI, Number of Comments: 30
# Video ID: ZLoHwv-VG4s, Number of Comments: 30
# Video ID: zM_1-BmuJ5U, Number of Comments: 30
# Video ID: DxM57pMaUOg, Number of Comments: 30
# Video ID: a_bRrhcXwQw, Number of Comments: 30
# Video ID: dXpAgVPLUbY, Number of Comments: 30
# Video ID: yC85kgIaHfg, Number of Comments: 30
# Video ID: teTvOBr5T3U, Number of Comments: 30
# Video ID: QsFZ98qBQkw, Number of Comments: 30
# Video ID: y5zQPvQVbKI, Number of Comments: 30
# Video ID: DjC7DAKSGhY, Number of Comments: 30
# Video ID: ktgloH7vlo8, Number of Comments: 30
# Video ID: NTWz2k5P0QI, Number of Comments: 30
# Video ID: prPxJ5sE4Hc, Number of Comments: 30
# Video ID: NXuPjIew2RQ, Number of Comments: 30
# Video ID: vusQXYuEhVc, Number of Comments: 30
# Video ID: SyCVud_BPr4, Number of Comments: 30
# Video ID: OR11EfAh9Rc, Number of Comments: 30
# Video ID: sEW1RMVXEPc, Number of Comments: 30
# Video ID: bMWAVIVmw_o, Number of Comments: 30
# Video ID: OV3wyVxqsDU, Number of Comments: 30
# Video ID: xpWyl5OXvEE, Number of Comments: 30
# Video ID: d8GiuBzqzY4, Number of Comments: 30
# Video ID: ojKd6KrDl18, Number of Comments: 30
# Video ID: y_lQoXCG14A, Number of Comments: 30

# %%
# Create a dict to map video ids to their corresponding details
yturk_vid_details = {vid['id']: vid for sublist in yturk_vid_info for vid in sublist}

# Comebine vid detail with comments
yturk_result = []

for sublist in yturk_comments:
    for item in sublist:
        vid_id = item['VideoId']
        if vid_id in yturk_vid_details:
            details = yturk_vid_details[vid_id].copy()
            details.update(item)
            yturk_result.append(details)

# %%
len(yturk_result)
# Out:
# 2341

# %%
yturk_comments_df = pd.DataFrame(yturk_result)

yturk_comments_df.head()
yturk_comments_df.shape
# Out:
# (2341, 11)

# %% [markdown]
# ### Combine ALL DF and Save as CSV

# %%
democrat_comment_df = pd.concat([vice_comments_df, vox_comments_df, msnbc_comments_df, daily_comments_df, yturk_comments_df], ignore_index=True)

# %%
democrat_comment_df.shape
# Out:
# (11662, 11)

# %%
# Save df to a CSV file
democrat_comment_df.to_csv("democrat_comments.csv", index=False)

# %% [markdown]
# ## Another Method to Grab Channel CSV (outdated)

# %% [markdown]
# #### Vice

# %%
vice_comments = get_video_comments('Vice', 'UUn8zNIfYAQNdrFRrr8oibKw', keyword_lists, limit=30)

# %%
len(vice_comments)

# %%
# Check output, commented out for viewing purposes
# vice_comments[:10]

# %%
# Change to DF
vice_comments_df = pd.DataFrame(vice_comments)

# %%
# Check output, commented out for viewing purposes
# vice_comments_df.head()

# %%
# Save df to a CSV file
vice_comments_df.to_csv("vice_comments.csv", index=False)

# %% [markdown]
# ### Vox

# %%
vox_comments = get_video_comments('Vox', 'UULXo7UDZvByw2ixzpQCufnA', keyword_lists, limit=30)

# %%
len(vox_comments)

# %%
# Check output, commented out for viewing purposes
# vox_comments[:10]

# %%
# Change to DF
vox_comments_df = pd.DataFrame(vox_comments)

# Check output, commented out for viewing purposes
# vox_comments_df.head()

# %%
# Save df to a CSV file
vox_comments_df.to_csv("vox_comments.csv", index=False)

# %% [markdown]
# #### MSNBC

# %%
msnbc_comments = get_video_comments('MSNBC', 'UUaXkIU1QidjPwiAYu6GcHjg', keyword_lists, limit=20)

# %%
len(msnbc_comments)

# %%
# Check output, commented out for viewing purposes
msnbc_comments[:10]

# %%
# Change to DF
msnbc_comments_df = pd.DataFrame(msnbc_comments)

# Check output, commented out for viewing purposes
# msnbc_comments_df.head()

# %%
# Save df to a CSV file
msnbc_comments_df.to_csv("msnbc_comments.csv", index=False)

# %% [markdown]
# #### The Daily Show

# %%
dailyshow_comments = get_video_comments('The Daily Show', 'UUwWhs_6x42TyRM4Wstoq8HA', keyword_lists, limit=30)

# %%
len(dailyshow_comments)

# %%
# Check output, commented out for viewing purposes
dailyshow_comments[:10]

# %%
# Change to DF
dailyshow_comments_df = pd.DataFrame(dailyshow_comments)

# Check output, commented out for viewing purposes
# dailyshow_comments_df.head()

# %%
# Save df to a CSV file
dailyshow_comments_df.to_csv("dailyshow_comments.csv", index=False)

# %% [markdown]
# #### Young Turks

# %%
yturk_comments = get_video_comments('The Young Turks', 'UU1yBKRuGpC1tSM73A0ZjYjQ', keyword_lists, limit=30)

# %%
len(yturk_comments)

# %%
# Check output, commented out for viewing purposes
yturk_comments[:10]

# %%
# Change to DF
yturk_comments_df = pd.DataFrame(yturk_comments)

# Check output, commented out for viewing purposes
# yturk_comments_df.head()

# %%
# Save df to a CSV file
yturk_comments_df.to_csv("yturk_comments.csv", index=False)

# %% [markdown]
# #### Combine all DFs

# %%
yturk_comments_df = pd.read_csv('yturk_comments.csv')

# %%
combine_democ_comments = pd.concat([vice_comments_df, vox_comments_df, yturk_comments_df])

combine_democ_comments.reset_index(drop=True, inplace=True)

# %%
combine_democ_comments.shape

# %%
# Save df to a CSV file
combine_democ_comments.to_csv("combine_democ_comments.csv", index=False)

# %% [markdown]
# ### Top 5 Republican YouTube Channels
# Fox News, Ben Shapiro, Steven Crowder, The Daily Mail, The Daily Wire

# %%
# function to fetch videos from a playlist and get title with keywordsand 
def keyword_videos_right(playlist_id, channel_name, dict_list):
    videos_info = []
    next_page_token = None

    while True:
        # Make the next API request using the nextPageToken
        request = youtube.playlistItems().list(
            part="snippet",
            playlistId=playlist_id,
            pageToken=next_page_token
        ) 
        res = request.execute()

        # Process the response and save video info
        for v in res["items"]:
            video_title = v["snippet"]["title"]
            for keyword_name, keywords in keyword_lists.items():
            
                detected_word = contains_keyword(video_title, keywords)
                if detected_word:
                    # Separate Resource Call to retrieve video views
                    views = youtube.videos().list(id=v['snippet']['resourceId']['videoId'], part="snippet,contentDetails,statistics")
                    view_temp = views.execute()
                    video_views = view_temp['items'][0]['statistics']['viewCount']
    
                    # Append video information with views to videos_info list
                    dict_list.append({
                        "id": v["snippet"]["resourceId"]["videoId"],
                        "channel_name" : v['snippet']['channelTitle'],
                        "title": video_title,
                        "keyword": detected_word,
                        "published_at": v["snippet"]["publishedAt"],
                        "VideoViews": video_views
                    })
        # Update the nextPageToken for the next iteration
        next_page_token = res.get('nextPageToken')

        if not next_page_token or (len(videos_info) > 60):
            break
    return videos_info

# %%
# Define channels
channels_right = ["BenShapiro", "StevenCrowder", "FoxNews", "DailyWirePlus", "dailymail"]

# %%
# Gets list of Right channels playlist id for uploads
right_up_id = []
for channel in channels_right:
    chan_id = get_channel_id(channel)
    upload_id = get_upload_id(chan_id)
    right_up_id.append(upload_id)

# %%
right_up_id

# %%
for keyword_name, keywords in keyword_lists.items():
    print(keywords)

# %% [markdown]
# ## Code for collecting titles

# %%
# Collects video titles for each of the given channels that contain keywords given
right_video_titles = []
for channel, upload_id in zip(channels_right, right_up_id):
    print(channel)
    videos_info = keyword_videos_right(upload_id, channel, right_video_titles)
    #right_video_titles.append(videos_info)

# %%
right_df = pd.DataFrame(right_video_titles)

# %%
right_df.shape

# %%
right_df.head(200)

# %%
# Save DF as CSV
right_df.to_csv('Project_yt_titles.csv')

# %%
right_video_titles[1]

# %% [markdown]
# ## Code to get Comments

# %%
# Function for getting comments for a given of videos
def get_vid_comments_right(vid, limit):
    vids_final = []
    
    # Iterate through each video in the video list
    request = youtube.commentThreads().list(
        videoId=vid['id'],
        part='id,snippet,replies',
        textFormat='plainText',
        order='relevance',
        maxResults=100
    )
    res = request.execute()

    # Iterate through each comment
    try:
        while res["nextPageToken"] != None:
            for v in res["items"]:
                # Create a copy of dictionary of current video that is being iterated. This is because each comment is also contained with the video data
                vid_temp = vid.copy()
                vid_temp.update({'CommentId':v['id']})
                vid_temp.update({'CommentTitle':v['snippet']['topLevelComment']['snippet']['textOriginal']})
                vid_temp.update({'CommentCreationTime':v['snippet']['topLevelComment']['snippet']['publishedAt']})
                vid_temp.update({'CommentLikes':v['snippet']['topLevelComment']['snippet']['likeCount']})
                vids_final.append(vid_temp)
            
            request = youtube.commentThreads().list(
                videoId=vid['id'],
                part='id,snippet,replies',
                textFormat='plainText',
                order='relevance',
                maxResults=100,
                pageToken = res["nextPageToken"]
            )
            res = request.execute()
    except KeyError:
        for v in res["items"]:
                # Create a copy of dictionary of current video that is being iterated. This is because each comment is also contained with the video data
                vid_temp = vid.copy()
                vid_temp.update({'CommentId':v['id']})
                vid_temp.update({'CommentTitle':v['snippet']['topLevelComment']['snippet']['textOriginal']})
                vid_temp.update({'CommentCreationTime':v['snippet']['topLevelComment']['snippet']['publishedAt']})
                vid_temp.update({'CommentLikes':v['snippet']['topLevelComment']['snippet']['likeCount']})
                vids_final.append(vid_temp)
        # If the number of saved videos is larger than self-defined limit, break while loop and return the list of videos
        if len(vids_final) >= limit:
            return(vids_final)
            
            
    return vids_final

# %%
# Runs code to get comments for each title in right_video_titles
right_comments_dict_list = []
for title in right_video_titles:
    result = get_vid_comments_right(title, 100)
    right_comments_dict_list.append(result)

# %%
len(right_comments_dict_list)

# %%
# Converts list of list of dictionaries to a flat list
flat_list_of_dicts = [item for sublist in right_comments_dict_list for item in sublist]

# %%
# Converts list of dictionaries to dataframe
right_comments_df = pd.DataFrame(flat_list_of_dicts)

# %%
right_comments_df.tail(2)

# %%
right_comments_df.shape

# %%
# Save DF as CSV
right_comments_df.to_csv('Project_yt_comments.csv')

# %% [markdown]
# ## Andy's Section

# %%
# Function for retrieving the upload playlist id of a channel
def get_upload_id(channel):
    request = youtube.channels().list(part='contentDetails', forUsername=channel)
    res = request.execute()
    return res["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

# Function for retrieving all vids within the upload playlist of a channel, stopping once a limit INT has been reached
def get_vids(channel, limit, keywords, ideology):
    
    # Output list
    vid_lst=[]

    request = youtube.playlistItems().list(part='snippet',playlistId=get_upload_id(channel),maxResults=50)
        
    res = request.execute()
    nextPageToken = res['nextPageToken']

    # Iterate through each video in the playlist
    for v in res["items"]:

        # Normalization of video title to check for keywords
        title = v['snippet']['title']
        title = title.lower()
        title = re.sub(r'[^\w\s]','', title)

        # Check for key words. If key word detected, then counter +1. If counter > 0, then the post will be flagged and added.
        counter = 0
        for word in title.split():
            counter = 0
            if word in keywords:
                counter += 1
        if counter == 0:
            continue

        # Create temp dictionary per video, and add video-specific information to dictionary
        vid_dict = {}
        vid_dict['ChannelName'] = v['snippet']['channelTitle']
        vid_dict['VideoId'] = v['snippet']['resourceId']['videoId']
        vid_dict['VideoTitle'] = v['snippet']['title']
        vid_dict['Ideology'] = ideology

        # Separate Resource Call to retrieve video views
        views = youtube.videos().list(id=v['snippet']['resourceId']['videoId'], part="snippet,contentDetails,statistics")
        view_temp = views.execute()
        vid_dict['VideoViews'] = view_temp['items'][0]['statistics']['viewCount']

        # Append dictionary to greater list
        vid_lst.append(vid_dict)

    # Iterate until no more next page
    while nextPageToken:
        try:
            request = youtube.playlistItems().list(part='snippet', playlistId=get_upload_id(channel), maxResults=50, pageToken = res['nextPageToken'])                
            res = request.execute()

            # Redefine next page token to check @ next iteration
            nextPageToken = res['nextPageToken']

            # Iterate through each video
            for v in res["items"]:

                # Normalization of video title to check for keywords
                title = v['snippet']['title']
                title = title.lower()
                title = re.sub(r'[^\w\s]','', title)

                # Check for key words. If key word detected, then counter +1. If counter > 0, then the post will be flagged and added.
                counter = 0
                for word in title.split():
                    if word in keywords:
                        counter += 1
                if counter == 0:
                    continue

                # Create temp dictionary per video, and add video-specific information to dictionary
                vid_dict = {}
                vid_dict['ChannelName'] = v['snippet']['channelTitle']
                vid_dict['VideoId'] = v['snippet']['resourceId']['videoId']
                vid_dict['VideoTitle'] = v['snippet']['title']
                                
                # Separate Resource Call to retrieve video views
                views = youtube.videos().list(id=v['snippet']['resourceId']['videoId'], part="snippet,contentDetails,statistics")
                view_temp = views.execute()
                vid_dict['VideoViews'] = view_temp['items'][0]['statistics']['viewCount']
                
                vid_lst.append(vid_dict)

            # If the number of saved videos is larger than self-defined limit, break while loop and return the list of videos
            if len(vid_lst) >= limit:
                return(vid_lst)

        # Error case handling
        except KeyError:
            break

# Function for getting top 30 relevant comments for a list of videos
def get_vid_comments(vid_lst, limit):
    vids_final = []

    # Iterate through each video in the video list
    for vid in vid_lst:
        
        request = youtube.commentThreads().list(videoId=vid['VideoId'],part='id,snippet,replies',textFormat='plainText',order='relevance',maxResults=50)
        res = request.execute()

        # Iterate through each comment
        for v in res["items"]:
            
            # Create a copy of dictionary of current video that is being iterated. This is because each comment is also contained with the video data
            vid_temp = copy.copy(vid)
            vid_temp.update({'CommentId':v['id']})
            vid_temp.update({'CommentTitle':v['snippet']['topLevelComment']['snippet']['textOriginal']})
            vid_temp.update({'CommentCreationTime':v['snippet']['topLevelComment']['snippet']['publishedAt']})
            vid_temp.update({'CommentLikes':v['snippet']['topLevelComment']['snippet']['likeCount']})
            vids_final.append(vid_temp)

        while nextPageToken:
            try:
                request = youtube.commentThreads().list(videoId=vid['VideoId'],part='id,snippet,replies',textFormat='plainText',order='relevance',maxResults=50)
                res = request.execute()
        
                nextPageToken = res['nextPageToken']
                
                for v in res["items"]:
                    # Create a copy of dictionary of current video that is being iterated. This is because each comment is also contained with the video data
                    vid_temp = copy.copy(vid)
                    vid_temp.update({'CommentId':v['id']})
                    vid_temp.update({'CommentTitle':v['snippet']['topLevelComment']['snippet']['textOriginal']})
                    vid_temp.update({'CommentCreationTime':v['snippet']['topLevelComment']['snippet']['publishedAt']})
                    vid_temp.update({'CommentLikes':v['snippet']['topLevelComment']['snippet']['likeCount']})
                    vids_final.append(vid_temp)
                    
                # If the number of saved videos is larger than self-defined limit, break while loop and return the list of videos
                if len(vids_final) >= limit:
                    return(vids_final)
            except KeyError:
                break
            
    return vids_final

# from Lab9
def textcleaner(row):
    row = str(row)
    row = row.lower()
    # remove punctuation
    row = re.sub(r'[^\w\s]', '', row)
    #remove urls
    row  = re.sub(r'http\S+', '', row)
    #remove mentions
    row = re.sub(r"(?<![@\w])@(\w{1,25})", '', row)
    #remove hashtags
    row = re.sub(r"(?<![#\w])#(\w{1,25})", '',row)
    #remove other special characters
    row = re.sub('[^A-Za-z .-]+', '', row)
        #remove digits
    row = re.sub('\d+', '', row)
    row = row.strip(" ")
    row = re.sub('\s+', ' ', row)
    return row
    
stopeng = set(stopwords.words('english'))
def remove_stop(text):
    try:
        words = text.split(' ')
        valid = [x for x in words if x not in stopeng]
        return(' '.join(valid))
    except AttributeError:
        return('')

def df_clean_process(df):

    # Change datetime to date
    df['VideoPublishedDate'] = df['VideoPublishedDate'].apply(lambda x: datetime.strptime(x[0:10], '%Y-%m-%d').date())
    df['CommentCreationTime'] = df['CommentCreationTime'].apply(lambda x: datetime.strptime(x[0:10], '%Y-%m-%d').date())

    # Check NaN, if < 10% of total dataset, drop NaN
    if df.isnull().values.any():
        if len(df[df.isna().any(axis=1)]) < len(df) * 0.1:
            df = df.dropna()

    # Split into separate df for computational load reduction
    title_df = df[['ChannelName', 'VideoTitle', 'VideoPublishedDate', 'VideoViews', 'Ideology']].drop_duplicates()
    comment_df = df[['ChannelName', 'VideoViews', 'CommentTitle', 'CommentCreationTime', 'CommentLikes', 'Ideology']]

    # tokenize
    title_df['TweetToken'] = title_df['VideoTitle'].apply(lambda x: casual.TweetTokenizer().tokenize(x))
    comment_df['TweetToken'] = comment_df['CommentTitle'].apply(lambda x: casual.TweetTokenizer().tokenize(x))

    # clean
    title_df['Cleaned'] = title_df['TweetToken'].apply(lambda x: remove_stop(textcleaner(x)))
    comment_df['Cleaned'] = comment_df['TweetToken'].apply(lambda x: remove_stop(textcleaner(x)))

    return (title_df, comment_df)

    # Sentiment analysis

# %%
# define channels
channels_left = ['VICE', 'Vox', 'MSNBC', 'The Daily Show', 'TheYoungTurks']
channels_right = ['Fox News', 'Ben Shapiro', 'StevenCrowder', 'Daily Mail', 'DailyWire+']

# define key ideologies/associated keywords to look for in title
isis_keywords = ['terrorism', 'terrorist', 'extremism', 'radicalist', 'radicalism']
guns_keywords = ['shooting', 'shootings', 'school shooting', 'school shootings', 'firearms', 'firearm', 'gun', 'gun control', 'guns', 'nra', 'second amendment']
immigration_keywords = ['border control', 'mexico', 'visa', 'citizenship', 'asylum', 'deportation', 'refugee']
economy_keywords = ['budget', 'budget deficit', 'unemployed', 'inflation', 'interest rate',' federal reserve', 'market', 'employment']
health_care_keywords = ['medicaid', 'covid', 'obamacare', 'public health', 'insurance']
socioeconomic_keywords = ['rich', 'poor', 'income inequality', 'poverty',' wealth distribution']
abortion_keywords = ['pregnancy', 'unwanted pregnancy', 'roe', 'wade', 'abortion', 'pro-life', 'rape', 'incest', 'life of mother', 'religion']
climate_change_keywords = ['global warming', 'carbon', 'alternative energy', 'climate', 'methane', 'emissions','gas','greenhouse']

# Define for iteration
keywords = [isis_keywords, guns_keywords, immigration_keywords, economy_keywords, health_care_keywords, socioeconomic_keywords, abortion_keywords, climate_change_keywords]

# Pre-define empty df
left_df = pd.DataFrame(columns=['ChannelName', 'VideoId', 'VideoTitle', 'Ideology', 'VideoPublishedDate', 'VideoViews', 'CommentId', 'CommentTitle', 'CommentCreationTime', 'CommentLikes'])

# Loop through all left channels
for channel in channels_left:

    # Loop through all keywords/ideologies
    for keyword, ideology in zip(keywords, ['ISIS', 'GUNS', 'IMMIGRATION', 'ECONOMY', 'HEALTH CARE', 'SOCIOECONOMIC', 'ABORTION', 'CLIMATE CHANGE']):

        # Return temp df for one ideology for one channel
        temp_df = pd.DataFrame(get_vid_comments(get_vids(channel, 50, keyword, ideology)[0:50], 150))

        # Append temp df to master df
        left_df = pd.concat([left_df,temp_df])

# Pre-define empty df
right_df = pd.DataFrame(columns=['ChannelName', 'VideoId', 'VideoTitle', 'Ideology', 'VideoPublishedDate', 'VideoViews', 'CommentId', 'CommentTitle', 'CommentCreationTime', 'CommentLikes'])
for channel in channels_right:

    # Loop through all keywords/ideologies
    for keyword, ideology in zip(keywords, ['ISIS', 'GUNS', 'IMMIGRATION', 'ECONOMY', 'HEALTH CARE', 'SOCIOECONOMIC', 'ABORTION', 'CLIMATE CHANGE']):

        # Return temp df for one ideology for one channel
        temp_df = pd.DataFrame(get_vid_comments(get_vids(channel, 50, keyword, ideology)[0:50], 150))

        # Append temp df to master df
        right_df = pd.concat([right_df,temp_df])

(left_title_df, left_comment_df) = df_clean_process(left_df)
(right_title_df, right_comment_df) = df_clean_process(right_df)
# Loop through all right channels
for channel in channels_right:

    # Loop through all keywords/ideologies
    for keyword, ideology in zip(keywords, ['ISIS', 'GUNS', 'IMMIGRATION', 'ECONOMY', 'HEALTH CARE', 'SOCIOECONOMIC', 'ABORTION', 'CLIMATE CHANGE']):

        # Return temp df for one ideology for one channel
        temp_df = pd.DataFrame(get_vid_comments(get_vids(channel, 50, keyword, ideology)[0:50], 150))

        # Append temp df to master df
        right_df = pd.concat([right_df,temp_df])

(left_title_df, left_comment_df) = df_clean_process(left_df)
(right_title_df, right_comment_df) = df_clean_process(right_df)
